# %% [markdown]
# <a href="https://colab.research.google.com/github/adryanshinta/Skripsi/blob/main/translate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip3 install googletrans==3.1.0a0
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 55.1/55.1 kB 1.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.5/1.5 MB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 133.4/133.4 kB 11.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.8/58.8 kB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.6/42.6 kB 4.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.6/53.6 kB 6.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.0/65.0 kB 7.5 MB/s eta 0:00:00
# ...
#   Created wheel for googletrans: filename=googletrans-3.1.0a0-py3-none-any.whl size=16352 sha256=c6c4a9323d82ac113fd77a32fbeab62827870896e32a32e8b2334b2bbe8ca3ce
#   Stored in directory: /root/.cache/pip/wheels/50/5d/3c/8477d0af4ca2b8b1308812c09f1930863caeebc762fe265a95
# Successfully built googletrans
# ...
#   Attempting uninstall: chardet
# ...

# %%
#import library yang dibutuhkan
import pandas as pd
import googletrans
from googletrans import Translator
import numpy as np

# %%
#import dataset
df = pd.read_csv("/content/shopee_pre.csv")
df.head()
# Out:
#                                              content  score  \
# 0  Shopee nipu,, saya ngumpulin koin, dan masa ka...      1
# 1          ko pembaharuan nya jadi kaya toko sebelah      1
# 2  Hrga barang murah cuma ga ada gratis ongkir d ...      3
# 3  pengiriman pake SPX gagal... pesan dr tggl 3 d...      1
# 4  Berbelanja apapun lebih simpel, Shopee express...      5
#
#                                           text_clean  \
# 0  shopee nipu saya ngumpulin koin dan masa kadal...
# 1          ko pembaharuan nya jadi kaya toko sebelah
# 2  hrga barang murah cuma ga ada gratis ongkir d ...
# 3  pengiriman pake spx gagal pesan dr tggl  des a...
# 4  berbelanja apapun lebih simpel shopee express ...
#
#                                        text_StopWord  \
# 0  shopee nipu ngumpulin koin kadaluarsanya tangg...
# 1               ko pembaharuan nya kaya toko sebelah
# 2  hrga barang murah ga gratis ongkir d cod d met...
# 3  pengiriman pake spx gagal pesan dr tggl des di...
# ...

# %% [markdown]
# translate

# %%
translator = Translator()
translations = {}
for column in df.columns:
  #unique elements of the column
  unique_elements = df[column].unique()
  for element in unique_elements:
    #adding all the translation to dictionary (translations)
    translations[element] = translator.translate(element).text
translations
# Out:
# {'Shopee nipu,, saya ngumpulin koin, dan masa kadaluarsanya tanggal 31 Desember,, sekarang bru tanggal 16, kok sudah hangus koin yg saya cek in setiap hari, padahal belum di gunakan,, balikin lgi koin saya.....': "Shopee is a scam... I collected coins, and the expiry date is December 31st, now it's the 16th, how come the coins I check in every day have been burned, even though they haven't been used yet... I'm returning my coins...",
#  'ko pembaharuan nya jadi kaya toko sebelah': 'How come the renewal looks like the shop next door?',
# ...

# %%
#mengganti semua kata yang diterjemahkan dari kamus ke original dataframe
df.replace(translations, inplace = True)

# %%
df.head(10)
# Out:
#                                              content score  \
# 0  Shopee is a scam... I collected coins, and the...     1
# 1  How come the renewal looks like the shop next ...     1
# 2  The price of the goods is cheap but there's no...     3
# 3  Delivery using SPX failed... ordered from 3 De...     1
# 4  Shopping for anything is simpler, Shopee expre...     5
# 5  It's fun, but if I may know how to complete th...     5
# 6  more perfect live chat customer service menu s...     5
# 7  Najis delivery took a really long time, what's...     1
# 8  Tired.... if only one is successfully sent, of...     5
# 9  Lots of choices, prices can suit your pocket, ...     5
#
#                                           text_clean  \
# 0  Shopee tricked me into collecting coins and th...
# 1  How come the renewal looks like the shop next ...
# 2  the price of the goods is cheap but there is n...
# 3  delivery using spx failed order from dec final...
# ...

# %%
df.to_csv("sp_tl1.csv", index = False) #tes simpen dulu
