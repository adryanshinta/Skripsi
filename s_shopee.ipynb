# %% [markdown]
# <a href="https://colab.research.google.com/github/adryanshinta/Skripsi/blob/main/s_shopee.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# scraping data

# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.4-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.4

# %% [markdown]
# Impor paket yang diperlukan

# %%
from google_play_scraper import app

import pandas as pd

import numpy as np

# %%
#scrape jumlah ulasan yang diinginkan
from google_play_scraper import Sort, reviews

result, continuation_token = reviews(
    'com.shopee.id',
    lang='id',  #disini kita mau men scrape data ulasan aplikasi shopee yang berada di google play store
    country='id', #kita setting bahasa nya menjadi bahasa indonesia
    sort=Sort.MOST_RELEVANT, # # kemudian kita gunakan most_relevan untuk mendapatkan ulasan yang paling relevant
    count=2000, # disini jumlah ulasan yang mau kita ambil ada seribu
    filter_score_with=None # # kemudian di filter_score kita gunakan None untuk mengambil semua score atau ratting bintang 1 sampai 5
)

# %%
df_shopee = pd.DataFrame(np.array(result),columns=['review'])

df_shopee = df_shopee.join(pd.DataFrame(df_shopee.pop('review').tolist()))

df_shopee.head()
# Out:
#                                reviewId                      userName  \
# 0  b26f81ae-9cd0-4a4e-9a89-7b4a01b400c6  Azzahra Zaskiara kurniandari
# 1  1ce0eb28-df34-4a9f-877c-8a7ea6fe1f27                   Rianti 1004
# 2  332325f5-99d3-413c-a82e-89e561c5c4dd                     Adji Djie
# 3  e7b0d332-575d-444d-8ad9-d5791da38dc3                Yunan Erdiansa
# 4  fd0aba18-74e1-467e-9264-07516946817f              Muh Nashih Ulwan
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a/ACg8oc...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Sekarang jadi muncul iklan di hp saya, itu san...      1            333
# 1  Ongkirnya mahal !! Makin kesini makin mahal ha...      1            306
# 2  Sekarang sangat Sulit memuat fitur transfer da...      1            199
# 3  Kenapa chat loading terus dan akhirnya gagal, ...      2              8
# 4  Jujur aja belanja apa-apa selalu pake shope ka...      2              3
#
#   reviewCreatedVersion                  at  \
# 0              3.14.22 2023-12-10 12:55:36
# 1              3.14.22 2023-12-09 18:21:23
# 2              3.14.22 2023-12-10 05:09:24
# 3              3.14.22 2023-12-09 23:38:06
# 4              3.14.22 2023-12-10 14:42:06
#
#                                         replyContent           repliedAt  \
# 0  Hi Kak, maaf ya buat risau. Mengenai kendala t... 2023-12-10 13:17:14
# 1                                               None                 NaT
# 2  Hai kak, maaf atas kendalanya. Mimin bantu inf... 2023-12-10 06:10:40
# 3  Hai kak, maaf banget ya udah buat ga nyaman. T... 2023-12-09 15:20:32
# 4  Hi Kak, maaf udh bkin km glau terkait applikas... 2023-12-10 15:33:09
#
#   appVersion
# 0    3.14.22
# 1    3.14.22
# 2    3.14.22
# 3    3.14.22
# 4    3.14.22

# %%
len(df_shopee.index) #kemudian hitung kembali berapa jumlah data yg didapatkan
# Out:
# 2000

# %%
df_shopee[['userName', 'score','at', 'content']].head()  #dari scrapping tsb didapatkan banyak sekali kolom, kemudian kolom" tsb kita filter
                                                        #sehingga didapatkan kolom username, score, at dan content
# Out:
#                        userName  score                  at  \
# 0  Azzahra Zaskiara kurniandari      1 2023-12-10 12:55:36
# 1                   Rianti 1004      1 2023-12-09 18:21:23
# 2                     Adji Djie      1 2023-12-10 05:09:24
# 3                Yunan Erdiansa      2 2023-12-09 23:38:06
# 4              Muh Nashih Ulwan      2 2023-12-10 14:42:06
#
#                                              content
# 0  Sekarang jadi muncul iklan di hp saya, itu san...
# 1  Ongkirnya mahal !! Makin kesini makin mahal ha...
# 2  Sekarang sangat Sulit memuat fitur transfer da...
# 3  Kenapa chat loading terus dan akhirnya gagal, ...
# 4  Jujur aja belanja apa-apa selalu pake shope ka...

# %%
#Run This Code to Sort the Data By Date

new_df = df_shopee[['userName', 'score','at', 'content']]
sorted_df = new_df.sort_values(by='at', ascending=False) #Sort by Newst, change to True if you want to sort by Oldest.
sorted_df.head()
# Out:
#                  userName  score                  at  \
# 158      Samsul Huda (HM)      5 2023-12-11 09:32:39
# 1605          Rini Cantik      5 2023-12-11 09:18:40
# 41        Muhammad Rif'at      2 2023-12-11 09:02:07
# 128   Shofiyah Salsabilah      1 2023-12-11 08:58:22
# 803          Linda Pongoh      1 2023-12-11 08:54:13
#
#                                                 content
# 158   Info dong min, saya pernah ada tagihan paylate...
# 1605  aplikasi shopee,yg menurut aku sih lumayan bag...
# 41    Sekian tahun memakai aplikasi ini, dengan form...
# 128   Shopee dari dulu selalu pakek aplikasi ini, be...
# 803   Kecewa dengan pengiriman otomatis pake J & T m...

# %%
my_df = sorted_df[['userName', 'score','at', 'content']] #kemudian kita simpan ke variabel my_df

# %%
my_df=my_df[['content', 'score']]#karena kita hanya membutuhkan kolom content dan score maka kita lakukan filter kolom lgi hing
