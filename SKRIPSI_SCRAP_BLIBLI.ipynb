# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
import google_play_scraper

# %%
app_id = 'blibli.mobile.commerce'

# %%
from google_play_scraper import Sort
from google_play_scraper.constants.element import ElementSpecs
from google_play_scraper.constants.regex import Regex
from google_play_scraper.constants.request import Formats
from google_play_scraper.utils.request import post

import pandas as pd
from datetime import datetime
from tqdm import tqdm
import time
import json
from time import sleep
from typing import List, Optional, Tuple

# %%
MAX_COUNT_EACH_FETCH = 199


class _ContinuationToken:
    __slots__ = (
        "token",
        "lang",
        "country",
        "sort",
        "count",
        "filter_score_with",
        "filter_device_with",
    )

    def __init__(
        self, token, lang, country, sort, count, filter_score_with, filter_device_with
    ):
        self.token = token
        self.lang = lang
        self.country = country
        self.sort = sort
        self.count = count
        self.filter_score_with = filter_score_with
        self.filter_device_with = filter_device_with


def _fetch_review_items(
    url: str,
    app_id: str,
    sort: int,
    count: int,
    filter_score_with: Optional[int],
    filter_device_with: Optional[int],
    pagination_token: Optional[str],
):
    dom = post(
        url,
        Formats.Reviews.build_body(
            app_id,
            sort,
            count,
            "null" if filter_score_with is None else filter_score_with,
            "null" if filter_device_with is None else filter_device_with,
            pagination_token,
        ),
        {"content-type": "application/x-www-form-urlencoded"},
    )
    match = json.loads(Regex.REVIEWS.findall(dom)[0])

    return json.loads(match[0][2])[0], json.loads(match[0][2])[-2][-1]


def reviews(
    app_id: str,
    lang: str = "en",
    country: str = "us",
    sort: Sort = Sort.MOST_RELEVANT,
    count: int = 100,
    filter_score_with: int = None,
    filter_device_with: int = None,
    continuation_token: _ContinuationToken = None,
) -> Tuple[List[dict], _ContinuationToken]:
    sort = sort.value

    if continuation_token is not None:
        token = continuation_token.token

        if token is None:
            return (
                [],
                continuation_token,
            )

        lang = continuation_token.lang
        country = continuation_token.country
        sort = continuation_token.sort
        count = continuation_token.count
        filter_score_with = continuation_token.filter_score_with
        filter_device_with = continuation_token.filter_device_with
    else:
        token = None

    url = Formats.Reviews.build(lang=lang, country=country)

    _fetch_count = count

    result = []

    while True:
        if _fetch_count == 0:
            break

        if _fetch_count > MAX_COUNT_EACH_FETCH:
            _fetch_count = MAX_COUNT_EACH_FETCH

        try:
            review_items, token = _fetch_review_items(
                url,
                app_id,
                sort,
                _fetch_count,
                filter_score_with,
                filter_device_with,
                token,
            )
        except (TypeError, IndexError):
            #funnan MOD start
            token = continuation_token.token
            continue
            #MOD end

        for review in review_items:
            result.append(
                {
                    k: spec.extract_content(review)
                    for k, spec in ElementSpecs.Review.items()
                }
            )

        _fetch_count = count - len(result)

        if isinstance(token, list):
            token = None
            break

    return (
        result,
        _ContinuationToken(
            token, lang, country, sort, count, filter_score_with, filter_device_with
        ),
    )


def reviews_all(app_id: str, sleep_milliseconds: int = 0, **kwargs) -> list:
    kwargs.pop("count", None)
    kwargs.pop("continuation_token", None)

    continuation_token = None

    result = []

    while True:
        _result, continuation_token = reviews(
            app_id,
            count=MAX_COUNT_EACH_FETCH,
            continuation_token=continuation_token,
            **kwargs
        )

        result += _result

        if continuation_token.token is None:
            break

        if sleep_milliseconds:
            sleep(sleep_milliseconds / 1000)

    return result

# %%
reviews_count = 10000

# %%
result = []
continuation_token = None


with tqdm(total=reviews_count, position=0, leave=True) as pbar:
    while len(result) < reviews_count:
        new_result, continuation_token = reviews(
            app_id,
            continuation_token=continuation_token,
            lang='id', #The language of review
            country='id', #Country for which you want to scrape
            sort=Sort.NEWEST,
            filter_score_with=None,
            count=199 #No need to change this
        )
        if not new_result:
            break
        result.extend(new_result)
        pbar.update(len(new_result))
# Out:
# 10149it [00:09, 1047.31it/s]

# %%
import numpy as np
df = pd.DataFrame(np.array(result),columns=['review'])

df = df.join(pd.DataFrame(df.pop('review').tolist()))

df.head()
# Out:
#                                reviewId           userName  \
# 0  6be275d9-9d29-42d3-a807-4ba33a618289    Suwarno Suwarno
# 1  f80086ea-6342-4d73-91d3-5a6f011b478b      WAHYU AMIJAYA
# 2  1e28c3f9-8a4a-4d70-b6c2-64f45b124a57          sri agung
# 3  8efe7503-235f-441c-bd5e-d67da2cfa30c  Setio Nggoro Wati
# 4  7e2a2f07-0db7-4c07-b625-bc504e13fd66     Prapti Lestari
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a-/ALV-U...
# 2  https://play-lh.googleusercontent.com/a-/ALV-U...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                              content  score  thumbsUpCount  \
# 0  Aplikasi mudah di hack, saya kena dgn pembelia...      1              0
# 1                                                top      5              0
# 2  1 dekade bersama BLIBLI. Terpercaya dan semaki...      5            123
# 3                                        is the best      5              0
# 4  Paling favorit untuk belanja elektronik online...      5              0
#
#   reviewCreatedVersion                  at  \
# 0               11.2.1 2024-06-14 15:44:33
# 1               11.2.1 2024-06-14 14:50:18
# 2               11.2.1 2024-06-14 13:56:20
# 3               11.2.1 2024-06-14 12:44:25
# 4                7.6.6 2024-06-14 12:34:29
#
#                                         replyContent           repliedAt  \
# 0  Halo kak Suwarno mohon maaf terkait Kendalanya... 2024-06-14 15:51:09
# 1  Halo kak Wahyu mantap! Makasih banyak buat rev... 2024-06-14 15:25:24
# 2  Yeay mantul banget kan kak sri belanja di Blib... 2021-01-08 16:39:12
# 3  Halo kak Setio Nggoro Wati mantap! Makasih ban... 2024-06-14 14:58:57
# 4  Halo kak Prapti Lestari mantap! Makasih banyak... 2024-06-14 15:01:02
#
#   appVersion
# 0     11.2.1
# 1     11.2.1
# 2     11.2.1
# 3     11.2.1
# 4      7.6.6

# %%
len(df)
# Out:
# 10149

# %%
df[['userName', 'score','at', 'content']].head()  #dari scrapping tsb didapatkan banyak sekali kolom, kemudian kolom" tsb kita filter
                                                        #sehingga didapatkan kolom username, score, at dan content
# Out:
#             userName  score                  at  \
# 0    Suwarno Suwarno      1 2024-06-14 15:44:33
# 1      WAHYU AMIJAYA      5 2024-06-14 14:50:18
# 2          sri agung      5 2024-06-14 13:56:20
# 3  Setio Nggoro Wati      5 2024-06-14 12:44:25
# 4     Prapti Lestari      5 2024-06-14 12:34:29
#
#                                              content
# 0  Aplikasi mudah di hack, saya kena dgn pembelia...
# 1                                                top
# 2  1 dekade bersama BLIBLI. Terpercaya dan semaki...
# 3                                        is the best
# 4  Paling favorit untuk belanja elektronik online...

# %%
df=df[['content', 'score']]#karena kita hanya membutuhkan kolom content dan score maka kita lakukan filter kolom lgi hing
df.head()
# Out:
#                                              content  score
# 0  Aplikasi mudah di hack, saya kena dgn pembelia...      1
# 1                                                top      5
# 2  1 dekade bersama BLIBLI. Terpercaya dan semaki...      5
# 3                                        is the best      5
# 4  Paling favorit untuk belanja elektronik online...      5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10149 entries, 0 to 10148
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  10149 non-null  object
#  1   score    10149 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 158.7+ KB

# %%
df.isna()
# Out:
#        content  score
# 0        False  False
# 1        False  False
# 2        False  False
# 3        False  False
# 4        False  False
# ...        ...    ...
# 10144    False  False
# 10145    False  False
# 10146    False  False
# 10147    False  False
# 10148    False  False
#
# [10149 rows x 2 columns]

# %%
df.describe()
# Out:
#               score
# count  10149.000000
# mean       3.922061
# std        1.644359
# min        1.000000
# 25%        3.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
df.isnull().sum()
# Out:
# content    0
# score      0
# dtype: int64

# %%
df.to_csv("hasil-scrap-blibli.csv", index = False) #simpan csv

# %% [markdown]
# # **PREPROCESSING**

# %% [markdown]
# Case Folding

# %%
import re
def  clean_text(df, text_field, new_text_field_name):
    df[new_text_field_name] = df[text_field].str.lower()
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    # remove numbers
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
    return df

# %%
df['text_clean'] = df['content'].str.lower()
df['text_clean']
data_clean = clean_text(df, 'content', 'text_clean')
data_clean.head(10)
# Out:
#                                              content  score  \
# 0  Aplikasi mudah di hack, saya kena dgn pembelia...      1
# 1                                                top      5
# 2  1 dekade bersama BLIBLI. Terpercaya dan semaki...      5
# 3                                        is the best      5
# 4  Paling favorit untuk belanja elektronik online...      5
# 5           sangat membantu memenuhi kebutuhan rumah      4
# 6  Sdh di instal ulang masih juga gak bisa di buk...      3
# 7                               semoga selalu sukses      4
# 8                          Semoga Blibli tambah maju      5
# 9                            Ngak suka aja pakainya.      1
#
#                                           text_clean
# 0  aplikasi mudah di hack saya kena dgn pembelian...
# 1                                                top
# 2   dekade bersama blibli terpercaya dan semakin ...
# 3                                        is the best
# 4  paling favorit untuk belanja elektronik online...
# 5           sangat membantu memenuhi kebutuhan rumah
# 6  sdh di instal ulang masih juga gak bisa di buk...
# 7                               semoga selalu sukses
# 8                          semoga blibli tambah maju
# 9                             ngak suka aja pakainya

# %% [markdown]
# Stopword Removal

# %%
import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('indonesian')
data_clean['text_StopWord'] = data_clean['text_clean'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop)]))
data_clean.head(50)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                               content  score  \
# 0   Aplikasi mudah di hack, saya kena dgn pembelia...      1
# 1                                                 top      5
# 2   1 dekade bersama BLIBLI. Terpercaya dan semaki...      5
# 3                                         is the best      5
# 4   Paling favorit untuk belanja elektronik online...      5
# 5            sangat membantu memenuhi kebutuhan rumah      4
# 6   Sdh di instal ulang masih juga gak bisa di buk...      3
# 7                                semoga selalu sukses      4
# 8                           Semoga Blibli tambah maju      5
# 9                             Ngak suka aja pakainya.      1
# 10  Tampilan aplikasinya membingungkan, kebanyakan...      2
# 11                                              bagus      5
# 12                                              delay      1
# 13  Maaf kk, skrg mau login di aplikasi gak bisa. ...      4
# 14  Bagus bagus! Semoga kedepannya Blibli tidak se...      5
# 15                                                 ok      5
# 16                                       Baru mencoba      5
# 17                                              Bagus      5
# 18                               ajhieb bin marqothop      5
# 19                              mantap sangat berguna      5
# 20                                              okehh      4
# 21                                             mantab      5
# 22  Makin gila aplikasi nya mau masuk aja ribet ka...      1
# 23  hmm bagus sekali ini aplikasi byk buanget isin...      5
# 24  Aplikasinya bagus simpel, mudah dioprasikan, d...      5
# 25          aplikasi yg sangat membantu bagus pokonya      5
# 26                                                TOP      5
# 27                                             mantul      5
# 28                                              bagus      5
# 29  Satu bintang buat Blibli karena beli barang ca...      1
# 30                                              cepat      5
# 31  10 tahun lebih saya sudah menjadi pengguna Bli...      1
# 32              Ok banget belanja pakai Blibli 🩷⭐⭐⭐⭐⭐      5
# 33  Sangat mudah untuk digunakan belanja on-line a...      5
# 34  Kenapa iklan muncul terus saat HP standby, mau...      1
# 35                                   santui dan kilat      5
# 36                                                 ok      5
# 37  Karena sdh lama pakai tokped dan berusaha mena...      5
# 38                              Mantap Dah Pokoknya 😙      5
# 39  Eh, juragan yang satu ini bener-bener dahsyat!...      5
# 40                      mantap belanja pertama sukses      5
# 41                                           mantaaap      5
# 42                                  mudah dan praktis      5
# 43                                                jos      5
# 44  Tampilan baru malah bikin ruwet buka aplikasi ...      1
# 45             Semoga membantu karena saya ini pemula      1
# 46                                               good      5
# 47  Pelayanan terbaik.. tak di ragukan lagi. Pesan...      5
# 48  Jelek. Cancel pesanan malah saldo masuk ke bil...      1
# 49                                                 ok      5
#
#                                            text_clean  \
# 0   aplikasi mudah di hack saya kena dgn pembelian...
# 1                                                 top
# 2    dekade bersama blibli terpercaya dan semakin ...
# 3                                         is the best
# 4   paling favorit untuk belanja elektronik online...
# 5            sangat membantu memenuhi kebutuhan rumah
# 6   sdh di instal ulang masih juga gak bisa di buk...
# 7                                semoga selalu sukses
# 8                           semoga blibli tambah maju
# 9                              ngak suka aja pakainya
# 10  tampilan aplikasinya membingungkan kebanyakan ...
# 11                                              bagus
# 12                                              delay
# 13  maaf kk skrg mau login di aplikasi gak bisa sa...
# 14  bagus bagus semoga kedepannya blibli tidak sep...
# 15                                                 ok
# 16                                       baru mencoba
# 17                                              bagus
# 18                               ajhieb bin marqothop
# 19                              mantap sangat berguna
# 20                                              okehh
# 21                                             mantab
# 22   makin gila aplikasi nya mau masuk aja ribet kali
# 23  hmm bagus sekali ini aplikasi byk buanget isin...
# 24  aplikasinya bagus simpel mudah dioprasikan dan...
# 25          aplikasi yg sangat membantu bagus pokonya
# 26                                                top
# 27                                             mantul
# 28                                              bagus
# 29  satu bintang buat blibli karena beli barang ca...
# 30                                              cepat
# 31   tahun lebih saya sudah menjadi pengguna blibl...
# 32                    ok banget belanja pakai blibli
# 33  sangat mudah untuk digunakan belanja online ap...
# 34  kenapa iklan muncul terus saat hp standby mau ...
# 35                                   santui dan kilat
# 36                                                 ok
# 37  karena sdh lama pakai tokped dan berusaha mena...
# 38                               mantap dah pokoknya
# 39  eh juragan yang satu ini benerbener dahsyat ba...
# 40                      mantap belanja pertama sukses
# 41                                           mantaaap
# 42                                  mudah dan praktis
# 43                                                jos
# 44  tampilan baru malah bikin ruwet buka aplikasi ...
# 45             semoga membantu karena saya ini pemula
# 46                                               good
# 47  pelayanan terbaik tak di ragukan lagi pesan dg...
# 48  jelek cancel pesanan malah saldo masuk ke bilp...
# 49                                                 ok
#
#                                         text_StopWord
# 0   aplikasi mudah hack kena dgn pembelian dicance...
# 1                                                 top
# 2   dekade blibli terpercaya terdepan pengiriman f...
# 3                                         is the best
# 4   favorit belanja elektronik online layanan ok b...
# 5                   membantu memenuhi kebutuhan rumah
# 6   sdh instal ulang gak buka aplikasinya tolong p...
# 7                                       semoga sukses
# 8                                  semoga blibli maju
# 9                              ngak suka aja pakainya
# 10  tampilan aplikasinya membingungkan kebanyakan ...
# 11                                              bagus
# 12                                              delay
# 13  maaf kk skrg login aplikasi gak diarahkan brow...
# 14  bagus bagus semoga kedepannya blibli shoppe gi...
# 15                                                 ok
# 16                                            mencoba
# 17                                              bagus
# 18                               ajhieb bin marqothop
# 19                                     mantap berguna
# 20                                              okehh
# 21                                             mantab
# 22             gila aplikasi nya masuk aja ribet kali
# 23  hmm bagus aplikasi byk buanget isinya murah mu...
# 24  aplikasinya bagus simpel mudah dioprasikan mud...
# 25                 aplikasi yg membantu bagus pokonya
# 26                                                top
# 27                                             mantul
# 28                                              bagus
# 29  bintang blibli beli barang cash kurir nya gak ...
# 30                                              cepat
# 31  pengguna blibli status platinum kecewa blibli ...
# 32                     ok banget belanja pakai blibli
# 33                        mudah belanja online apapun
# 34   iklan muncul hp standby telp tulis wa mengganggu
# 35                                       santui kilat
# 36                                                 ok
# 37  sdh pakai tokped berusaha menaikan levelberat ...
# 38                                mantap dah pokoknya
# 39  eh juragan benerbener dahsyat barang dijualnya...
# 40                              mantap belanja sukses
# 41                                           mantaaap
# 42                                      mudah praktis
# 43                                                jos
# 44  tampilan bikin ruwet buka aplikasi bertele gak...
# 45                             semoga membantu pemula
# 46                                               good
# 47  pelayanan terbaik ragukan pesan dgn nominal sm...
# 48  jelek cancel pesanan saldo masuk bilpay udh gi...
# 49                                                 ok

# %% [markdown]
# **Tokenizing**

# %%
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
data_clean['text_tokens'] = data_clean['text_StopWord'].apply(lambda x: word_tokenize(x))
data_clean.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                              content  score  \
# 0  Aplikasi mudah di hack, saya kena dgn pembelia...      1
# 1                                                top      5
# 2  1 dekade bersama BLIBLI. Terpercaya dan semaki...      5
# 3                                        is the best      5
# 4  Paling favorit untuk belanja elektronik online...      5
#
#                                           text_clean  \
# 0  aplikasi mudah di hack saya kena dgn pembelian...
# 1                                                top
# 2   dekade bersama blibli terpercaya dan semakin ...
# 3                                        is the best
# 4  paling favorit untuk belanja elektronik online...
#
#                                        text_StopWord  \
# 0  aplikasi mudah hack kena dgn pembelian dicance...
# 1                                                top
# 2  dekade blibli terpercaya terdepan pengiriman f...
# 3                                        is the best
# 4  favorit belanja elektronik online layanan ok b...
#
#                                          text_tokens
# 0  [aplikasi, mudah, hack, kena, dgn, pembelian, ...
# 1                                              [top]
# 2  [dekade, blibli, terpercaya, terdepan, pengiri...
# 3                                    [is, the, best]
# 4  [favorit, belanja, elektronik, online, layanan...

# %% [markdown]
# **Stemming**

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 3.5 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
#-----------------STEMMING -----------------
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
#import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}
hitung=0

for document in data_clean['text_tokens']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")
for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    hitung+=1
    print(hitung,":",term,":" ,term_dict[term])

print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]


#script ini bisa dipisah dari eksekusinya setelah pembacaaan term selesai
data_clean['text_steamindo'] = data_clean['text_tokens'].apply(lambda x:' '.join(get_stemmed_term(x)))
data_clean.head(20)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# 4325 : diekse : diekse
# 4326 : kusinya : kus
# 4327 : mantapcara : mantapcara
# 4328 : bertransaksiy : bertransaksiy
# 4329 : pakek : pakek
# 4330 : inibarangnya : inibarangnya
# 4331 : kualitasnya : kualitas
# 4332 : pkonya : pkonya
# 4333 : bangget : bangget
# 4334 : investor : investor
# 4335 : originalitas : originalitas
# 4336 : buktiin : buktiin
# 4337 : kembangin : kembangin
# 4338 : pembaruan : baru
# 4339 : ribetdan : ribetdan
# 4340 : burukpengiriman : burukpengiriman
# 4341 : molorfitur : molorfitur
# 4342 : aplikasirendahmbeda : aplikasirendahmbeda
# 4343 : inisebagai : inisebagai
# 4344 : dirugikantidak : dirugikantidak
# 4345 : selayaknya : layak
# 4346 : lainyg : lainyg
# 4347 : efisienjangan : efisienjangan
# 4348 : salahkan : salah
# 4349 : forever : forever
# 4350 : cepatblibli : cepatblibli
# 4351 : okl : okl
# 4352 : promonyaaa : promonyaaa
# 4353 : makasii : makasii
# 4354 : bisanya : bisa
# 4355 : diurut : urut
# 4356 : disusun : susun
# 4357 : loss : loss
# 4358 : doll : doll
# 4359 : manage : manage
# 4360 : picture : picture
# 4361 : bida : bida
# 4362 : nyicil : nyicil
# 4363 : milih : milih
# 4364 : lemottttttttttttt : lemottttttttttttt
# 4365 : maaaantaap : maaaantaap
# 4366 : sangaat : sangaat
# 4367 : serubanyakin : serubanyakin
# 4368 : scor : scor
# 4369 : hundred : hundred
# 4370 : anti : anti
# 4371 : tampilanya : tampilanya
# 4372 : nyobaaja : nyobaaja
# 4373 : bravo : bravo
# 4374 : quiz : quiz
# 4375 : mantaaaabb : mantaaaabb
# 4376 : gundam : gundam
# 4377 : leter : leter
# 4378 : goodjob : goodjob
# 4379 : referal : referal
# 4380 : nomernya : nomernya
# 4381 : lancarkan : lancar
# 4382 : tiktoknya : tiktoknya
# 4383 : januardigeboy : januardigeboy
# 4384 : besarnya : besar
# 4385 : bersihkan : sih
# 4386 : tida : tida
# 4387 : permudah : mudah
# 4388 : jelekpantas : jelekpantas
# 4389 : msih : msih
# 4390 : percobaan : coba
# 4391 : waalaikumussalaam : waalaikumussalaam
# 4392 : nbb : nbb
# 4393 : jb : jb
# 4394 : ffff : ffff
# 4395 : berbagi : bagi
# 4396 : belaja : baja
# 4397 : okeeeeeeee : okeeeeeeee
# 4398 : pemakaianya : pemakaianya
# 4399 : vyy : vyy
# 4400 : mymjjyk : mymjjyk
# 4401 : cc : cc
# 4402 : yamaha : yamaha
# 4403 : smpi : smpi
# 4404 : memahami : paham
# 4405 : maklum : maklum
# 4406 : muda : muda
# 4407 : mksih : mksih
# 4408 : raq : raq
# 4409 : katalog : katalog
# 4410 : susa : susa
# 4411 : expedisi : expedisi
# 4412 : andai : andai
# 4413 : id : id
# 4414 : hmpr : hmpr
# 4415 : bln : bln
# 4416 : pmbyrn : pmbyrn
# 4417 : jwbn : jwbn
# 4418 : copas : copas
# 4419 : cncle : cncle
# 4420 : blg : blg
# 4421 : knpa : knpa
# 4422 : bnr : bnr
# 4423 : logout : logout
# 4424 : mnta : mnta
# 4425 : sndiri : sndiri
# 4426 : gunanya : guna
# 4427 : hoak : hoak
# 4428 : keuangan : uang
# 4429 : oksemoga : oksemoga
# 4430 : menyediakan : sedia
# 4431 : antarmuka : antarmuka
# 4432 : menawarkan : tawar
# 4433 : hoaxttp : hoaxttp
# 4434 : pembelilangkah : bilang
# 4435 : kurng : kurng
# 4436 : trhdp : trhdp
# 4437 : seakan : akan
# 4438 : pelihara : pelihara
# 4439 : komsumen : komsumen
# 4440 : ditawarkan : tawar
# 4441 : wwconm : wwconm
# 4442 : moktar : moktar
# 4443 : harag : harag
# 4444 : sekitat : sekitat
# 4445 : jangka : jangka
# 4446 : mudahmurahmengasikanbarange : mudahmurahmengasikanbarange
# 4447 : berukuran : ukur
# 4448 : jumbo : jumbo
# 4449 : josssss : josssss
# 4450 : pop : pop
# 4451 : abaikan : abai
# 4452 : pengambilan : ambil
# 4453 : iklasin : iklasin
# 4454 : okproses : okproses
# 4455 : cepattks : cepattks
# 4456 : ngetop : ngetop
# 4457 : chet : chet
# 4458 : harusssss : harusssss
# 4459 : sinyalya : sinyalya
# 4460 : kua : kua
# 4461 : mental : mental
# 4462 : branda : branda
# 4463 : dapahal : dapahal
# 4464 : gedex : gedex
# 4465 : penggunanan : penggunanan
# 4466 : pembodohan : bodoh
# 4467 : bertentangan : tentang
# 4468 : teori : teori
# 4469 : peluang : peluang
# 4470 : mantapl : mantapl
# 4471 : kgk : kgk
# 4472 : byar : byar
# 4473 : sopi : sopi
# 4474 : oce : oce
# 4475 : skg : skg
# 4476 : vc : vc
# 4477 : tmplan : tmplan
# 4478 : tipuuuu : tipuuuu
# 4479 : ii : ii
# 4480 : nyambung : nyambung
# 4481 : brimantul : brimantul
# 4482 : ddrrf : ddrrf
# 4483 : yoo : yoo
# 4484 : reeee : reeee
# 4485 : goooddd : goooddd
# 4486 : pamer : pamer
# 4487 : knapa : knapa
# 4488 : cuekin : cuekin
# 4489 : ehhh : ehhh
# 4490 : etdah : etdah
# 4491 : autounistal : autounistal
# 4492 : ngiklannya : ngiklannya
# 4493 : perasaan : asa
# 4494 : youtube : youtube
# 4495 : semogha : semogha
# 4496 : disemua : semua
# 4497 : poto : poto
# 4498 : sebagainyamalah : sebagainyamalah
# 4499 : tolaksemoga : tolaksemoga
# 4500 : pisah : pisah
# 4501 : padat : padat
# 4502 : sajabli : sajabli
# 4503 : trap : trap
# 4504 : bertahuntahun : bertahuntahun
# 4505 : vakum : vakum
# 4506 : seringsering : seringsering
# 4507 : lari : lari
# 4508 : kaliansudah : kaliansudah
# 4509 : batakan : bata
# 4510 : evoucher : evoucher
# 4511 : budaya : budaya
# 4512 : oktober : oktober
# 4513 : wib : wib
# 4514 : disalah : salah
# 4515 : trbaik : trbaik
# 4516 : pelyann : pelyann
# 4517 : merekomendasikan : rekomendasi
# 4518 : seandainya : anda
# 4519 : payletter : payletter
# 4520 : markotopp : markotopp
# 4521 : teruskan : terus
# 4522 : aplilasi : aplilasi
# 4523 : slop : slop
# 4524 : buti : buti
# 4525 : peserta : serta
# 4526 : bpjstk : bpjstk
# 4527 : thebest : thebest
# 4528 : click : click
# 4529 : colectsemoga : colectsemoga
# 4530 : sekomplit : sekomplit
# 4531 : sesimpel : simpel
# 4532 : tik : tik
# 4533 : tok : tok
# 4534 : maintenance : maintenance
# 4535 : servernya : servernya
# 4536 : bufering : bufering
# 4537 : buffering : buffering
# 4538 : paxel : paxel
# 4539 : kiriman : kirim
# 4540 : grab : grab
# 4541 : soldout : soldout
# 4542 : usahain : usahain
# 4543 : wkwkwkkw : wkwkwkkw
# 4544 : oktpi : oktpi
# 4545 : pembaharuanterutama : pembaharuanterutama
# 4546 : refun : refun
# 4547 : yakecewa : yakecewa
# 4548 : tbk : tbk
# 4549 : iponya : iponya
# 4550 : premiun : premiun
# 4551 : mangstab : mangstab
# 4552 : freeong : freeong
# 4553 : casjback : casjback
# 4554 : warehouse : warehouse
# 4555 : regional : regional
# 4556 : kehabisan : habis
# 4557 : vouchee : vouchee
# 4558 : muraaahh : muraaahh
# 4559 : bliblimoga : bliblimoga
# 4560 : tjakeup : tjakeup
# 4561 : manfaat : manfaat
# 4562 : ajapengajuan : ajapengajuan
# 4563 : op : op
# 4564 : laahhh : laahhh
# 4565 : mogamoga : mogamoga
# 4566 : cuannn : cuannn
# 4567 : amatpas : amatpas
# 4568 : sesi : sesi
# 4569 : vidio : vidio
# 4570 : terangkalo : terangkalo
# 4571 : persulittinggal : persulittinggal
# 4572 : lolosin : lolosin
# 4573 : iyaaaa : iyaaaa
# 4574 : buggg : buggg
# 4575 : menentukan : tentu
# 4576 : tergantikan : ganti
# 4577 : lainbukan : lainbukan
# 4578 : tuju : tuju
# 4579 : sekalii : sekali
# 4580 : seisi : isi
# 4581 : rumahku : rumah
# 4582 : surantab : surantab
# 4583 : bray : bray
# 4584 : insyaa : insyaa
# 4585 : alloh : alloh
# 4586 : dihpus : dihpus
# 4587 : takutnya : takut
# 4588 : semudah : mudah
# 4589 : ngentt : ngentt
# 4590 : siiiip : siiiip
# 4591 : paylayer : paylayer
# 4592 : mantaaabs : mantaaabs
# 4593 : betuuul : betuuul
# 4594 : disin : sin
# 4595 : berlimpah : limpah
# 4596 : diaplikasi : aplikasi
# 4597 : ats : ats
# 4598 : kosongdi : kosongdi
# 4599 : bisaakamper : bisaakamper
# 4600 : gombal : gombal
# 4601 : kenyataannya : nyata
# 4602 : leletbeberapa : leletbeberapa
# 4603 : orderanpernah : orderanpernah
# 4604 : kosongsedangkan : kosongsedangkan
# 4605 : trucking : trucking
# 4606 : sep : sep
# 4607 : stuk : stuk
# 4608 : muaantab : muaantab
# 4609 : mantuul : mantuul
# 4610 : platfrom : platfrom
# 4611 : murahan : murah
# 4612 : aliyas : aliyas
# 4613 : ditempattolong : ditempattolong
# 4614 : aturan : atur
# 4615 : itudan : itudan
# 4616 : opo : opo
# 4617 : vhh : vhh
# 4618 : menemukan : temu
# 4619 : tk : tk
# 4620 : brmasalah : brmasalah
# 4621 : berbicars : berbicars
# 4622 : softcase : softcase
# 4623 : dibawah : bawah
# 4624 : paka : paka
# 4625 : history : history
# 4626 : dancok : dancok
# 4627 : turun : turun
# 4628 : reccomended : reccomended
# 4629 : sptnya : sptnya
# 4630 : kesebelah : belah
# 4631 : dl : dl
# 4632 : pengecekan : kece
# 4633 : counter : counter
# 4634 : unit : unit
# 4635 : mentang : mentang
# 4636 : ojek : ojek
# 4637 : kai : kai
# 4638 : expo : expo
# 4639 : lancat : lancat
# 4640 : rugiin : rugiin
# 4641 : ajaib : ajaib
# 4642 : sanin : sanin
# 4643 : dobel : dobel
# 4644 : cumak : cumak
# 4645 : lengkapnya : lengkap
# 4646 : partner : partner
# 4647 : shopedan : shopedan
# 4648 : ji : ji
# 4649 : cp : cp
# 4650 : tampilih : tampilih
# 4651 : jelastlp : jelastlp
# 4652 : apapundan : apapundan
# 4653 : apapuntrus : apapuntrus
# 4654 : tangguhkansaya : tangguhkansaya
# 4655 : sekaljelek : sekaljelek
# 4656 : byrtolong : byrtolong
# 4657 : kaliansaya : kaliansaya
# 4658 : sanggat : sanggat
# 4659 : merugikandi : merugikandi
# 4660 : membodoh : bodoh
# 4661 : bodohi : bodoh
# 4662 : orangsangat : orangsangat
# 4663 : akurat : akurat
# 4664 : cansel : cansel
# 4665 : eneg : eneg
# 4666 : feel : feel
# 4667 : sni : sni
# 4668 : wowokwowowkkwwo : wowokwowowkkwwo
# 4669 : bisi : bis
# 4670 : mudahsimple : mudahsimple
# 4671 : pelopor : pelopor
# 4672 : sealu : alu
# 4673 : pesanantapi : pesanantapi
# 4674 : terussudah : terussudah
# 4675 : kooperatif : kooperatif
# 4676 : ribetcoba : ribetcoba
# 4677 : wamalah : wamalah
# 4678 : jawabparaaaahhh : jawabparaaaahhh
# 4679 : tanmpa : tanmpa
# 4680 : gelapan : gelap
# 4681 : sebelumnyatp : sebelumnyatp
# 4682 : iseng : iseng
# 4683 : hptp : hptp
# 4684 : lainkok : lainkok
# 4685 : yasoalnya : yasoalnya
# 4686 : benefitnya : benefitnya
# 4687 : mantappppp : mantappppp
# 4688 : tkasih : tkasih
# 4689 : melewati : lewat
# 4690 : waterbom : waterbom
# 4691 : liburan : libur
# 4692 : tiketnya : tiket
# 4693 : konyol : konyol
# 4694 : sex : sex
# 4695 : bersangkutanterjadi : bersangkutanterjadi
# 4696 : coklat : coklat
# 4697 : gagalmau : gagalmau
# 4698 : mix : mix
# 4699 : vegetable : vegetable
# 4700 : gagalsetelah : gagalsetelah
# 4701 : mengisi : isi
# 4702 : kartukrn : kartukrn
# 4703 : tua : tua
# 4704 : munculnya : muncul
# 4705 : blank : blank
# 4706 : putihlama : putihlama
# 4707 : berubahpadahal : berubahpadahal
# 4708 : berhasillalu : berhasillalu
# 4709 : penerbit : terbit
# 4710 : kartupdhl : kartupdhl
# 4711 : kondite : kondite
# 4712 : lancarkarena : lancarkarena
# 4713 : bgitu : bgitu
# 4714 : mk : mk
# 4715 : tinggalin : tinggalin
# 4716 : initransaksi : initransaksi
# 4717 : cob : cob
# 4718 : lekas : lekas
# 4719 : ditujuan : tuju
# 4720 : gpo : gpo
# 4721 : mantaab : mantaab
# 4722 : kereeeen : kereeeen
# 4723 : cakepppawalnya : cakepppawalnya
# 4724 : mudahn : mudahn
# 4725 : mengorbankan : korban
# 4726 : gulung : gulung
# 4727 : tikar : tikar
# 4728 : apkbye : apkbye
# 4729 : wwww : wwww
# 4730 : aa : aa
# 4731 : wwa : wwa
# 4732 : bermaindlm : bermaindlm
# 4733 : diguanakan : diguanakan
# 4734 : peracaya : peracaya
# 4735 : pemgiriman : pemgiriman
# 4736 : cepattt : cepattt
# 4737 : habisjanjiin : habisjanjiin
# 4738 : emas : emas
# 4739 : mustahil : mustahil
# 4740 : dapatkan : dapat
# 4741 : orens : orens
# 4742 : bbrapa : bbrapa
# 4743 : dimohon : mohon
# 4744 : dievaluasi : evaluasi
# 4745 : rewar : rewar
# 4746 : lengkaptolong : lengkaptolong
# 4747 : perbaikin : perbaikin
# 4748 : jaringn : jaringn
# 4749 : fan : fan
# 4750 : iyes : iyes
# 4751 : aamiiin : aamiiin
# 4752 : aamin : aamin
# 4753 : jelekpantesan : jelekpantesan
# 4754 : cancle : cancle
# 4755 : etalase : etalase
# 4756 : alhasil : alhasil
# 4757 : kedaftar : daftar
# 4758 : tertaut : taut
# 4759 : pulak : pulak
# 4760 : ketahan : tahan
# 4761 : hadeuuh : hadeuuh
# 4762 : whhwhw : whhwhw
# 4763 : mantabz : mantabz
# 4764 : apes : apes
# 4765 : dahh : dahh
# 4766 : blipaypea : blipaypea
# 4767 : systemnya : systemnya
# 4768 : kejeblos : jeblos
# 4769 : denda : denda
# 4770 : mahh : mahh
# 4771 : bayartelkom : bayartelkom
# 4772 : ungu : ungu
# 4773 : musa : musa
# 4774 : ashasri : ashasri
# 4775 : putus : putus
# 4776 : kontrak : kontrak
# 4777 : spamnya : spamnya
# 4778 : mantaapppp : mantaapppp
# 4779 : nyayang : nyayang
# 4780 : dapatkandengan : dapatkandengan
# 4781 : mudahkan : mudah
# 4782 : wasalam : wasalam
# 4783 : refrun : refrun
# 4784 : pengembaliab : pengembaliab
# 4785 : dh : dh
# 4786 : lacak : lacak
# 4787 : pickup : pickup
# 4788 : lunas : lunas
# 4789 : curi : curi
# 4790 : miskin : miskin
# 4791 : samsung : samsung
# 4792 : seach : seach
# 4793 : kereen : kereen
# 4794 : gooood : gooood
# 4795 : kalaw : kalaw
# 4796 : issue : issue
# 4797 : yeay : yeay
# 4798 : midah : midah
# 4799 : pakaigak : pakaigak
# 4800 : kecamatan : camat
# 4801 : kutawaringin : kutawaringin
# 4802 : nyapadahal : nyapadahal
# 4803 : orenhijau : orenhijau
# 4804 : navy : navy
# 4805 : enggaktolong : enggaktolong
# 4806 : daget : daget
# 4807 : balnja : balnja
# 4808 : bliblimurahcptpuas : bliblimurahcptpuas
# 4809 : efisien : efisien
# 4810 : mantullll : mantullll
# 4811 : alikasi : alikasi
# 4812 : lalod : lalod
# 4813 : xxxl : xxxl
# 4814 : orxxx : orxxx
# 4815 : protektif : protektif
# 4816 : samping : samping
# 4817 : baruny : baruny
# 4818 : trdaftar : trdaftar
# 4819 : badjingan : badjingan
# 4820 : bnget : bnget
# 4821 : dinaiki : naik
# 4822 : maks : maks
# 4823 : kembaliiiiiiiiii : kembaliiiiiiiiii
# 4824 : teribet : teribet
# 4825 : kudu : kudu
# 4826 : dllbikin : dllbikin
# 4827 : antian : anti
# 4828 : konser : konser
# 4829 : gunankan : gunankan
# 4830 : pengembangan : kembang
# 4831 : mengulang : ulang
# 4832 : akalakalan : akalakalan
# 4833 : ditengah : tengah
# 4834 : kepepet : pepet
# 4835 : gandos : gandos
# 4836 : gosend : gosend
# 4837 : bruk : bruk
# 4838 : obrok : obrok
# 4839 : ursa : ursa
# 4840 : nano : nano
# 4841 : broo : broo
# 4842 : hargasory : hargasory
# 4843 : jajahi : jajah
# 4844 : ajeng : ajeng
# 4845 : ber : ber
# 4846 : operasi : operasi
# 4847 : biarin : biarin
# 4848 : dsni : dsni
# 4849 : memebantu : bantu
# 4850 : mantapsss : mantapsss
# 4851 : rma : rma
# 4852 : pencuri : curi
# 4853 : ditulis : tulis
# 4854 : mengerjai : kerja
# 4855 : jempol : jempol
# 4856 : geuud : geuud
# 4857 : qstilgoogle : qstilgoogle
# 4858 : apaaansi : apaaansi
# 4859 : kredibel : kredibel
# 4860 : kemudahannya : mudah
# 4861 : layananternyata : layananternyata
# 4862 : sesimple : sesimple
# 4863 : cicil : cicil
# 4864 : bulanny : bulanny
# 4865 : gedein : gedein
# 4866 : penggunannya : gun
# 4867 : dibliblisangat : dibliblisangat
# 4868 : bpkku : bpkku
# 4869 : pengajian : aji
# 4870 : gadget : gadget
# 4871 : bergaransi : garansi
# 4872 : apoko : apoko
# 4873 : desktop : desktop
# 4874 : ditanggapi : tanggap
# 4875 : aplikaai : aplikaai
# 4876 : diblokir : blokir
# 4877 : nan : nan
# 4878 : berbuat : buat
# 4879 : nyatahanya : nyatahanya
# 4880 : rumahnya : rumah
# 4881 : orangnya : orang
# 4882 : mantapppppppppppp : mantapppppppppppp
# 4883 : pollll : pollll
# 4884 : mayang : mayang
# 4885 : sangaterbaik : sangaterbaik
# 4886 : minigame : minigame
# 4887 : tante : tante
# 4888 : bekukan : beku
# 4889 : belanjaan : belanja
# 4890 : bagusbarang : bagusbarang
# 4891 : originalmantapppppp : originalmantapppppp
# 4892 : mamtap : mamtap
# 4893 : skli : skli
# 4894 : play : play
# 4895 : of : of
# 4896 : jelasyang : jelasyang
# 4897 : kebutuhandi : kebutuhandi
# 4898 : ketik : ketik
# 4899 : puassssss : puassssss
# 4900 : micro : micro
# 4901 : evo : evo
# 4902 : gb : gb
# 4903 : wallet : wallet
# 4904 : dibanned : dibanned
# 4905 : hellooo : hellooo
# 4906 : gilak : gilak
# 4907 : kelen : kelen
# 4908 : molor : molor
# 4909 : mantaaaaaaaaps : mantaaaaaaaaps
# 4910 : nyaampe : nyaampe
# 4911 : kelarnyimpen : kelarnyimpen
# 4912 : debit : debit
# 4913 : dulubeda : dulubeda
# 4914 : hijau : hijau
# 4915 : seribet : seribet
# 4916 : beranda : beranda
# 4917 : rehat : rehat
# 4918 : dikirain : dikirain
# 4919 : diadakan : ada
# 4920 : kecewasih : kecewasih
# 4921 : oribisa : oribisa
# 4922 : terjaga : jaga
# 4923 : utara : utara
# 4924 : tangerang : tangerang
# 4925 : niceeee : niceeee
# 4926 : slahnya : slah
# 4927 : pppl : pppl
# 4928 : ppp : ppp
# 4929 : ppl : ppl
# 4930 : bbra : bbra
# 4931 : ws : ws
# 4932 : era : era
# 4933 : reformasi : reformasi
# 4934 : edin : edin
# 4935 : start : start
# 4936 : eiffel : eiffel
# 4937 : zsexxd : zsexxd
# 4938 : sj : sj
# 4939 : bh : bh
# 4940 : ri : ri
# 4941 : bbvxxd : bbvxxd
# 4942 : ijbbgx : ijbbgx
# 4943 : gerti : gerti
# 4944 : berjaya : jaya
# 4945 : customerblibli : customerblibli
# 4946 : alhmdllh : alhmdllh
# 4947 : bakar : bakar
# 4948 : saham : saham
# 4949 : konsumsi : konsumsi
# 4950 : yng : yng
# 4951 : apresiasi : apresiasi
# 4952 : pk : pk
# 4953 : hargain : hargain
# 4954 : jutad : jutad
# 4955 : terimah : terimah
# 4956 : belanjasering : belanjasering
# 4957 : lagiterimakasih : lagiterimakasih
# 4958 : nani : nan
# 4959 : ninja : ninja
# 4960 : express : express
# 4961 : bersholawat : bersholawat
# 4962 : nabi : nabi
# 4963 : walliyulloh : walliyulloh
# 4964 : nagri : nagri
# 4965 : terlanjut : lanjut
# 4966 : payleternya : payleternya
# 4967 : kantong : kantong
# 4968 : mantaaaaap : mantaaaaap
# 4969 : keereeennn : keereeennn
# 4970 : kangennya : kangen
# 4971 : takjub : takjub
# 4972 : pengirimannyagood : pengirimannyagood
# 4973 : bernilai : nila
# 4974 : residu : residu
# 4975 : survive : survive
# 4976 : apknyajangan : apknyajangan
# 4977 : kaku : kaku
# 4978 : kerrnnnn : kerrnnnn
# 4979 : narang : narang
# 4980 : tq : tq
# 4981 : truskan : truskan
# 4982 : potensial : potensial
# 4983 : telanjur : telanjur
# 4984 : barangnyaapakah : barangnyaapakah
# 4985 : ckup : ckup
# 4986 : mantapkeren : mantapkeren
# 4987 : begus : begus
# 4988 : msuk : msuk
# 4989 : blan : blan
# 4990 : september : september
# 4991 : potongkirnya : potongkirnya
# 4992 : dikurangi : rang
# 4993 : maksk : maksk
# 4994 : mink : mink
# 4995 : terkecil : kecil
# 4996 : rada : rada
# 4997 : dilayani : layan
# 4998 : kary : kary
# 4999 : pria : pria
# 5000 : ditawari : tawar
# 5001 : chargernya : chargernya
# 5002 : koq : koq
# 5003 : karyawannya : karyawannya
# 5004 : charger : charger
# 5005 : kepikiran : pikir
# 5006 : dikasi : kasi
# 5007 : ngecek : ngecek
# 5008 : fisik : fisik
# 5009 : palsunya : palsu
# 5010 : young : young
# 5011 : ris : ris
# 5012 : downloads : downloads
# 5013 : performa : performa
# 5014 : pahit : pahit
# 5015 : dulunya : dulunya
# 5016 : diskoncashback : diskoncashback
# 5017 : pahiiittt : pahiiittt
# 5018 : apksoalny : apksoalny
# 5019 : namany : namany
# 5020 : hrusny : hrusny
# 5021 : donggua : donggua
# 5022 : niatny : niatny
# 5023 : lcddi : lcddi
# 5024 : sbelah : sbelah
# 5025 : shopelazada : shopelazada
# 5026 : klha : klha
# 5027 : hrapan : hrapan
# 5028 : hrgany : hrgany
# 5029 : murahbgitu : murahbgitu
# 5030 : kpaling : kpaling
# 5031 : nyri : nyri
# 5032 : jamemg : jamemg
# 5033 : akuin : akuin
# 5034 : dftar : dftar
# 5035 : bnyktpi : bnyktpi
# 5036 : gliran : gliran
# 5037 : dipkega : dipkega
# 5038 : dipkeyg : dipkeyg
# 5039 : ngsih : ngsih
# 5040 : tololtrlalu : tololtrlalu
# 5041 : egoisudh : egoisudh
# 5042 : mahalga : mahalga
# 5043 : dagangga : dagangga
# 5044 : memikirkan : pikir
# 5045 : pelanggandasar : pelanggandasar
# 5046 : perampokan : ampo
# 5047 : neh : neh
# 5048 : aplikasilebih : aplikasilebih
# 5049 : pelayananya : pelayananya
# 5050 : mi : mi
# 5051 : nn : nn
# 5052 : ibuuu : ibuuu
# 5053 : we : we
# 5054 : bc : bc
# 5055 : senilai : nila
# 5056 : pesanannya : pesan
# 5057 : codya : codya
# 5058 : dikampung : kampung
# 5059 : dikirimmaka : dikirimmaka
# 5060 : bula : bula
# 5061 : kkatau : kkatau
# 5062 : promokaya : promokaya
# 5063 : bliblisukses : bliblisukses
# 5064 : truuss : truuss
# 5065 : hadehhhvoucher : hadehhhvoucher
# 5066 : medit : medit
# 5067 : loyalti : loyalti
# 5068 : gift : gift
# 5069 : bday : bday
# 5070 : dihilangkan : hilang
# 5071 : brtahun : brtahun
# 5072 : mp : mp
# 5073 : rumitmisal : rumitmisal
# 5074 : walletini : walletini
# 5075 : kelemahan : lemah
# 5076 : mancing : mancing
# 5077 : mania : mania
# 5078 : packaging : packaging
# 5079 : resepsionis : resepsionis
# 5080 : penipuann : penipuann
# 5081 : bertahan : tahan
# 5082 : maybe : maybe
# 5083 : kompetitif : kompetitif
# 5084 : tenyata : tenyata
# 5085 : sanga : sanga
# 5086 : mendesak : desak
# 5087 : ngatipin : ngatipin
# 5088 : plater : plater
# 5089 : jeleksellernya : jeleksellernya
# 5090 : pembelisudah : pembelisudah
# 5091 : alamitolong : alamitolong
# 5092 : penalti : penalti
# 5093 : pembelijadi : pembelijadi
# 5094 : bliblisellernya : bliblisellernya
# 5095 : pnah : pnah
# 5096 : belibtp : belibtp
# 5097 : brgnya : brgnya
# 5098 : dikirimkan : kirim
# 5099 : menggiurkan : giur
# 5100 : berating : berating
# 5101 : atawa : atawa
# 5102 : tahunan : tahun
# 5103 : berumur : umur
# 5104 : baguscuman : baguscuman
# 5105 : berkwalitas : berkwalitas
# 5106 : puaas : puaas
# 5107 : cimb : cimb
# 5108 : niaga : niaga
# 5109 : smenjak : smenjak
# 5110 : sukasaya : sukasaya
# 5111 : sebelahnya : belah
# 5112 : ja : ja
# 5113 : sebela : bela
# 5114 : perdana : perdana
# 5115 : al : al
# 5116 : bangetkirim : bangetkirim
# 5117 : nyaloading : nyaloading
# 5118 : dasar : dasar
# 5119 : becusaplikasi : becusaplikasi
# 5120 : tololtolol : tololtolol
# 5121 : sayangga : sayangga
# 5122 : berminat : minat
# 5123 : wahsenangnya : wahsenangnya
# 5124 : bgetkereen : bgetkereen
# 5125 : sensitif : sensitif
# 5126 : liquid : liquid
# 5127 : dipikirnya : pikir
# 5128 : berkaitan : kait
# 5129 : agustus : agustus
# 5130 : dihapuss : dihapuss
# 5131 : joba : joba
# 5132 : ahhh : ahhh
# 5133 : mantulsippokmen : mantulsippokmen
# 5134 : recommendedgood : recommendedgood
# 5135 : baikk : baikk
# 5136 : animasinya : animasi
# 5137 : litenya : litenya
# 5138 : keluaran : keluar
# 5139 : ram : ram
# 5140 : penyimpanan : simpan
# 5141 : force : force
# 5142 : tinggaldmn : tinggaldmn
# 5143 : disepong : disepong
# 5144 : gakutsuasananyasepertidiatasawan : gakutsuasananyasepertidiatasawan
# 5145 : manap : manap
# 5146 : dipelajari : ajar
# 5147 : huk : huk
# 5148 : kantor : kantor
# 5149 : ngetik : ngetik
# 5150 : kantornya : kantor
# 5151 : diketik : ketik
# 5152 : aouto : aouto
# 5153 : ajalah : aja
# 5154 : bhkn : bhkn
# 5155 : dunk : dunk
# 5156 : srbelah : srbelah
# 5157 : bih : bih
# 5158 : fashion : fashion
# 5159 : future : future
# 5160 : feat : feat
# 5161 : menutut : tutut
# 5162 : emsil : emsil
# 5163 : kalao : kalao
# 5164 : nggk : nggk
# 5165 : mzh : mzh
# 5166 : bnyaksungguh : bnyaksungguh
# 5167 : mengecewakanketerangannya : mengecewakanketerangannya
# 5168 : aktifsdangkan : aktifsdangkan
# 5169 : septemberpelayanan : septemberpelayanan
# 5170 : dinyala : nyala
# 5171 : dibangunkan : bangun
# 5172 : scroll : scroll
# 5173 : cut : cut
# 5174 : launching : launching
# 5175 : keunggulan : unggul
# 5176 : mndesak : mndesak
# 5177 : cocoknya : cocok
# 5178 : gantinama : gantinama
# 5179 : umk : umk
# 5180 : jawa : jawa
# 5181 : menanggung : tanggung
# 5182 : dibalik : balik
# 5183 : brani : brani
# 5184 : combo : combo
# 5185 : colab : colab
# 5186 : goto : goto
# 5187 : serakah : serakah
# 5188 : hilangkan : hilang
# 5189 : calo : calo
# 5190 : penurunan : turun
# 5191 : introspeksi : introspeksi
# 5192 : mengobati : obat
# 5193 : mencegahfatal : mencegahfatal
# 5194 : rejeki : rejeki
# 5195 : kluarga : kluarga
# 5196 : palinng : palinng
# 5197 : hubungu : hubungu
# 5198 : taiiiiiii : taiiiiiii
# 5199 : mengelola : kelola
# 5200 : finance : finance
# 5201 : tuwa : tuwa
# 5202 : bisskyu : bisskyu
# 5203 : bui : bui
# 5204 : gps : gps
# 5205 : enrgyz : enrgyz
# 5206 : simpell : simpell
# 5207 : sejam : jam
# 5208 : trusdasar : trusdasar
# 5209 : nyuruh : nyuruh
# 5210 : penaikan : naik
# 5211 : mendaftar : daftar
# 5212 : nib : nib
# 5213 : bikinnya : bikin
# 5214 : npwp : npwp
# 5215 : wih : wih
# 5216 : segi : segi
# 5217 : thksz : thksz
# 5218 : mematikan : mati
# 5219 : ngudang : ngudang
# 5220 : telegram : telegram
# 5221 : belanjasangat : belanjasangat
# 5222 : td : td
# 5223 : ru : ru
# 5224 : mit : mit
# 5225 : oln : oln
# 5226 : dp : dp
# 5227 : tampa : tampa
# 5228 : kemama : mama
# 5229 : oky : oky
# 5230 : bay : bay
# 5231 : dek : dek
# 5232 : bek : bek
# 5233 : padhal : padhal
# 5234 : kga : kga
# 5235 : sistemnye : sistemnye
# 5236 : koneksi : koneksi
# 5237 : nnton : nnton
# 5238 : timbang : timbang
# 5239 : aje : aje
# 5240 : nyalahinnye : nyalahinnye
# 5241 : ribetnya : ribetnya
# 5242 : ampunprosesnya : ampunprosesnya
# 5243 : bgtpdhl : bgtpdhl
# 5244 : duwit : duwit
# 5245 : dapt : dapt
# 5246 : pascabayarjd : pascabayarjd
# 5247 : ush : ush
# 5248 : jelekkkkk : jelekkkkk
# 5249 : jelekk : jelekk
# 5250 : bangetjika : bangetjika
# 5251 : chattapi : chattapi
# 5252 : tanyakanpdhl : tanyakanpdhl
# 5253 : pilihditanya : pilihditanya
# 5254 : dllya : dllya
# 5255 : tauditempat : tauditempat
# 5256 : aty : aty
# 5257 : mulyatitolong : mulyatitolong
# 5258 : okok : okok
# 5259 : customerpelanggan : customerpelanggan
# 5260 : inovasi : inovasi
# 5261 : paylatertrimaksih : paylatertrimaksih
# 5262 : plazz : plazz
# 5263 : tapcahs : tapcahs
# 5264 : lenyap : lenyap
# 5265 : semogah : semogah
# 5266 : sialakk : sialakk
# 5267 : transaksina : transaksina
# 5268 : diadain : diadain
# 5269 : boz : boz
# 5270 : ecommercecm : ecommercecm
# 5271 : kapoknunggu : kapoknunggu
# 5272 : dibalikinhbis : dibalikinhbis
# 5273 : aplikasin : aplikasin
# 5274 : serangkai : rangka
# 5275 : sebelahbiru : sebelahbiru
# 5276 : tuaijoma : tuaijoma
# 5277 : orentrims : orentrims
# 5278 : secure : secure
# 5279 : caleg : caleg
# 5280 : perindo : perindo
# 5281 : dprd : dprd
# 5282 : dki : dki
# 5283 : dapil : dapil
# 5284 : kebayoran : kebayoran
# 5285 : uta : uta
# 5286 : pesanggrahan : pesanggrahan
# 5287 : setiabudi : setiabudi
# 5288 : cilandak : cilandak
# 5289 : kli : kli
# 5290 : makek : makek
# 5291 : terisi : isi
# 5292 : menganggap : anggap
# 5293 : penipuakun : penipuakun
# 5294 : sistemhello : sistemhello
# 5295 : kehilangan : hilang
# 5296 : terangsaksi : terangsaksi
# 5297 : setela : setela
# 5298 : tanggadan : tanggadan
# 5299 : okhh : okhh
# 5300 : pelangaran : pelangaran
# 5301 : berbelit : belit
# 5302 : komporgas : komporgas
# 5303 : pengambalian : pengambalian
# 5304 : jemputt : jemputt
# 5305 : tks : tks
# 5306 : ditukar : tukar
# 5307 : size : size
# 5308 : helloo : helloo
# 5309 : goodddbnykin : goodddbnykin
# 5310 : cashbackgratis : cashbackgratis
# 5311 : ongkirdan : ongkirdan
# 5312 : terbaiklah : baik
# 5313 : mysterybox : mysterybox
# 5314 : agt : agt
# 5315 : box : box
# 5316 : belain : bain
# 5317 : cepetan : cepetan
# 5318 : klasik : klasik
# 5319 : mengirim : kirim
# 5320 : terbatal : batal
# 5321 : mystery : mystery
# 5322 : php : php
# 5323 : hmmmm : hmmmm
# 5324 : riweuh : riweuh
# 5325 : ajak : ajak
# 5326 : temen : temen
# 5327 : done : done
# 5328 : hihii : hihii
# 5329 : becus : becus
# 5330 : murahperfectterima : murahperfectterima
# 5331 : pengepakan : epak
# 5332 : puasssssssm : puasssssssm
# 5333 : tariksaldo : tariksaldo
# 5334 : agus : agus
# 5335 : smpe : smpe
# 5336 : edaan : edaan
# 5337 : libur : libur
# 5338 : kya : kya
# 5339 : pns : pns
# 5340 : persentasenya : persentase
# 5341 : hnya : hnya
# 5342 : jagoin : jagoin
# 5343 : dibnding : dibnding
# 5344 : diamondsetiap : diamondsetiap
# 5345 : ketentuanpadahal : ketentuanpadahal
# 5346 : wajarsajabelanja : wajarsajabelanja
# 5347 : dlljuga : dlljuga
# 5348 : ukeperluan : ukeperluan
# 5349 : koktidak : koktidak
# 5350 : bliblisama : bliblisama
# 5351 : sekalimasa : sekalimasa
# 5352 : ketentuanbelanja : ketentuanbelanja
# 5353 : kreditkecewa : kreditkecewa
# 5354 : bliblibermanfaat : bliblibermanfaat
# 5355 : kaum : kaum
# 5356 : leasing : leasing
# 5357 : informatifterima : informatifterima
# 5358 : saring : saring
# 5359 : sellerny : sellerny
# 5360 : hadeeeuh : hadeeeuh
# 5361 : betuuulll : betuuulll
# 5362 : antreannya : antre
# 5363 : cargo : cargo
# 5364 : yaaasuksesss : yaaasuksesss
# 5365 : regis : regis
# 5366 : npw : npw
# 5367 : xjam : xjam
# 5368 : karn : karn
# 5369 : ca : ca
# 5370 : mantappppppplll : mantappppppplll
# 5371 : marketingnya : marketingnya
# 5372 : unsubscribe : unsubscribe
# 5373 : emailnya : email
# 5374 : footer : footer
# 5375 : unsubscribenya : unsubscribenya
# 5376 : besoknya : besok
# 5377 : betoool : betoool
# 5378 : barooo : barooo
# 5379 : diskonpromogratis : diskonpromogratis
# 5380 : mundur : mundur
# 5381 : yadikit : yadikit
# 5382 : ratus : ratus
# 5383 : legends : legends
# 5384 : bisagak : bisagak
# 5385 : meringankan : ringan
# 5386 : hila : hila
# 5387 : marketop : marketop
# 5388 : rban : rban
# 5389 : teruuuus : teruuuus
# 5390 : dikembangkan : kembang
# 5391 : trusss : trusss
# 5392 : grcep : grcep
# 5393 : krimannya : krim
# 5394 : murahdan : murahdan
# 5395 : supermurah : supermurah
# 5396 : ngalahin : ngalahin
# 5397 : orenijo : orenijo
# 5398 : aplikas : aplikas
# 5399 : mantapfast : mantapfast
# 5400 : gasws : gasws
# 5401 : wokeh : wokeh
# 5402 : asus : asus
# 5403 : bukak : bukak
# 5404 : putar : putar
# 5405 : mngajukan : mngajukan
# 5406 : bliplaylater : bliplaylater
# 5407 : mhon : mhon
# 5408 : baguuuuusss : baguuuuusss
# 5409 : senng : senng
# 5410 : indihome : indihome
# 5411 : shopi : shopi
# 5412 : lets : lets
# 5413 : help : help
# 5414 : people : people
# 5415 : who : who
# 5416 : need : need
# 5417 : persusah : susah
# 5418 : bantuinnya : bantuinnya
# 5419 : mengelabui : kelabu
# 5420 : juduldeskripsi : juduldeskripsi
# 5421 : ditindak : tindak
# 5422 : pro : pro
# 5423 : pantasan : pantas
# 5424 : mayoritas : mayoritas
# 5425 : sisanya : sisa
# 5426 : worthed : worthed
# 5427 : stocknya : stocknya
# 5428 : qtau : qtau
# 5429 : berharap : harap
# 5430 : dikembaliin : dikembaliin
# 5431 : utuh : utuh
# 5432 : mlh : mlh
# 5433 : dipisahkcewa : dipisahkcewa
# 5434 : hots : hots
# 5435 : mbtj : mbtj
# 5436 : brooks : brooks
# 5437 : wwwwwe : wwwwwe
# 5438 : mantapppps : mantapppps
# 5439 : miminyasegra : miminyasegra
# 5440 : responmengenai : responmengenai
# 5441 : batalsegera : batalsegera
# 5442 : trnsfer : trnsfer
# 5443 : bertnsaksi : bertnsaksi
# 5444 : lamban : lamban
# 5445 : manttul : manttul
# 5446 : wwwww : wwwww
# 5447 : mestinya : mesti
# 5448 : keleluasaan : leluasa
# 5449 : menjual : jual
# 5450 : produknyajgn : produknyajgn
# 5451 : surat : surat
# 5452 : usaha : usaha
# 5453 : dibli : dibli
# 5454 : dikenakan : kena
# 5455 : penjualanpun : jual
# 5456 : pajakan : paja
# 5457 : penghasilan : hasil
# 5458 : tahunsemua : tahunsemua
# 5459 : sadar : sadar
# 5460 : taat : taat
# 5461 : sesuaikan : sesuai
# 5462 : beralihpakai : beralihpakai
# 5463 : ribetsusah : ribetsusah
# 5464 : indodanapaylater : indodanapaylater
# 5465 : melibatkan : libat
# 5466 : waw : waw
# 5467 : debest : debest
# 5468 : more : more
# 5469 : than : than
# 5470 : mantabzz : mantabzz
# 5471 : betullngsung : betullngsung
# 5472 : prosestidak : prosestidak
# 5473 : dibintangapalagi : dibintangapalagi
# 5474 : bayarkan : bayar
# 5475 : afdol : afdol
# 5476 : baguuuuuus : baguuuuuus
# 5477 : skale : skale
# 5478 : lahi : lah
# 5479 : mantepunnn : mantepunnn
# 5480 : kompeten : kompeten
# 5481 : dikomplain : komplain
# 5482 : war : war
# 5483 : wkwkw : wkwkw
# 5484 : belanjaudh : belanjaudh
# 5485 : belanaja : belanaja
# 5486 : mskchat : mskchat
# 5487 : lahklu : lahklu
# 5488 : muncur : muncur
# 5489 : jdj : jdj
# 5490 : belanjasaya : belanjasaya
# 5491 : brp : brp
# 5492 : kasiklu : kasiklu
# 5493 : bgtsering : bgtsering
# 5494 : termuraahhhh : termuraahhhh
# 5495 : sofarsogud : sofarsogud
# 5496 : dicon : dicon
# 5497 : uji : uji
# 5498 : alhamdulillahrejeki : alhamdulillahrejeki
# 5499 : settlement : settlement
# 5500 : manual : manual
# 5501 : vcfimp : vcfimp
# 5502 : ngabisin : ngabisin
# 5503 : jatah : jatah
# 5504 : aka : aka
# 5505 : dinilai : nilai
# 5506 : digagalkan : gagal
# 5507 : wkwkwkw : wkwkwkw
# 5508 : heiii : heiii
# 5509 : shame : shame
# 5510 : really : really
# 5511 : layanin : layanin
# 5512 : buy : buy
# 5513 : berbepanja : berbepanja
# 5514 : ngentof : ngentof
# 5515 : lanjuti : lanjut
# 5516 : menaikkan : naik
# 5517 : perfomance : perfomance
# 5518 : ultah : ultah
# 5519 : tggl : tggl
# 5520 : kemaren : kemaren
# 5521 : banner : banner
# 5522 : ngadain : ngadain
# 5523 : apalikasinya : apalikasinya
# 5524 : tlalu : tlalu
# 5525 : btele : btele
# 5526 : telelamag : telelamag
# 5527 : intinyw : intinyw
# 5528 : anjurkan : anjur
# 5529 : dijadikan : jadi
# 5530 : shingga : shingga
# 5531 : dendajg : dendajg
# 5532 : byrkan : byrkan
# 5533 : dendanykrn : dendanykrn
# 5534 : bertumpukw : bertumpukw
# 5535 : dendanyttapi : dendanyttapi
# 5536 : waive : waive
# 5537 : tlah : tlah
# 5538 : mpe : mpe
# 5539 : kembalikn : kembalikn
# 5540 : inihanya : inihanya
# 5541 : des : des
# 5542 : slesaibutuh : slesaibutuh
# 5543 : stgh : stgh
# 5544 : joos : joos
# 5545 : rx : rx
# 5546 : red : red
# 5547 : ddr : ddr
# 5548 : dxf : dxf
# 5549 : rss : rss
# 5550 : fc : fc
# 5551 : fzez : fzez
# 5552 : rrc : rrc
# 5553 : ffi : ffi
# 5554 : xt : xt
# 5555 : kwalitasnya : kwalitasnya
# 5556 : cman : cman
# 5557 : gatisn : gatisn
# 5558 : dihargai : harga
# 5559 : veryyyyyy : veryyyyyy
# 5560 : memaksakan : paksa
# 5561 : mengirimkan : kirim
# 5562 : sebelmnya : sebelmnya
# 5563 : aktifnya : aktif
# 5564 : unt : unt
# 5565 : kereeennsimpleee : kereeennsimpleee
# 5566 : nyesek : nyesek
# 5567 : hatibegadang : hatibegadang
# 5568 : promogiliran : promogiliran
# 5569 : kirimeh : kirimeh
# 5570 : habisanjbanget : habisanjbanget
# 5571 : tuhharusnya : tuhharusnya
# 5572 : dibatalkanparah : dibatalkanparah
# 5573 : dihari : hari
# 5574 : sakithati : sakithati
# 5575 : asikdibikinkonten : asikdibikinkonten
# 5576 : pastipasti : pastipasti
# 5577 : penampilan : tampil
# 5578 : kontennya : konten
# 5579 : tokopediabertambah : tokopediabertambah
# 5580 : bunganya : bunga
# 5581 : beban : beban
# 5582 : buktikan : bukti
# 5583 : barangya : barangya
# 5584 : selow : selow
# 5585 : lamaakhir : lamaakhir
# 5586 : direset : direset
# 5587 : kebijakan : bijak
# 5588 : foundernya : foundernya
# 5589 : hargai : harga
# 5590 : diperhitungkan : hitung
# 5591 : dipikir : pikir
# 5592 : kritisi : kritisi
# 5593 : owh : owh
# 5594 : photo : photo
# 5595 : cmiiw : cmiiw
# 5596 : kotaongkos : kotaongkos
# 5597 : gilepantesan : gilepantesan
# 5598 : disinipercuma : disinipercuma
# 5599 : punjarang : punjarang
# 5600 : kecuali : kecuali
# 5601 : keluarga : keluarga
# 5602 : dijawa : dijawa
# 5603 : barangnyacnc : barangnyacnc
# 5604 : gaungnya : gaung
# 5605 : seramai : serama
# 5606 : tenggelam : tenggelam
# 5607 : elevania : elevania
# 5608 : menguras : uras
# 5609 : batrai : batrai
# 5610 : belibli : belibli
# 5611 : gas : gas
# 5612 : belanjai : belanja
# 5613 : lucumanis : lucumanis
# 5614 : hey : hey
# 5615 : kece : kece
# 5616 : ollshop : ollshop
# 5617 : bentar : bentar
# 5618 : capcusssss : capcusssss
# 5619 : tis : tis
# 5620 : manax : manax
# 5621 : gratisan : gratis
# 5622 : maa : maa
# 5623 : redup : redup
# 5624 : siiippp : siiippp
# 5625 : membatalakan : membatalakan
# 5626 : hbd : hbd
# 5627 : aplication : aplication
# 5628 : freshlagi : freshlagi
# 5629 : doain : doain
# 5630 : jelekmahal : jelekmahal
# 5631 : orangeengga : orangeengga
# 5632 : sebelahribet : sebelahribet
# 5633 : maahal : maahal
# 5634 : betah : betah
# 5635 : yaasoalnya : yaasoalnya
# 5636 : restok : restok
# 5637 : chek : chek
# 5638 : sellersellernya : sellersellernya
# 5639 : menjanjikan : janji
# 5640 : penipusaya : penipusaya
# 5641 : xiixix : xiixix
# 5642 : liternya : liter
# 5643 : terbiasa : biasa
# 5644 : bliblitp : bliblitp
# 5645 : jugadan : jugadan
# 5646 : bgtmantul : bgtmantul
# 5647 : dipertahankan : tahan
# 5648 : teknologi : teknologi
# 5649 : contohnya : contoh
# 5650 : nilainya : nilai
# 5651 : diakal : akal
# 5652 : njelimet : njelimet
# 5653 : besttt : besttt
# 5654 : asing : asing
# 5655 : sp : sp
# 5656 : sprti : sprti
# 5657 : ahh : ahh
# 5658 : nyampah : nyampah
# 5659 : henti : henti
# 5660 : invoice : invoice
# 5661 : berdasar : dasar
# 5662 : menurutku : turut
# 5663 : disertai : serta
# 5664 : beserta : serta
# 5665 : dibukti : bukti
# 5666 : kevalidan : valid
# 5667 : thd : thd
# 5668 : teusss : teusss
# 5669 : trua : trua
# 5670 : cekin : cekin
# 5671 : yh : yh
# 5672 : keridet : keridet
# 5673 : lemoot : lemoot
# 5674 : cepaf : cepaf
# 5675 : toling : toling
# 5676 : menguntung : untung
# 5677 : muantaaapp : muantaaapp
# 5678 : pastikan : pasti
# 5679 : sing : sing
# 5680 : cucok : cucok
# 5681 : jemboottt : jemboottt
# 5682 : limid : limid
# 5683 : celuler : celuler
# 5684 : memori : memori
# 5685 : zee : zee
# 5686 : z : z
# 5687 : didepan : depan
# 5688 : waspada : waspada
# 5689 : mengajak : ajak
# 5690 : mengatas : atas
# 5691 : yaas : yaas
# 5692 : dicicil : cicil
# 5693 : ajibbbbbbb : ajibbbbbbb
# 5694 : memoriku : memori
# 5695 : furious : furious
# 5696 : hadehh : hadehh
# 5697 : apply : apply
# 5698 : informasipadahal : informasipadahal
# 5699 : livechat : livechat
# 5700 : telan : telan
# 5701 : bumiparah : bumiparah
# 5702 : mepet : mepet
# 5703 : secepatnya : cepat
# 5704 : ehh : ehh
# 5705 : penanganannya : tangan
# 5706 : hrgnya : hrgnya
# 5707 : ituhanya : ituhanya
# 5708 : pengembalianrefund : pengembalianrefund
# 5709 : nasabah : nasabah
# 5710 : bliblimasa : bliblimasa
# 5711 : hoexs : hoexs
# 5712 : bliblinnjing : bliblinnjing
# 5713 : hahaaha : hahaaha
# 5714 : banyaksebelum : banyaksebelum
# 5715 : popok : popok
# 5716 : langkat : langkat
# 5717 : sumut : sumut
# 5718 : come : come
# 5719 : bantingan : banting
# 5720 : remit : rit
# 5721 : tele : tele
# 5722 : sopy : sopy
# 5723 : kwn : kwn
# 5724 : mengecewakantolong : mengecewakantolong
# 5725 : chrome : chrome
# 5726 : veri : veri
# 5727 : goof : goof
# 5728 : ridwan : ridwan
# 5729 : dulubarang : dulubarang
# 5730 : nyata : nyata
# 5731 : ajiiib : ajiiib
# 5732 : bass : bass
# 5733 : bahayaaaaaaa : bahayaaaaaaa
# 5734 : bangetttbelanja : bangetttbelanja
# 5735 : kemarinpagi : kemarinpagi
# 5736 : belanjaalias : belanjaalias
# 5737 : blacklist : blacklist
# 5738 : keinstall : keinstall
# 5739 : sangattttt : sangattttt
# 5740 : gpp : gpp
# 5741 : sistim : sistim
# 5742 : memperlancar : lancar
# 5743 : kermh : kermh
# 5744 : cuk : cuk
# 5745 : atw : atw
# 5746 : munkinlah : munkinlah
# 5747 : mndingan : mndingan
# 5748 : wktunya : wktunya
# 5749 : bwt : bwt
# 5750 : meminjam : pinjam
# 5751 : gagaldibatalkan : gagaldibatalkan
# 5752 : danauangnya : danauangnya
# 5753 : membandingkan : banding
# 5754 : installemot : installemot
# 5755 : terganti : ganti
# 5756 : eren : eren
# 5757 : hill : hill
# 5758 : rasane : rasane
# 5759 : luaarrrrr : luaarrrrr
# 5760 : biaasaaaaa : biaasaaaaa
# 5761 : sgra : sgra
# 5762 : selangit : langit
# 5763 : bliblisudah : bliblisudah
# 5764 : sayasukses : sayasukses
# 5765 : magkin : magkin
# 5766 : pembayatan : bayat
# 5767 : mahalpenguna : mahalpenguna
# 5768 : beuudd : beuudd
# 5769 : balon : balon
# 5770 : wis : wis
# 5771 : cincin : cincin
# 5772 : mantaabuntuk : mantaabuntuk
# 5773 : trimakasiih : trimakasiih
# 5774 : interfacenya : interfacenya
# 5775 : pembaran : bar
# 5776 : mahalpaylater : mahalpaylater
# 5777 : tangguhkanauto : tangguhkanauto
# 5778 : mantaff : mantaff
# 5779 : aksesnya : akses
# 5780 : semohga : semohga
# 5781 : kapokbeli : kapokbeli
# 5782 : blender : blender
# 5783 : philips : philips
# 5784 : promonyapadahal : promonyapadahal
# 5785 : seringkalo : seringkalo
# 5786 : sa : sa
# 5787 : tuduh : tuduh
# 5788 : sahabat : sahabat
# 5789 : diikuti : ikut
# 5790 : happiness : happiness
# 5791 : also : also
# 5792 : hold : hold
# 5793 : long : long
# 5794 : healthya : healthya
# 5795 : where : where
# 5796 : now : now
# 5797 : self : self
# 5798 : alllove : alllove
# 5799 : animore : animore
# 5800 : kun : kun
# 5801 : anta : anta
# 5802 : rempong : rempong
# 5803 : kkkkkkkk : kkkkkkkk
# 5804 : bafusss : bafusss
# 5805 : gantuk : gantuk
# 5806 : gblok : gblok
# 5807 : tagihanku : tagih
# 5808 : mmbntu : mmbntu
# 5809 : permsalahan : permsalahan
# 5810 : jadul : jadul
# 5811 : redmi : redmi
# 5812 : eccomerce : eccomerce
# 5813 : ketuk : ketuk
# 5814 : hptablet : hptablet
# 5815 : disayangkan : sayang
# 5816 : ngebet : ngebet
# 5817 : terhindar : hindar
# 5818 : modus : modus
# 5819 : ujang : ujang
# 5820 : aji : aji
# 5821 : mengubah : ubah
# 5822 : nomo : nomo
# 5823 : mahalbeda : mahalbeda
# 5824 : shopeelazadatokopedia : shopeelazadatokopedia
# 5825 : sebutkan : sebut
# 5826 : manntap : manntap
# 5827 : aah : aah
# 5828 : tpklo : tpklo
# 5829 : semangkin : semangkin
# 5830 : lncar : lncar
# 5831 : go : go
# 5832 : simplemohon : simplemohon
# 5833 : benahi : benah
# 5834 : tampianya : tampianya
# 5835 : dngn : dngn
# 5836 : situ : situ
# 5837 : berkarya : karya
# 5838 : strong : strong
# 5839 : djarum : djarum
# 5840 : grup : grup
# 5841 : bertaha : bertaha
# 5842 : mangstaapp : mangstaapp
# 5843 : tambilan : tambilan
# 5844 : dtingkatkan : dtingkatkan
# 5845 : barangproduknya : barangproduknya
# 5846 : pakeharappakeharapopp : pakeharappakeharapopp
# 5847 : hayuuu : hayuuu
# 5848 : kdang : kdang
# 5849 : ngirimi : ngirimi
# 5850 : outlet : outlet
# 5851 : ajh : ajh
# 5852 : ribeettttttt : ribeettttttt
# 5853 : sad : sad
# 5854 : talk : talk
# 5855 : kelarin : kelarin
# 5856 : bangetttt : bangetttt
# 5857 : perlukan : perlu
# 5858 : tercantum : cantum
# 5859 : dftr : dftr
# 5860 : pngalaman : pngalaman
# 5861 : alus : alus
# 5862 : otaknya : otak
# 5863 : fb : fb
# 5864 : beguna : beguna
# 5865 : batasi : batas
# 5866 : goob : goob
# 5867 : kesana : kesana
# 5868 : mantavv : mantavv
# 5869 : jembooot : jembooot
# 5870 : tol : tol
# 5871 : ms : ms
# 5872 : glow : glow
# 5873 : facial : facial
# 5874 : wash : wash
# 5875 : men : men
# 5876 : prtama : prtama
# 5877 : fungsi : fungsi
# 5878 : pengunjung : unjung
# 5879 : tenar : tenar
# 5880 : jaim : jaim
# 5881 : juaji : juaji
# 5882 : hohoho : hohoho
# 5883 : contohlah : contoh
# 5884 : sopee : sopee
# 5885 : bukalpak : bukalpak
# 5886 : diakses : akses
# 5887 : aplikasinyamudah : aplikasinyamudah
# 5888 : semakinn : semakinn
# 5889 : nihh : nihh
# 5890 : sipplaahh : sipplaahh
# 5891 : mantabbbsss : mantabbbsss
# 5892 : ditambaah : ditambaah
# 5893 : pakaian : pakai
# 5894 : anaknya : anak
# 5895 : ekonomis : ekonomis
# 5896 : bbrpa : bbrpa
# 5897 : mantaaapp : mantaaapp
# 5898 : pokoknyabelanja : pokoknyabelanja
# 5899 : rmxxxx : rmxxxx
# 5900 : internal : internal
# 5901 : jemput : jemput
# 5902 : rekaman : rekam
# 5903 : bijaksana : bijaksana
# 5904 : aftersales : aftersales
# 5905 : kerenproses : kerenproses
# 5906 : ribetjuara : ribetjuara
# 5907 : pokoknynamun : pokoknynamun
# 5908 : mmbri : mmbri
# 5909 : msukn : msukn
# 5910 : packingan : packingan
# 5911 : agr : agr
# 5912 : sefety : sefety
# 5913 : okey : okey
# 5914 : playlatter : playlatter
# 5915 : coy : coy
# 5916 : penyok : penyok
# 5917 : adminnya : adminnya
# 5918 : padamu : pada
# 5919 : smile : smile
# 5920 : eeegag : eeegag
# 5921 : track : track
# 5922 : record : record
# 5923 : survey : survey
# 5924 : oklah : oklah
# 5925 : tercakup : cakup
# 5926 : maap : maap
# 5927 : chasbank : chasbank
# 5928 : ye : ye
# 5929 : goods : goods
# 5930 : minya : mi
# 5931 : markerplace : markerplace
# 5932 : olx : olx
# 5933 : smg : smg
# 5934 : shg : shg
# 5935 : berlanjut : lanjut
# 5936 : saldi : saldi
# 5937 : zi : zi
# 5938 : terhubung : hubung
# 5939 : servis : servis
# 5940 : siiiiiiiip : siiiiiiiip
# 5941 : trash : trash
# 5942 : ceppat : ceppat
# 5943 : kamrin : kamrin
# 5944 : sekrang : sekrang
# 5945 : katro : katro
# 5946 : date : date
# 5947 : exspor : exspor
# 5948 : potensi : potensi
# 5949 : ketersediaan : sedia
# 5950 : terinfluence : terinfluence
# 5951 : eko : eko
# 5952 : kurniawan : kurniawan
# 5953 : khannedy : khannedy
# 5954 : hai : hai
# 5955 : dimiliki : milik
# 5956 : oiyy : oiyy
# 5957 : tersusah : susah
# 5958 : parahparahsangat : parahparahsangat
# 5959 : mbuletttt : mbuletttt
# 5960 : ae : ae
# 5961 : terusss : terusss
# 5962 : brkualitas : brkualitas
# 5963 : kreditnya : kredit
# 5964 : kekecilan : kecil
# 5965 : argo : argo
# 5966 : mal : mal
# 5967 : manteppp : manteppp
# 5968 : qiris : qiris
# 5969 : dibalikinrefundudah : dibalikinrefundudah
# 5970 : segini : gin
# 5971 : ongkirtop : ongkirtop
# 5972 : rancak : rancak
# 5973 : bana : bana
# 5974 : kooha : kooha
# 5975 : hancur : hancur
# 5976 : appsaya : appsaya
# 5977 : ditinggalin : ditinggalin
# 5978 : solat : solat
# 5979 : muteraneh : muteraneh
# 5980 : websitetolong : websitetolong
# 5981 : pengembang : kembang
# 5982 : blibliaplikasi : blibliaplikasi
# 5983 : sekarangharga : sekarangharga
# 5984 : bxk : bxk
# 5985 : legit : legit
# 5986 : gilaaa : gilaaa
# 5987 : coyy : coyy
# 5988 : wstge : wstge
# 5989 : layal : layal
# 5990 : exclusif : exclusif
# 5991 : keseruan : seru
# 5992 : sinitop : sinitop
# 5993 : difikirkan : difikirkan
# 5994 : sdah : sdah
# 5995 : inbound : inbound
# 5996 : rugikan : rugi
# 5997 : terimatapi : terimatapi
# 5998 : reza : reza
# 5999 : kredidsb : kredidsb
# 6000 : canggihbalikin : canggihbalikin
# 6001 : berhariharimending : berhariharimending
# 6002 : mantaaaaaaaaabbb : mantaaaaaaaaabbb
# 6003 : keluarkan : keluar
# 6004 : kec : kec
# 6005 : trimaksih : trimaksih
# 6006 : mmbantuuu : mmbantuuu
# 6007 : komtol : komtol
# 6008 : px : px
# 6009 : shoopetokopedialazada : shoopetokopedialazada
# 6010 : beratnya : berat
# 6011 : gram : gram
# 6012 : cmn : cmn
# 6013 : dongeng : dongeng
# 6014 : stay : stay
# 6015 : sangatx : sangatx
# 6016 : diselesaikan : selesai
# 6017 : berlamalama : berlamalama
# 6018 : seiengkapnya : seiengkapnya
# 6019 : opsionai : opsionai
# 6020 : biibii : biibii
# 6021 : ngebutttt : ngebutttt
# 6022 : uip : uip
# 6023 : bag : bag
# 6024 : us : us
# 6025 : keridivo : keridivo
# 6026 : sunscreen : sunscreen
# 6027 : tri : tri
# 6028 : kasihh : kasihh
# 6029 : mantabbb : mantabbb
# 6030 : peminat : minat
# 6031 : gblk : gblk
# 6032 : lengkapp : lengkapp
# 6033 : akurattttapi : akurattttapi
# 6034 : mentah : mentah
# 6035 : tidk : tidk
# 6036 : jelasmasak : jelasmasak
# 6037 : paylaterny : paylaterny
# 6038 : dinonaktifkanpadahal : dinonaktifkanpadahal
# 6039 : waktutidk : waktutidk
# 6040 : telatbahkan : telatbahkan
# 6041 : lunastolong : lunastolong
# 6042 : diperbaikimengecewakanterimakasih : diperbaikimengecewakanterimakasih
# 6043 : diapk : diapk
# 6044 : qrisnya : qrisnya
# 6045 : kinerja : kerja
# 6046 : bagussekali : bagussekali
# 6047 : memesanbeli : memesanbeli
# 6048 : sibuk : sibuk
# 6049 : kuliah : kuliah
# 6050 : ut : ut
# 6051 : bantuanya : bantuanya
# 6052 : variatif : variatif
# 6053 : besarberat : besarberat
# 6054 : pecinta : cinta
# 6055 : olah : olah
# 6056 : raga : raga
# 6057 : tenis : tenis
# 6058 : meja : meja
# 6059 : karet : karet
# 6060 : aci : aci
# 6061 : gamespot : gamespot
# 6062 : nite : nite
# 6063 : muna : muna
# 6064 : sentla : sentla
# 6065 : gayas : gayas
# 6066 : aitesi : aitesi
# 6067 : senawirnya : senawirnya
# 6068 : covid : covid
# 6069 : sii : sii
# 6070 : mantoel : mantoel
# 6071 : blilbli : blilbli
# 6072 : grubnya : grubnya
# 6073 : fbb : fbb
# 6074 : second : second
# 6075 : desbuk : desbuk
# 6076 : unitnya : unit
# 6077 : imeinya : imeinya
# 6078 : kartunya : kartu
# 6079 : disalahgunakan : disalahgunakan
# 6080 : ctcfrr : ctcfrr
# 6081 : htc : htc
# 6082 : vcd : vcd
# 6083 : cree : cree
# 6084 : vtv : vtv
# 6085 : pastiin : pastiin
# 6086 : dibesok : besok
# 6087 : terpakai : pakai
# 6088 : mane : mane
# 6089 : gagaal : gagaal
# 6090 : termcondition : termcondition
# 6091 : baaaanyak : baaaanyak
# 6092 : promosinya : promosi
# 6093 : ktswzs : ktswzs
# 6094 : gy : gy
# 6095 : yvyt : yvyt
# 6096 : cepatdan : cepatdan
# 6097 : mantapblibli : mantapblibli
# 6098 : hahah : hahah
# 6099 : embel : embel
# 6100 : ternyta : ternyta
# 6101 : bulanannya : bulan
# 6102 : newsletter : newsletter
# 6103 : matikan : mati
# 6104 : menyerang : serang
# 6105 : piahak : piahak
# 6106 : bliblisejauh : bliblisejauh
# 6107 : sampee : sampee
# 6108 : saller : saller
# 6109 : standard : standard
# 6110 : default : default
# 6111 : tekan : tekan
# 6112 : blibliemejing : blibliemejing
# 6113 : mntep : mntep
# 6114 : qo : qo
# 6115 : kkselalu : kkselalu
# 6116 : jumat : jumat
# 6117 : snin : snin
# 6118 : ngendep : ngendep
# 6119 : distu : distu
# 6120 : alfamrtindomrt : alfamrtindomrt
# 6121 : bllibisemoga : bllibisemoga
# 6122 : efektif : efektif
# 6123 : simply : simply
# 6124 : feature : feature
# 6125 : mantaaaaaap : mantaaaaaap
# 6126 : gtu : gtu
# 6127 : ee : ee
# 6128 : lll : lll
# 6129 : kooljjookkkkkkkkkku : kooljjookkkkkkkkkku
# 6130 : lkj : lkj
# 6131 : klll : klll
# 6132 : jx : jx
# 6133 : xmlj : xmlj
# 6134 : sore : sore
# 6135 : supir : supir
# 6136 : indah : indah
# 6137 : mampir : mampir
# 6138 : dititipi : titip
# 6139 : terangkan : terang
# 6140 : saksi : saksi
# 6141 : connecting : connecting
# 6142 : lambaaatttt : lambaaatttt
# 6143 : ribettttproses : ribettttproses
# 6144 : refundbertele : refundbertele
# 6145 : okeeeeh : okeeeeh
# 6146 : kb : kb
# 6147 : nu : nu
# 6148 : mantulkk : mantulkk
# 6149 : nikmat : nikmat
# 6150 : berkompetisi : kompetisi
# 6151 : disempurnakan : sempurna
# 6152 : backnya : backnya
# 6153 : pgood : pgood
# 6154 : night : night
# 6155 : sweet : sweet
# 6156 : aplikasih : aplikasih
# 6157 : sarang : sarang
# 6158 : pertahankn : pertahankn
# 6159 : brlanja : brlanja
# 6160 : madang : madang
# 6161 : gedean : gede
# 6162 : hariansyediiiih : hariansyediiiih
# 6163 : akutuh : akutuh
# 6164 : elektrik : elektrik
# 6165 : sempak : sempak
# 6166 : jamalsaputra : jamalsaputra
# 6167 : bbnnnnhe : bbnnnnhe
# 6168 : informatif : informatif
# 6169 : terpecaya : terpecaya
# 6170 : alldxxx : alldxxx
# 6171 : parahkata : parahkata
# 6172 : melulubikin : melulubikin
# 6173 : ribetaplikasi : ribetaplikasi
# 6174 : sandikecuali : sandikecuali
# 6175 : hpnyabaru : hpnyabaru
# 6176 : sandiudah : sandiudah
# 6177 : systemjadi : systemjadi
# 6178 : masukkalau : masukkalau
# 6179 : mengerikan : keri
# 6180 : mantuull : mantuull
# 6181 : daftarkn : daftarkn
# 6182 : posel : posel
# 6183 : verivikasinya : verivikasinya
# 6184 : lma : lma
# 6185 : bisabisa : bisabisa
# 6186 : kendalanya : kendala
# 6187 : buruan : buru
# 6188 : dehhsoal : dehhsoal
# 6189 : jozzz : jozzz
# 6190 : kelar : kelar
# 6191 : bawa : bawa
# 6192 : dpat : dpat
# 6193 : potk : potk
# 6194 : skrang : skrang
# 6195 : minblnja : minblnja
# 6196 : dirubah : rubah
# 6197 : persyaratannya : syarat
# 6198 : syukur : syukur
# 6199 : jgmasih : jgmasih
# 6200 : tmapt : tmapt
# 6201 : mh : mh
# 6202 : diatur : atur
# 6203 : dbanding : dbanding
# 6204 : ngubek : ngubek
# 6205 : belanjalah : belanja
# 6206 : ba : ba
# 6207 : butuhnya : butuh
# 6208 : ayookk : ayookk
# 6209 : inddna : inddna
# 6210 : mikir : mikir
# 6211 : nyerah : nyerah
# 6212 : hadeeehhbikin : hadeeehhbikin
# 6213 : terthebest : terthebest
# 6214 : desain : desain
# 6215 : uiux : uiux
# 6216 : perbandingannya : banding
# 6217 : bumn : bumn
# 6218 : sesalkan : sesal
# 6219 : pengembaliannya : kembali
# 6220 : wew : wew
# 6221 : goblog : goblog
# 6222 : kargonya : kargo
# 6223 : jj : jj
# 6224 : antriannya : antri
# 6225 : tertulis : tulis
# 6226 : damn : damn
# 6227 : funny : funny
# 6228 : bliblipayleter : bliblipayleter
# 6229 : still : still
# 6230 : termahal : mahal
# 6231 : pokokny : pokokny
# ...
# 9088 : telattapi : telattapi
# 9089 : nonaktipknkan : nonaktipknkan
# 9090 : anehorang : anehorang
# 9091 : bayrnya : bayrnya
# 9092 : aktipknnlbh : aktipknnlbh
# 9093 : tinjauannya : tinjau
# 9094 : custamer : custamer
# 9095 : setiamu : setia
# 9096 : muhammad : muhammad
# 9097 : azzam : azzam
# 9098 : tas : tas
# 9099 : jw : jw
# 9100 : laaaaaaaa : laaaaaaaa
# 9101 : perbulan : bulan
# 9102 : bliblipenggunaan : bliblipenggunaan
# 9103 : ht : ht
# 9104 : nmn : nmn
# 9105 : omm : omm
# 9106 : mmm : mmm
# 9107 : pelayananny : pelayananny
# 9108 : yaaaa : yaaaa
# 9109 : terbaikuntuk : terbaikuntuk
# 9110 : penolakan : tolak
# 9111 : apgie : apgie
# 9112 : confirm : confirm
# 9113 : digitalnya : digital
# 9114 : mandek : mandek
# 9115 : segampang : gampang
# 9116 : mejeng : mejeng
# 9117 : payllter : payllter
# 9118 : terbagus : bagus
# 9119 : ges : ges
# 9120 : ogaah : ogaah
# 9121 : ketingalan : ketingalan
# 9122 : asem : asem
# 9123 : tobs : tobs
# 9124 : autol : autol
# 9125 : sekaly : sekaly
# 9126 : blibliecomm : blibliecomm
# 9127 : qr : qr
# 9128 : oct : oct
# 9129 : stlah : stlah
# 9130 : stngah : stngah
# 9131 : ternya : ter
# 9132 : tautan : taut
# 9133 : mibile : mibile
# 9134 : wassalam : wassalam
# 9135 : akeh : akeh
# 9136 : tervalidasi : tervalidasi
# 9137 : validasi : validasi
# 9138 : alat : alat
# 9139 : stndar : stndar
# 9140 : ra : ra
# 9141 : datakenapa : datakenapa
# 9142 : dahbeda : dahbeda
# 9143 : shopeecepat : shopeecepat
# 9144 : ketrangan : ketrangan
# 9145 : optimalisasikan : optimalisasi
# 9146 : monthly : monthly
# 9147 : well : well
# 9148 : he : he
# 9149 : hhuft : hhuft
# 9150 : bagusdan : bagusdan
# 9151 : ketelitian : teliti
# 9152 : ngtd : ngtd
# 9153 : mempersempit : sempit
# 9154 : ruang : ruang
# 9155 : mang : mang
# 9156 : rekeninh : rekeninh
# 9157 : paraha : paraha
# 9158 : perputaran : putar
# 9159 : kompalin : kompalin
# 9160 : simulasi : simulasi
# 9161 : viera : viera
# 9162 : divisi : divisi
# 9163 : mnatap : mnatap
# 9164 : josh : josh
# 9165 : aplikasinta : aplikasinta
# 9166 : hmpir : hmpir
# 9167 : memasukan : pasu
# 9168 : sejenis : jenis
# 9169 : onlinenanti : onlinenanti
# 9170 : punyaku : punya
# 9171 : lamaaaaaaaaa : lamaaaaaaaaa
# 9172 : tanggerang : tanggerang
# 9173 : cilegon : cilegon
# 9174 : banten : banten
# 9175 : bisawoy : bisawoy
# 9176 : lahiran : lahir
# 9177 : bangetpayah : bangetpayah
# 9178 : ganproses : ganproses
# 9179 : dullu : dullu
# 9180 : sayajangan : sayajangan
# 9181 : gunakanpengajuan : gunakanpengajuan
# 9182 : bliblirespon : bliblirespon
# 9183 : ongkirpuas : ongkirpuas
# 9184 : do : do
# 9185 : tiduran : tidur
# 9186 : trimksih : trimksih
# 9187 : memng : memng
# 9188 : mantaaasp : mantaaasp
# 9189 : dulul : dulul
# 9190 : awsome : awsome
# 9191 : salalu : salalu
# 9192 : mengecawakan : cawak
# 9193 : licik : licik
# 9194 : bertantraksi : bertantraksi
# 9195 : belit : belit
# 9196 : musim : musim
# 9197 : hujan : hujan
# 9198 : kardus : kardus
# 9199 : tempatkuu : tempatkuu
# 9200 : mengcancel : mengcancel
# 9201 : menyarankan : saran
# 9202 : minbelnya : minbelnya
# 9203 : bliblipengiriman : bliblipengiriman
# 9204 : cepatbanyak : cepatbanyak
# 9205 : otpnya : otpnya
# 9206 : dipembatalan : batal
# 9207 : mantapssss : mantapssss
# 9208 : sblum : sblum
# 9209 : sring : sring
# 9210 : bngd : bngd
# 9211 : ngadu : ngadu
# 9212 : ngilang : ngilang
# 9213 : hiasan : hias
# 9214 : masjk : masjk
# 9215 : murni : murni
# 9216 : bljbljl : bljbljl
# 9217 : bangeeettt : bangeeettt
# 9218 : mantaabe : mantaabe
# 9219 : cuocoook : cuocoook
# 9220 : daster : daster
# 9221 : hidden : hidden
# 9222 : gems : gems
# 9223 : kapitalis : kapitalis
# 9224 : lapkeu : lapkeu
# 9225 : pertahanken : pertahanken
# 9226 : duper : duper
# 9227 : murahhhh : murahhhh
# 9228 : livin : livin
# 9229 : telepo : tepo
# 9230 : bacaanya : bacaanya
# 9231 : barangx : barangx
# 9232 : akuntansi : akuntansi
# 9233 : oengguna : oengguna
# 9234 : blja : blja
# 9235 : tanks : tanks
# 9236 : mengambil : ambil
# 9237 : kesiapa : siapa
# 9238 : kebijkan : kebijkan
# 9239 : mantuuuullll : mantuuuullll
# 9240 : tinjau : tinjau
# 9241 : ngedit : ngedit
# 9242 : copy : copy
# 9243 : paste : paste
# 9244 : ct : ct
# 9245 : yaadm : yaadm
# 9246 : mwmuaskan : mwmuaskan
# 9247 : ngawur : ngawur
# 9248 : recoveri : recoveri
# 9249 : murahmurah : murahmurah
# 9250 : kluar : kluar
# 9251 : gojeknya : gojek
# 9252 : dtgapa : dtgapa
# 9253 : istirahat : istirahat
# 9254 : kasiannyari : kasiannyari
# 9255 : gituhrus : gituhrus
# 9256 : nurani : nurani
# 9257 : gacor : gacor
# 9258 : sangant : sangant
# 9259 : ahsedd : ahsedd
# 9260 : cobah : cobah
# 9261 : brensek : brensek
# 9262 : buangbuang : buangbuang
# 9263 : realmi : realmi
# 9264 : black : black
# 9265 : bangetkadang : bangetkadang
# 9266 : kmbali : kmbali
# 9267 : pemakainya : maka
# 9268 : promony : promony
# 9269 : bnyakcuma : bnyakcuma
# 9270 : kmplain : kmplain
# 9271 : bkin : bkin
# 9272 : kolor : kolor
# 9273 : bliblitagihan : bliblitagihan
# 9274 : basmi : basmi
# 9275 : rela : rela
# 9276 : begadang : begadang
# 9277 : ditidak : tidak
# 9278 : dagang : dagang
# 9279 : mendengar : dengar
# 9280 : curhatsemua : curhatsemua
# 9281 : menguap : uap
# 9282 : terlelapblanja : terlelapblanja
# 9283 : bilibil : bilibil
# 9284 : ngibulin : ngibulin
# 9285 : konsumennya : konsumen
# 9286 : maatp : maatp
# 9287 : injek : injek
# 9288 : kibarkan : kibar
# 9289 : menbatu : menbatu
# 9290 : bersatu : satu
# 9291 : ceraikan : cerai
# 9292 : eaaaa : eaaaa
# 9293 : sellery : sellery
# 9294 : bgtupn : bgtupn
# 9295 : nyampein : nyampein
# 9296 : ksellery : ksellery
# 9297 : mju : mju
# 9298 : mitk : mitk
# 9299 : kuku : kuku
# 9300 : mii : mii
# 9301 : yiu : yiu
# 9302 : imut : imut
# 9303 : ujio : ujio
# 9304 : muantaab : muantaab
# 9305 : saripa : saripa
# 9306 : gimna : gimna
# 9307 : ntap : ntap
# 9308 : matkiding : matkiding
# 9309 : sh : sh
# 9310 : nyasudah : nyasudah
# 9311 : gateway : gateway
# 9312 : jakartalama : jakartalama
# 9313 : manjami : manjami
# 9314 : kebutu : kebutu
# 9315 : batang : batang
# 9316 : seolaholah : seolaholah
# 9317 : memiliki : milik
# 9318 : sybli : sybli
# 9319 : ciciln : ciciln
# 9320 : sklistlah : sklistlah
# 9321 : tempotiba : tempotiba
# 9322 : nonaktifkanpdhal : nonaktifkanpdhal
# {'aplikasi': 'aplikasi', 'mudah': 'mudah', 'hack': 'hack', 'kena': 'kena', 'dgn': 'dgn', 'pembelian': 'beli', 'dicancel': 'dicancel', 'dana': 'dana', 'masuk': 'masuk', 'blibli': 'blibli', 'pay': 'pay', 'password': 'password', 'berbeda': 'beda', 'beli': 'beli', 'pulsa': 'pulsa', 'ngga': 'ngga', 'dibatalkan': 'batal', 'ditransfer': 'transfer', 'dikembalikan': 'kembali', 'hp': 'hp', 'lazada': 'lazada', 'tokopediagojek': 'tokopediagojek', 'shoppe': 'shoppe', 'm': 'm', 'banking': 'banking', 'ovo': 'ovo', 'isaku': 'isa', 'seabanktapi': 'seabanktapi', 'top': 'top', 'dekade': 'dekade', 'terpercaya': 'percaya', 'terdepan': 'depan', 'pengiriman': 'kirim', 'free': 'free', 'ongkirnya': 'ongkirnya', 'juara': 'juara', 'is': 'is', 'the': 'the', 'best': 'best', 'favorit': 'favorit', 'belanja': 'belanja', 'elektronik': 'elektronik', 'online': 'online', 'layanan': 'layan', 'ok': 'ok', 'banget': 'banget', 'x': 'x', 'tv': 'tv', 'pecah': 'pecah', 'lapor': 'lapor', 'kirim': 'kirim', 'barang': 'barang', 'langsung': 'langsung', 'diganti': 'ganti', 'membantu': 'bantu', 'memenuhi': 'penuh', 'kebutuhan': 'butuh', 'rumah': 'rumah', 'sdh': 'sdh', 'instal': 'instal', 'ulang': 'ulang', 'gak': 'gak', 'buka': 'buka', 'aplikasinya': 'aplikasi', 'tolong': 'tolong', 'perbaiki': 'baik', 'semoga': 'moga', 'sukses': 'sukses', 'maju': 'maju', 'ngak': 'ngak', 'suka': 'suka', 'aja': 'aja', 'pakainya': 'pakai', 'tampilan': 'tampil', 'membingungkan': 'bingung', 'kebanyakan': 'banyak', 'animasi': 'animasi', 'mengganggu': 'ganggu', 'saar': 'saar', 'proses': 'proses', 'memilih': 'pilih', 'bagus': 'bagus', 'delay': 'delay', 'maaf': 'maaf', 'kk': 'kk', 'skrg': 'skrg', 'login': 'login', 'diarahkan': 'arah', 'browser': 'browser', 'sll': 'sll', 'dlm': 'dlm', 'posisi': 'posisi', 'respon': 'respon', 'mohon': 'mohon', 'pencerahannya': 'cerah', 'kak': 'kak', 'makasih': 'makasih', 'kedepannya': 'depan', 'gila': 'gila', 'ntah': 'ntah', 'kategori': 'kategori', 'pengguna': 'guna', 'tahan': 'tahan', 'sembunyikan': 'sembunyi', 'halnya': 'hal', 'membeli': 'beli', 'peralatan': 'alat', 'senapan': 'senapan', 'vape': 'vape', 'sensor': 'sensor', 'sungguh': 'sungguh', 'user': 'user', 'berat': 'berat', 'hati': 'hati', 'menggunakannya': 'guna', 'mencoba': 'coba', 'ajhieb': 'ajhieb', 'bin': 'bin', 'marqothop': 'marqothop', 'mantap': 'mantap', 'berguna': 'guna', 'okehh': 'okehh', 'mantab': 'mantab', 'nya': 'nya', 'ribet': 'ribet', 'kali': 'kali', 'hmm': 'hmm', 'byk': 'byk', 'buanget': 'buanget', 'isinya': 'isi', 'murah': 'murah', 'harga': 'harga', 'termurah': 'murah', 'sajian': 'saji', 'termudan': 'mud', 'apik': 'apik', 'simpel': 'simpel', 'dioprasikan': 'dioprasikan', 'kerja': 'kerja', 'yg': 'yg', 'pokonya': 'poko', 'mantul': 'mantul', 'bintang': 'bintang', 'cash': 'cash', 'kurir': 'kurir', 'bermodal': 'modal', 'berakal': 'akal', 'nomor': 'nomor', 'telpon': 'telpon', 'tinggal': 'tinggal', 'sms': 'sms', 'gau': 'gau', 'bayar': 'bayar', 'payah': 'payah', 'kapok': 'kapok', 'gua': 'gua', 'cepat': 'cepat', 'status': 'status', 'platinum': 'platinum', 'kecewa': 'kecewa', 'keluhan': 'keluh', 'terkait': 'kait', 'misleading': 'misleading', 'informasi': 'informasi', 'deskripsi': 'deskripsi', 'produk': 'produk', 'menanggapi': 'tanggap', 'karna': 'karna', 'loyalitas': 'loyalitas', 'pelanggan': 'langgan', 'dibutuhkan': 'butuh', 'kasih': 'kasih', 'orderan': 'order', 'uninstall': 'uninstall', 'pakai': 'pakai', 'apapun': 'apa', 'iklan': 'iklan', 'muncul': 'muncul', 'standby': 'standby', 'telp': 'telp', 'tulis': 'tulis', 'wa': 'wa', 'santui': 'santui', 'kilat': 'kilat', 'tokped': 'tokped', 'berusaha': 'usaha', 'menaikan': 'naik', 'levelberat': 'levelberat', 'u': 'u', 'pindah': 'pindah', 'bli': 'bli', 'sih': 'sih', 'dah': 'dah', 'pokoknya': 'pokok', 'eh': 'eh', 'juragan': 'juragan', 'benerbener': 'benerbener', 'dahsyat': 'dahsyat', 'dijualnya': 'jual', 'bikin': 'bikin', 'nggak': 'nggak', 'tidur': 'tidur', 'saking': 'saking', 'senangnya': 'senang', 'pelayanannya': 'layan', 'prima': 'prima', 'meleleh': 'leleh', 'kayak' ...
# ------------------------
#                                               content  score  \
# 0   Aplikasi mudah di hack, saya kena dgn pembelia...      1
# 1                                                 top      5
# 2   1 dekade bersama BLIBLI. Terpercaya dan semaki...      5
# 3                                         is the best      5
# 4   Paling favorit untuk belanja elektronik online...      5
# 5            sangat membantu memenuhi kebutuhan rumah      4
# 6   Sdh di instal ulang masih juga gak bisa di buk...      3
# 7                                semoga selalu sukses      4
# 8                           Semoga Blibli tambah maju      5
# 9                             Ngak suka aja pakainya.      1
# 10  Tampilan aplikasinya membingungkan, kebanyakan...      2
# 11                                              bagus      5
# 12                                              delay      1
# 13  Maaf kk, skrg mau login di aplikasi gak bisa. ...      4
# 14  Bagus bagus! Semoga kedepannya Blibli tidak se...      5
# 15                                                 ok      5
# 16                                       Baru mencoba      5
# 17                                              Bagus      5
# 18                               ajhieb bin marqothop      5
# 19                              mantap sangat berguna      5
#
#                                            text_clean  \
# 0   aplikasi mudah di hack saya kena dgn pembelian...
# 1                                                 top
# 2    dekade bersama blibli terpercaya dan semakin ...
# 3                                         is the best
# 4   paling favorit untuk belanja elektronik online...
# 5            sangat membantu memenuhi kebutuhan rumah
# 6   sdh di instal ulang masih juga gak bisa di buk...
# 7                                semoga selalu sukses
# 8                           semoga blibli tambah maju
# 9                              ngak suka aja pakainya
# 10  tampilan aplikasinya membingungkan kebanyakan ...
# 11                                              bagus
# 12                                              delay
# 13  maaf kk skrg mau login di aplikasi gak bisa sa...
# 14  bagus bagus semoga kedepannya blibli tidak sep...
# 15                                                 ok
# 16                                       baru mencoba
# 17                                              bagus
# 18                               ajhieb bin marqothop
# 19                              mantap sangat berguna
#
#                                         text_StopWord  \
# 0   aplikasi mudah hack kena dgn pembelian dicance...
# 1                                                 top
# 2   dekade blibli terpercaya terdepan pengiriman f...
# 3                                         is the best
# 4   favorit belanja elektronik online layanan ok b...
# 5                   membantu memenuhi kebutuhan rumah
# 6   sdh instal ulang gak buka aplikasinya tolong p...
# 7                                       semoga sukses
# 8                                  semoga blibli maju
# 9                              ngak suka aja pakainya
# 10  tampilan aplikasinya membingungkan kebanyakan ...
# 11                                              bagus
# 12                                              delay
# 13  maaf kk skrg login aplikasi gak diarahkan brow...
# 14  bagus bagus semoga kedepannya blibli shoppe gi...
# 15                                                 ok
# 16                                            mencoba
# 17                                              bagus
# 18                               ajhieb bin marqothop
# 19                                     mantap berguna
#
#                                           text_tokens  \
# 0   [aplikasi, mudah, hack, kena, dgn, pembelian, ...
# 1                                               [top]
# 2   [dekade, blibli, terpercaya, terdepan, pengiri...
# 3                                     [is, the, best]
# 4   [favorit, belanja, elektronik, online, layanan...
# 5              [membantu, memenuhi, kebutuhan, rumah]
# 6   [sdh, instal, ulang, gak, buka, aplikasinya, t...
# 7                                    [semoga, sukses]
# 8                              [semoga, blibli, maju]
# 9                         [ngak, suka, aja, pakainya]
# 10  [tampilan, aplikasinya, membingungkan, kebanya...
# 11                                            [bagus]
# 12                                            [delay]
# 13  [maaf, kk, skrg, login, aplikasi, gak, diarahk...
# 14  [bagus, bagus, semoga, kedepannya, blibli, sho...
# 15                                               [ok]
# 16                                          [mencoba]
# 17                                            [bagus]
# 18                           [ajhieb, bin, marqothop]
# 19                                  [mantap, berguna]
#
#                                        text_steamindo
# 0   aplikasi mudah hack kena dgn beli dicancel hac...
# 1                                                 top
# 2   dekade blibli percaya depan kirim free ongkirn...
# 3                                         is the best
# 4   favorit belanja elektronik online layan ok ban...
# 5                             bantu penuh butuh rumah
# 6      sdh instal ulang gak buka aplikasi tolong baik
# 7                                         moga sukses
# 8                                    moga blibli maju
# 9                                 ngak suka aja pakai
# 10  tampil aplikasi bingung banyak animasi ganggu ...
# 11                                              bagus
# 12                                              delay
# 13  maaf kk skrg login aplikasi gak arah browser l...
# 14  bagus bagus moga depan blibli shoppe gila ntah...
# 15                                                 ok
# 16                                               coba
# 17                                              bagus
# 18                               ajhieb bin marqothop
# 19                                        mantap guna

# %%
data_clean.to_csv('blibli.csv', index= False) #kemudian simpan hasil text preprocessing ke file csv
