# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
import google_play_scraper

# %%
app_id = 'com.tokopedia.tkpd'

# %%
from google_play_scraper import Sort
from google_play_scraper.constants.element import ElementSpecs
from google_play_scraper.constants.regex import Regex
from google_play_scraper.constants.request import Formats
from google_play_scraper.utils.request import post

import pandas as pd
from datetime import datetime
from tqdm import tqdm
import time
import json
from time import sleep
from typing import List, Optional, Tuple

# %%
MAX_COUNT_EACH_FETCH = 199


class _ContinuationToken:
    __slots__ = (
        "token",
        "lang",
        "country",
        "sort",
        "count",
        "filter_score_with",
        "filter_device_with",
    )

    def __init__(
        self, token, lang, country, sort, count, filter_score_with, filter_device_with
    ):
        self.token = token
        self.lang = lang
        self.country = country
        self.sort = sort
        self.count = count
        self.filter_score_with = filter_score_with
        self.filter_device_with = filter_device_with


def _fetch_review_items(
    url: str,
    app_id: str,
    sort: int,
    count: int,
    filter_score_with: Optional[int],
    filter_device_with: Optional[int],
    pagination_token: Optional[str],
):
    dom = post(
        url,
        Formats.Reviews.build_body(
            app_id,
            sort,
            count,
            "null" if filter_score_with is None else filter_score_with,
            "null" if filter_device_with is None else filter_device_with,
            pagination_token,
        ),
        {"content-type": "application/x-www-form-urlencoded"},
    )
    match = json.loads(Regex.REVIEWS.findall(dom)[0])

    return json.loads(match[0][2])[0], json.loads(match[0][2])[-2][-1]


def reviews(
    app_id: str,
    lang: str = "en",
    country: str = "us",
    sort: Sort = Sort.MOST_RELEVANT,
    count: int = 100,
    filter_score_with: int = None,
    filter_device_with: int = None,
    continuation_token: _ContinuationToken = None,
) -> Tuple[List[dict], _ContinuationToken]:
    sort = sort.value

    if continuation_token is not None:
        token = continuation_token.token

        if token is None:
            return (
                [],
                continuation_token,
            )

        lang = continuation_token.lang
        country = continuation_token.country
        sort = continuation_token.sort
        count = continuation_token.count
        filter_score_with = continuation_token.filter_score_with
        filter_device_with = continuation_token.filter_device_with
    else:
        token = None

    url = Formats.Reviews.build(lang=lang, country=country)

    _fetch_count = count

    result = []

    while True:
        if _fetch_count == 0:
            break

        if _fetch_count > MAX_COUNT_EACH_FETCH:
            _fetch_count = MAX_COUNT_EACH_FETCH

        try:
            review_items, token = _fetch_review_items(
                url,
                app_id,
                sort,
                _fetch_count,
                filter_score_with,
                filter_device_with,
                token,
            )
        except (TypeError, IndexError):
            #funnan MOD start
            token = continuation_token.token
            continue
            #MOD end

        for review in review_items:
            result.append(
                {
                    k: spec.extract_content(review)
                    for k, spec in ElementSpecs.Review.items()
                }
            )

        _fetch_count = count - len(result)

        if isinstance(token, list):
            token = None
            break

    return (
        result,
        _ContinuationToken(
            token, lang, country, sort, count, filter_score_with, filter_device_with
        ),
    )


def reviews_all(app_id: str, sleep_milliseconds: int = 0, **kwargs) -> list:
    kwargs.pop("count", None)
    kwargs.pop("continuation_token", None)

    continuation_token = None

    result = []

    while True:
        _result, continuation_token = reviews(
            app_id,
            count=MAX_COUNT_EACH_FETCH,
            continuation_token=continuation_token,
            **kwargs
        )

        result += _result

        if continuation_token.token is None:
            break

        if sleep_milliseconds:
            sleep(sleep_milliseconds / 1000)

    return result

# %%
reviews_count = 10000

# %%
result = []
continuation_token = None


with tqdm(total=reviews_count, position=0, leave=True) as pbar:
    while len(result) < reviews_count:
        new_result, continuation_token = reviews(
            app_id,
            continuation_token=continuation_token,
            lang='id', #The language of review
            country='id', #Country for which you want to scrape
            sort=Sort.NEWEST,
            filter_score_with=None,
            count=199 #No need to change this
        )
        if not new_result:
            break
        result.extend(new_result)
        pbar.update(len(new_result))
# Out:
# 10149it [00:12, 837.70it/s]

# %%
import numpy as np
df = pd.DataFrame(np.array(result),columns=['review'])

df = df.join(pd.DataFrame(df.pop('review').tolist()))

df.head(20)
# Out:
#                                 reviewId                  userName  \
# 0   29c522fc-5fb1-4aec-9685-545b54d32ccf               Asep Ridwan
# 1   8e58ec7e-1558-4bdc-a5a1-183c982a2314              Marini Putri
# 2   042688db-fa7c-4b54-8213-a92698236b04             Andik Widjaya
# 3   51759b1b-8861-47b3-ab30-b4c36935b2e6                      Divv
# 4   4a09ebcf-644e-413c-8213-90c9274050cb             Bella Cantika
# 5   309ee5c7-ecfb-4a5d-bb7f-7abebe94e93c           Muhammad Fauzan
# 6   b7721003-fca1-4d19-bdb3-36c0fce8042c              Umar Alfaruq
# 7   d29d7d14-bd12-4f82-b653-094159a3365a              Imam Bahrain
# 8   579bd221-e3e2-45ed-b7c2-6e0e93bd3ee1             Riza Fikriyah
# 9   3cd73b81-4cbd-4ae6-8033-e8555cbe4d90  riris yuli endah lestari
# 10  785998e5-8f2e-4ec7-925d-1a71be05f0b5             ricky bahtiar
# 11  be677ef1-2c40-4a22-bd36-ffa9b70f5d65               Agus Sofyan
# 12  e4665a86-897b-4beb-8526-0283c448db63                Rida Junme
# 13  352c918c-1b75-4755-a6e5-286d232f2f64                 Deku Cole
# 14  97befd5e-1429-4f18-9726-7aa34061d30b                Fajar Alam
# 15  7bf35db3-9e78-4512-b7eb-66b272e7f85c               Fahmi Rizal
# 16  7a3404ae-6f12-4f95-b926-e3648f56d6d3             GALA OFFICIAL
# 17  6582e5df-a2cb-45ea-a87e-d428c085fe12             Yogi Prasetyo
# 18  63c527c5-fae4-4e8b-9f3a-5b8fbde1990d           Rifqi Nasta'iin
# 19  7a3c8d5a-d68f-4640-9e1e-d46ac1162f93              dede gunawan
#
#                                             userImage  \
# 0   https://play-lh.googleusercontent.com/a-/ALV-U...
# 1   https://play-lh.googleusercontent.com/a-/ALV-U...
# 2   https://play-lh.googleusercontent.com/a-/ALV-U...
# 3   https://play-lh.googleusercontent.com/a/ACg8oc...
# 4   https://play-lh.googleusercontent.com/a/ACg8oc...
# 5   https://play-lh.googleusercontent.com/a-/ALV-U...
# 6   https://play-lh.googleusercontent.com/a/ACg8oc...
# 7   https://play-lh.googleusercontent.com/a-/ALV-U...
# 8   https://play-lh.googleusercontent.com/a/ACg8oc...
# 9   https://play-lh.googleusercontent.com/a/ACg8oc...
# 10  https://play-lh.googleusercontent.com/a-/ALV-U...
# 11  https://play-lh.googleusercontent.com/a-/ALV-U...
# 12  https://play-lh.googleusercontent.com/a-/ALV-U...
# 13  https://play-lh.googleusercontent.com/a-/ALV-U...
# 14  https://play-lh.googleusercontent.com/a-/ALV-U...
# 15  https://play-lh.googleusercontent.com/a-/ALV-U...
# 16  https://play-lh.googleusercontent.com/a-/ALV-U...
# 17  https://play-lh.googleusercontent.com/a/ACg8oc...
# 18  https://play-lh.googleusercontent.com/a/ACg8oc...
# 19  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                                               content  score  thumbsUpCount  \
# 0   aplikasi paling complete nyaman cepat terperca...      5              0
# 1   Lemot bgt, pas dicancel malahan vouchernya ang...      1              0
# 2        Apk sampah loading Mulu waktu mau pembayaran      1              0
# 3   APK GAJELASS ANJJJ, BARU PERTAMA KALI BUAT AKU...      1              0
# 4                                     Tokopedia bagus      5              0
# 5   Sejak ada kurir rekomendasi, pengiriman malah ...      3              1
# 6                       makasih mantap aplikasinya👍👍👍      5              0
# 7                                               keren      5              0
# 8                  bagusss, tmbhn diskonnya yaaa.....      5              0
# 9   sebernya suka cuma kenapa dana ferund di bawah...      3              0
# 10                     Kurir next day rasa reguler...      1              1
# 11  Kepada pihak Tokopedia... kalau mau bikin ikla...      1              0
# 12       Kenapa sekarang ga ada pilihan jumlah barang      5              0
# 13  Ini ckp sekali gw belanja di sini, barang priv...      1              0
# 14                                             mantap      5              0
# 15        Tidak bisa cod saya padahal ga pernah retur      1              0
# 16                                               baik      5              0
# 17               apps langganan buat berbayar online👍      5              0
# 18                                              Bagus      5              0
# 19                                             mantap      4              0
#
#    reviewCreatedVersion                  at  \
# 0                 3.267 2024-06-14 15:37:09
# 1                 3.267 2024-06-14 15:35:51
# 2                 3.267 2024-06-14 15:33:31
# 3                 3.267 2024-06-14 15:06:53
# 4                  None 2024-06-14 14:57:40
# 5               3.247.1 2024-06-14 14:53:05
# 6                 3.266 2024-06-14 14:49:35
# 7                 3.267 2024-06-14 14:29:37
# 8                 3.267 2024-06-14 14:26:56
# 9                 3.267 2024-06-14 14:13:36
# 10                3.266 2024-06-14 14:13:04
# 11                3.265 2024-06-14 14:06:07
# 12                3.267 2024-06-14 14:03:43
# 13                3.266 2024-06-14 13:59:57
# 14                3.266 2024-06-14 13:58:11
# 15                3.265 2024-06-14 13:49:25
# 16                3.267 2024-06-14 13:49:20
# 17                3.264 2024-06-14 13:48:43
# 18                3.267 2024-06-14 13:45:52
# 19                3.267 2024-06-14 13:43:44
#
#                                          replyContent           repliedAt  \
# 0   Toppers, terima kasih atas rating yang kamu be... 2024-06-14 15:40:03
# 1   Hi Toppers, silakan sampaikan kritik/saran ata... 2024-06-14 15:40:07
# 2   Toppers, mohon maaf atas kendala yang kamu ala... 2024-06-14 15:40:04
# 3   Halo Toppers, terima kasih atas rating yang ka... 2024-06-14 15:20:05
# 4   Hi Toppers, terima kasih untuk rating dan ulas... 2024-06-14 15:00:04
# 5   Terima kasih atas rating yang kamu berikan, To... 2024-06-14 15:00:03
# 6   Hi Toppers, terima kasih untuk rating dan ulas... 2024-06-14 15:00:05
# 7   Toppers, terima kasih atas rating yang kamu be... 2024-06-14 14:40:02
# 8   Toppers, terima kasih atas rating yang kamu be... 2024-06-14 14:40:05
# 9   Terima kasih atas rating yang kamu berikan, To... 2024-06-14 14:20:15
# 10  Halo Toppers, terima kasih atas rating yang ka... 2024-06-14 14:20:03
# 11  Halo Toppers, terima kasih atas rating yang ka... 2024-06-14 14:20:09
# 12  Hi Toppers, terima kasih untuk rating dan ulas... 2024-06-14 14:20:08
# 13  Halo Toppers, terima kasih atas rating yang ka... 2024-06-14 14:20:11
# 14  Hi Toppers, terima kasih untuk rating dan ulas... 2024-06-14 14:00:15
# 15  Toppers, mohon maaf atas kendala yang kamu ala... 2024-06-14 14:00:06
# 16  Toppers, terima kasih atas rating yang kamu be... 2024-06-14 14:00:14
# 17  Terima kasih sudah mempercayakan Tokopedia seb... 2024-06-14 14:00:12
# 18  Terima kasih sudah mempercayakan Tokopedia seb... 2024-06-14 14:00:07
# 19  Toppers, terima kasih atas rating yang kamu be... 2024-06-14 14:00:10
#
#    appVersion
# 0       3.267
# 1       3.267
# 2       3.267
# 3       3.267
# 4        None
# 5     3.247.1
# 6       3.266
# 7       3.267
# 8       3.267
# 9       3.267
# 10      3.266
# 11      3.265
# 12      3.267
# 13      3.266
# 14      3.266
# 15      3.265
# 16      3.267
# 17      3.264
# 18      3.267
# 19      3.267

# %%
len(df)
# Out:
# 10149

# %%
df[['userName', 'score','at', 'content']].head(20)  #dari scrapping tsb didapatkan banyak sekali kolom, kemudian kolom" tsb kita filter
                                                        #sehingga didapatkan kolom username, score, at dan content
# Out:
#                     userName  score                  at  \
# 0                Asep Ridwan      5 2024-06-14 15:37:09
# 1               Marini Putri      1 2024-06-14 15:35:51
# 2              Andik Widjaya      1 2024-06-14 15:33:31
# 3                       Divv      1 2024-06-14 15:06:53
# 4              Bella Cantika      5 2024-06-14 14:57:40
# 5            Muhammad Fauzan      3 2024-06-14 14:53:05
# 6               Umar Alfaruq      5 2024-06-14 14:49:35
# 7               Imam Bahrain      5 2024-06-14 14:29:37
# 8              Riza Fikriyah      5 2024-06-14 14:26:56
# 9   riris yuli endah lestari      3 2024-06-14 14:13:36
# 10             ricky bahtiar      1 2024-06-14 14:13:04
# 11               Agus Sofyan      1 2024-06-14 14:06:07
# 12                Rida Junme      5 2024-06-14 14:03:43
# 13                 Deku Cole      1 2024-06-14 13:59:57
# 14                Fajar Alam      5 2024-06-14 13:58:11
# 15               Fahmi Rizal      1 2024-06-14 13:49:25
# 16             GALA OFFICIAL      5 2024-06-14 13:49:20
# 17             Yogi Prasetyo      5 2024-06-14 13:48:43
# 18           Rifqi Nasta'iin      5 2024-06-14 13:45:52
# 19              dede gunawan      4 2024-06-14 13:43:44
#
#                                               content
# 0   aplikasi paling complete nyaman cepat terperca...
# 1   Lemot bgt, pas dicancel malahan vouchernya ang...
# 2        Apk sampah loading Mulu waktu mau pembayaran
# 3   APK GAJELASS ANJJJ, BARU PERTAMA KALI BUAT AKU...
# 4                                     Tokopedia bagus
# 5   Sejak ada kurir rekomendasi, pengiriman malah ...
# 6                       makasih mantap aplikasinya👍👍👍
# 7                                               keren
# 8                  bagusss, tmbhn diskonnya yaaa.....
# 9   sebernya suka cuma kenapa dana ferund di bawah...
# 10                     Kurir next day rasa reguler...
# 11  Kepada pihak Tokopedia... kalau mau bikin ikla...
# 12       Kenapa sekarang ga ada pilihan jumlah barang
# 13  Ini ckp sekali gw belanja di sini, barang priv...
# 14                                             mantap
# 15        Tidak bisa cod saya padahal ga pernah retur
# 16                                               baik
# 17               apps langganan buat berbayar online👍
# 18                                              Bagus
# 19                                             mantap

# %%
df=df[['content', 'score']]#karena kita hanya membutuhkan kolom content dan score maka kita lakukan filter kolom lgi hing
df.head(20)
# Out:
#                                               content  score
# 0   aplikasi paling complete nyaman cepat terperca...      5
# 1   Lemot bgt, pas dicancel malahan vouchernya ang...      1
# 2        Apk sampah loading Mulu waktu mau pembayaran      1
# 3   APK GAJELASS ANJJJ, BARU PERTAMA KALI BUAT AKU...      1
# 4                                     Tokopedia bagus      5
# 5   Sejak ada kurir rekomendasi, pengiriman malah ...      3
# 6                       makasih mantap aplikasinya👍👍👍      5
# 7                                               keren      5
# 8                  bagusss, tmbhn diskonnya yaaa.....      5
# 9   sebernya suka cuma kenapa dana ferund di bawah...      3
# 10                     Kurir next day rasa reguler...      1
# 11  Kepada pihak Tokopedia... kalau mau bikin ikla...      1
# 12       Kenapa sekarang ga ada pilihan jumlah barang      5
# 13  Ini ckp sekali gw belanja di sini, barang priv...      1
# 14                                             mantap      5
# 15        Tidak bisa cod saya padahal ga pernah retur      1
# 16                                               baik      5
# 17               apps langganan buat berbayar online👍      5
# 18                                              Bagus      5
# 19                                             mantap      4

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10149 entries, 0 to 10148
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  10149 non-null  object
#  1   score    10149 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 158.7+ KB

# %%
df.isna()
# Out:
#        content  score
# 0        False  False
# 1        False  False
# 2        False  False
# 3        False  False
# 4        False  False
# ...        ...    ...
# 10144    False  False
# 10145    False  False
# 10146    False  False
# 10147    False  False
# 10148    False  False
#
# [10149 rows x 2 columns]

# %%
df.describe()
# Out:
#               score
# count  10149.000000
# mean       3.168292
# std        1.869157
# min        1.000000
# 25%        1.000000
# 50%        4.000000
# 75%        5.000000
# max        5.000000

# %%
df.isnull().sum()
# Out:
# content    0
# score      0
# dtype: int64

# %%
df.to_csv("hasil-scrap-tokopedia.csv", index = False) #simpan csv

# %% [markdown]
# # **PREPROCESSING**

# %% [markdown]
# Case Folding

# %%
import re
def  clean_text(df, text_field, new_text_field_name):
    df[new_text_field_name] = df[text_field].str.lower()
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    # remove numbers
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
    return df

# %%
df['text_clean'] = df['content'].str.lower()
df['text_clean']
data_clean = clean_text(df, 'content', 'text_clean')
data_clean.head(20)
# Out:
#                                               content  score  \
# 0   aplikasi paling complete nyaman cepat terperca...      5
# 1   Lemot bgt, pas dicancel malahan vouchernya ang...      1
# 2        Apk sampah loading Mulu waktu mau pembayaran      1
# 3   APK GAJELASS ANJJJ, BARU PERTAMA KALI BUAT AKU...      1
# 4                                     Tokopedia bagus      5
# 5   Sejak ada kurir rekomendasi, pengiriman malah ...      3
# 6                       makasih mantap aplikasinya👍👍👍      5
# 7                                               keren      5
# 8                  bagusss, tmbhn diskonnya yaaa.....      5
# 9   sebernya suka cuma kenapa dana ferund di bawah...      3
# 10                     Kurir next day rasa reguler...      1
# 11  Kepada pihak Tokopedia... kalau mau bikin ikla...      1
# 12       Kenapa sekarang ga ada pilihan jumlah barang      5
# 13  Ini ckp sekali gw belanja di sini, barang priv...      1
# 14                                             mantap      5
# 15        Tidak bisa cod saya padahal ga pernah retur      1
# 16                                               baik      5
# 17               apps langganan buat berbayar online👍      5
# 18                                              Bagus      5
# 19                                             mantap      4
#
#                                            text_clean
# 0   aplikasi paling complete nyaman cepat terperca...
# 1   lemot bgt pas dicancel malahan vouchernya angu...
# 2        apk sampah loading mulu waktu mau pembayaran
# 3   apk gajelass anjjj baru pertama kali buat akun...
# 4                                     tokopedia bagus
# 5   sejak ada kurir rekomendasi pengiriman malah j...
# 6                          makasih mantap aplikasinya
# 7                                               keren
# 8                        bagusss tmbhn diskonnya yaaa
# 9   sebernya suka cuma kenapa dana ferund di bawah...
# 10                        kurir next day rasa reguler
# 11  kepada pihak tokopedia kalau mau bikin iklan d...
# 12       kenapa sekarang ga ada pilihan jumlah barang
# 13  ini ckp sekali gw belanja di sini barang priva...
# 14                                             mantap
# 15        tidak bisa cod saya padahal ga pernah retur
# 16                                               baik
# 17                apps langganan buat berbayar online
# 18                                              bagus
# 19                                             mantap

# %% [markdown]
# Stopword Removal

# %%
import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('indonesian')
data_clean['text_StopWord'] = data_clean['text_clean'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop)]))
data_clean.head(50)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                               content  score  \
# 0   aplikasi paling complete nyaman cepat terperca...      5
# 1   Lemot bgt, pas dicancel malahan vouchernya ang...      1
# 2        Apk sampah loading Mulu waktu mau pembayaran      1
# 3   APK GAJELASS ANJJJ, BARU PERTAMA KALI BUAT AKU...      1
# 4                                     Tokopedia bagus      5
# 5   Sejak ada kurir rekomendasi, pengiriman malah ...      3
# 6                       makasih mantap aplikasinya👍👍👍      5
# 7                                               keren      5
# 8                  bagusss, tmbhn diskonnya yaaa.....      5
# 9   sebernya suka cuma kenapa dana ferund di bawah...      3
# 10                     Kurir next day rasa reguler...      1
# 11  Kepada pihak Tokopedia... kalau mau bikin ikla...      1
# 12       Kenapa sekarang ga ada pilihan jumlah barang      5
# 13  Ini ckp sekali gw belanja di sini, barang priv...      1
# 14                                             mantap      5
# 15        Tidak bisa cod saya padahal ga pernah retur      1
# 16                                               baik      5
# 17               apps langganan buat berbayar online👍      5
# 18                                              Bagus      5
# 19                                             mantap      4
# 20  Pilih Jasa expedisi manapun tetep ajah lama se...      1
# 21  Pelit sama vocher ,tidak sesuai, kok dikit2 di...      1
# 22                                             Mantap      5
# 23  sangat rekomendasi banget tokopedia terima kas...      5
# 24                                               baik      5
# 25                                                oke      5
# 26                                             mantab      5
# 27  Sebagai penjual, Market place ini paling bagus...      5
# 28  sangat kecewa pakai kurir rekomendasi, sdh sem...      2
# 29                                    Banner COD hoax      1
# 30                                           ok ok ok      5
# 31  Parah.. baru pertama kali transaksi udah senen...      1
# 32  Sudah bertahun tahun pakai aplikasi toped, tap...      1
# 33  CS Tokopedia paling sombong diantara semua CS ...      1
# 34  niat mau cari diskon pake akun ibuk tpi malah ...      1
# 35  Saya pengguna baru Tokopedia, dan transaksi pa...      1
# 36  proses claim saldo kembali saat barang hilang ...      1
# 37  Gw bayar pake kredivo malah masih menunggu pem...      1
# 38                                            nais...      5
# 39       Kalo ga niat bikin promo mending ga usah dah      1
# 40  Soal ya kalau pake wifi lama kalau pake kaota ...      5
# 41                                               Nice      5
# 42             terimakasih berguna untuk pembelanjaan      5
# 43                                         99% mantap      5
# 44      tokopedia luaaarrr biasaaa,yang lain lewaatt5      5
# 45  Tokopedia tidak punya Customer service dan sol...      1
# 46                                ongkirnya ga ngotak      1
# 47                                      Alhamdulillah      4
# 48                                   toko pedia keren      5
# 49                                             mantap      5
#
#                                            text_clean  \
# 0   aplikasi paling complete nyaman cepat terperca...
# 1   lemot bgt pas dicancel malahan vouchernya angu...
# 2        apk sampah loading mulu waktu mau pembayaran
# 3   apk gajelass anjjj baru pertama kali buat akun...
# 4                                     tokopedia bagus
# 5   sejak ada kurir rekomendasi pengiriman malah j...
# 6                          makasih mantap aplikasinya
# 7                                               keren
# 8                        bagusss tmbhn diskonnya yaaa
# 9   sebernya suka cuma kenapa dana ferund di bawah...
# 10                        kurir next day rasa reguler
# 11  kepada pihak tokopedia kalau mau bikin iklan d...
# 12       kenapa sekarang ga ada pilihan jumlah barang
# 13  ini ckp sekali gw belanja di sini barang priva...
# 14                                             mantap
# 15        tidak bisa cod saya padahal ga pernah retur
# 16                                               baik
# 17                apps langganan buat berbayar online
# 18                                              bagus
# 19                                             mantap
# 20  pilih jasa expedisi manapun tetep ajah lama se...
# 21  pelit sama vocher tidak sesuai kok dikit di ba...
# 22                                             mantap
# 23  sangat rekomendasi banget tokopedia terima kas...
# 24                                               baik
# 25                                                oke
# 26                                             mantab
# 27  sebagai penjual market place ini paling bagus ...
# 28  sangat kecewa pakai kurir rekomendasi sdh semi...
# 29                                    banner cod hoax
# 30                                           ok ok ok
# 31  parah baru pertama kali transaksi udah seneng ...
# 32  sudah bertahun tahun pakai aplikasi toped tapi...
# 33  cs tokopedia paling sombong diantara semua cs ...
# 34  niat mau cari diskon pake akun ibuk tpi malah ...
# 35  saya pengguna baru tokopedia dan transaksi pak...
# 36  proses claim saldo kembali saat barang hilang ...
# 37  gw bayar pake kredivo malah masih menunggu pem...
# 38                                               nais
# 39       kalo ga niat bikin promo mending ga usah dah
# 40  soal ya kalau pake wifi lama kalau pake kaota ...
# 41                                               nice
# 42             terimakasih berguna untuk pembelanjaan
# 43                                             mantap
# 44        tokopedia luaaarrr biasaaayang lain lewaatt
# 45  tokopedia tidak punya customer service dan sol...
# 46                                ongkirnya ga ngotak
# 47                                      alhamdulillah
# 48                                   toko pedia keren
# 49                                             mantap
#
#                                         text_StopWord
# 0   aplikasi complete nyaman cepat terpercaya teri...
# 1         lemot bgt pas dicancel vouchernya angus fak
# 2                  apk sampah loading mulu pembayaran
# 3   apk gajelass anjjj kali akun pesanan dibatalka...
# 4                                     tokopedia bagus
# 5   kurir rekomendasi pengiriman jarak kota berdek...
# 6                          makasih mantap aplikasinya
# 7                                               keren
# 8                        bagusss tmbhn diskonnya yaaa
# 9    sebernya suka dana ferund ngk ditarik belanjakan
# 10                             kurir next day reguler
# 11  tokopedia bikin iklan game dialihkan paksa pla...
# 12                                  ga pilihan barang
# 13  ckp gw belanja barang privat gw dibuka kulirny...
# 14                                             mantap
# 15                                       cod ga retur
# 16
# 17                     apps langganan berbayar online
# 18                                              bagus
# 19                                             mantap
# 20  pilih jasa expedisi manapun tetep ajah kalah a...
# 21  pelit vocher sesuai dikit batalkan sistem tolo...
# 22                                             mantap
# 23  rekomendasi banget tokopedia terima kasih laya...
# 24
# 25                                                oke
# 26                                             mantab
# 27  penjual market place bagus menu fitur mudah pa...
# 28  kecewa pakai kurir rekomendasi sdh seminggu ba...
# 29                                    banner cod hoax
# 30                                           ok ok ok
# 31  parah kali transaksi udah seneng dapet voucher...
# 32  bertahun pakai aplikasi toped expedisi bebas o...
# 33  cs tokopedia sombong cs sejenisnya membantu me...
# 34    niat cari diskon pake akun ibuk tpi ngrasa tipu
# 35  pengguna tokopedia transaksi pakai voucer rp b...
# 36       proses claim saldo barang hilang plis banget
# 37          gw bayar pake kredivo menunggu pembayaran
# 38                                               nais
# 39            kalo ga niat bikin promo mending ga dah
# 40                ya pake wifi pake kaota cepat kilat
# 41                                               nice
# 42                   terimakasih berguna pembelanjaan
# 43                                             mantap
# 44             tokopedia luaaarrr biasaaayang lewaatt
# 45  tokopedia customer service solusi cuman robot ...
# 46                                ongkirnya ga ngotak
# 47                                      alhamdulillah
# 48                                   toko pedia keren
# 49                                             mantap

# %% [markdown]
# **Tokenizing**

# %%
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
data_clean['text_tokens'] = data_clean['text_StopWord'].apply(lambda x: word_tokenize(x))
data_clean.head(20)
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                                               content  score  \
# 0   aplikasi paling complete nyaman cepat terperca...      5
# 1   Lemot bgt, pas dicancel malahan vouchernya ang...      1
# 2        Apk sampah loading Mulu waktu mau pembayaran      1
# 3   APK GAJELASS ANJJJ, BARU PERTAMA KALI BUAT AKU...      1
# 4                                     Tokopedia bagus      5
# 5   Sejak ada kurir rekomendasi, pengiriman malah ...      3
# 6                       makasih mantap aplikasinya👍👍👍      5
# 7                                               keren      5
# 8                  bagusss, tmbhn diskonnya yaaa.....      5
# 9   sebernya suka cuma kenapa dana ferund di bawah...      3
# 10                     Kurir next day rasa reguler...      1
# 11  Kepada pihak Tokopedia... kalau mau bikin ikla...      1
# 12       Kenapa sekarang ga ada pilihan jumlah barang      5
# 13  Ini ckp sekali gw belanja di sini, barang priv...      1
# 14                                             mantap      5
# 15        Tidak bisa cod saya padahal ga pernah retur      1
# 16                                               baik      5
# 17               apps langganan buat berbayar online👍      5
# 18                                              Bagus      5
# 19                                             mantap      4
#
#                                            text_clean  \
# 0   aplikasi paling complete nyaman cepat terperca...
# 1   lemot bgt pas dicancel malahan vouchernya angu...
# 2        apk sampah loading mulu waktu mau pembayaran
# 3   apk gajelass anjjj baru pertama kali buat akun...
# 4                                     tokopedia bagus
# 5   sejak ada kurir rekomendasi pengiriman malah j...
# 6                          makasih mantap aplikasinya
# 7                                               keren
# 8                        bagusss tmbhn diskonnya yaaa
# 9   sebernya suka cuma kenapa dana ferund di bawah...
# 10                        kurir next day rasa reguler
# 11  kepada pihak tokopedia kalau mau bikin iklan d...
# 12       kenapa sekarang ga ada pilihan jumlah barang
# 13  ini ckp sekali gw belanja di sini barang priva...
# 14                                             mantap
# 15        tidak bisa cod saya padahal ga pernah retur
# 16                                               baik
# 17                apps langganan buat berbayar online
# 18                                              bagus
# 19                                             mantap
#
#                                         text_StopWord  \
# 0   aplikasi complete nyaman cepat terpercaya teri...
# 1         lemot bgt pas dicancel vouchernya angus fak
# 2                  apk sampah loading mulu pembayaran
# 3   apk gajelass anjjj kali akun pesanan dibatalka...
# 4                                     tokopedia bagus
# 5   kurir rekomendasi pengiriman jarak kota berdek...
# 6                          makasih mantap aplikasinya
# 7                                               keren
# 8                        bagusss tmbhn diskonnya yaaa
# 9    sebernya suka dana ferund ngk ditarik belanjakan
# 10                             kurir next day reguler
# 11  tokopedia bikin iklan game dialihkan paksa pla...
# 12                                  ga pilihan barang
# 13  ckp gw belanja barang privat gw dibuka kulirny...
# 14                                             mantap
# 15                                       cod ga retur
# 16
# 17                     apps langganan berbayar online
# 18                                              bagus
# 19                                             mantap
#
#                                           text_tokens
# 0   [aplikasi, complete, nyaman, cepat, terpercaya...
# 1   [lemot, bgt, pas, dicancel, vouchernya, angus,...
# 2            [apk, sampah, loading, mulu, pembayaran]
# 3   [apk, gajelass, anjjj, kali, akun, pesanan, di...
# 4                                  [tokopedia, bagus]
# 5   [kurir, rekomendasi, pengiriman, jarak, kota, ...
# 6                      [makasih, mantap, aplikasinya]
# 7                                             [keren]
# 8                   [bagusss, tmbhn, diskonnya, yaaa]
# 9   [sebernya, suka, dana, ferund, ngk, ditarik, b...
# 10                        [kurir, next, day, reguler]
# 11  [tokopedia, bikin, iklan, game, dialihkan, pak...
# 12                              [ga, pilihan, barang]
# 13  [ckp, gw, belanja, barang, privat, gw, dibuka,...
# 14                                           [mantap]
# 15                                   [cod, ga, retur]
# 16                                                 []
# 17                [apps, langganan, berbayar, online]
# 18                                            [bagus]
# 19                                           [mantap]

# %% [markdown]
# **Stemming**

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 1.9 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
#-----------------STEMMING -----------------
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
#import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}
hitung=0

for document in data_clean['text_tokens']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")
for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    hitung+=1
    print(hitung,":",term,":" ,term_dict[term])

print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]


#script ini bisa dipisah dari eksekusinya setelah pembacaaan term selesai
data_clean['text_steamindo'] = data_clean['text_tokens'].apply(lambda x:' '.join(get_stemmed_term(x)))
data_clean.head(20)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# 6296 : roda : roda
# 6297 : ekspedisipadahal : ekspedisipadahal
# 6298 : nyangeri : nyangeri
# 6299 : mesi : mes
# 6300 : merusak : rusak
# 6301 : atuh : atuh
# 6302 : gratisan : gratis
# 6303 : ecommere : ecommere
# 6304 : dimalingin : dimalingin
# 6305 : aset : aset
# 6306 : amankan : aman
# 6307 : don : don
# 6308 : katepe : katepe
# 6309 : semuah : semuah
# 6310 : kuasai : kuasa
# 6311 : olek : olek
# 6312 : mendapak : mendapak
# 6313 : ida : ida
# 6314 : iklimah : iklimah
# 6315 : minjam : minjam
# 6316 : pemilikkarena : pemilikkarena
# 6317 : siiip : siiip
# 6318 : searchinghasil : searchinghasil
# 6319 : mengutamakan : utama
# 6320 : prosedur : prosedur
# 6321 : dibatlkan : dibatlkan
# 6322 : sragen : sragen
# 6323 : membatasi : batas
# 6324 : seringsering : seringsering
# 6325 : chattingan : chattingan
# 6326 : menghabiskan : habis
# 6327 : membahas : bahas
# 6328 : saatbikin : saatbikin
# 6329 : sekarangg : sekarangg
# 6330 : apasihhhhhh : apasihhhhhh
# 6331 : nalar : nalar
# 6332 : gilakk : gilakk
# 6333 : beberapakali : beberapakali
# 6334 : perna : perna
# 6335 : tlpn : tlpn
# 6336 : inggu : inggu
# 6337 : penjelasin : penjelasin
# 6338 : selesaikan : selesai
# 6339 : pencuri : curi
# 6340 : aplikasinyalebih : aplikasinyalebih
# 6341 : paketkalau : paketkalau
# 6342 : jtjneatau : jtjneatau
# 6343 : indonesiabuang : indonesiabuang
# 6344 : sapxtiap : sapxtiap
# 6345 : merek : merek
# 6346 : itupengirimannya : itupengirimannya
# 6347 : terkirimmendingan : terkirimmendingan
# 6348 : dehada : dehada
# 6349 : klepot : klepot
# 6350 : kerennnnn : kerennnnn
# 6351 : nyamantap : nyamantap
# 6352 : ngab : ngab
# 6353 : apalg : apalg
# 6354 : sayur : sayur
# 6355 : mayur : mayur
# 6356 : pasar : pasar
# 6357 : tradisional : tradisional
# 6358 : anehh : anehh
# 6359 : menggu : menggu
# 6360 : kenadala : kenadala
# 6361 : balesanya : balesanya
# 6362 : berjam : jam
# 6363 : penyebab : sebab
# 6364 : mtix : mtix
# 6365 : huft : huft
# 6366 : kargo : kargo
# 6367 : jan : jan
# 6368 : njir : njir
# 6369 : invest : invest
# 6370 : reksadana : reksadana
# 6371 : windi : windi
# 6372 : penyelesaiansampah : penyelesaiansampah
# 6373 : mempermudahkan : mudah
# 6374 : end : end
# 6375 : banhak : banhak
# 6376 : dmana : dmana
# 6377 : gmaps : gmaps
# 6378 : letak : letak
# 6379 : cirebon : cirebon
# 6380 : undur : undur
# 6381 : kuri : kur
# 6382 : puasss : puasss
# 6383 : bayarkan : bayar
# 6384 : menduga : duga
# 6385 : struktur : struktur
# 6386 : sistematis : sistematis
# 6387 : sanksi : sanksi
# 6388 : castamer : castamer
# 6389 : servisnya : servis
# 6390 : updet : updet
# 6391 : sprti : sprti
# 6392 : browser : browser
# 6393 : aspek : aspek
# 6394 : gile : gile
# 6395 : hak : hak
# 6396 : bermanfaatdan : bermanfaatdan
# 6397 : mencerdaskan : cerdas
# 6398 : penerus : terus
# 6399 : cita : cita
# 6400 : jasanya : jasa
# 6401 : company : company
# 6402 : paylatter : paylatter
# 6403 : masukmasuk : masukmasuk
# 6404 : nie : nie
# 6405 : cobain : cobain
# 6406 : kuy : kuy
# 6407 : becuss : becuss
# 6408 : cancle : cancle
# 6409 : merepotkan : repot
# 6410 : baaaaaaggguuuuuuuusssss : baaaaaaggguuuuuuuusssss
# 6411 : huseru : huseru
# 6412 : toap : toap
# 6413 : ff : ff
# 6414 : baguspaket : baguspaket
# 6415 : skkecewa : skkecewa
# 6416 : trushilang : trushilang
# 6417 : eee : eee
# 6418 : unag : unag
# 6419 : ptosea : ptosea
# 6420 : tfk : tfk
# 6421 : bujti : bujti
# 6422 : akunsaya : akunsaya
# 6423 : granadamass : granadamass
# 6424 : hanyadi : hanyadi
# 6425 : sutuh : sutuh
# 6426 : ebtah : ebtah
# 6427 : kereeeen : kereeeen
# 6428 : ngembaliin : ngembaliin
# 6429 : opc : opc
# 6430 : tipunya : tipu
# 6431 : menanggung : tanggung
# 6432 : barangmya : barangmya
# 6433 : ajar : ajar
# 6434 : kepakek : kepakek
# 6435 : pemalu : malu
# 6436 : vcr : vcr
# 6437 : layanangak : layanangak
# 6438 : antaraja : antaraja
# 6439 : kurin : kurin
# 6440 : bebanin : bebanin
# 6441 : konsumenkocak : konsumenkocak
# 6442 : ribetttt : ribetttt
# 6443 : dilihatkan : lihat
# 6444 : sebelahlahh : sebelahlahh
# 6445 : akunterverikasibayar : akunterverikasibayar
# 6446 : ribeettt : ribeettt
# 6447 : konsepnya : konsep
# 6448 : jabodetabekapaapa : jabodetabekapaapa
# 6449 : mahalmau : mahalmau
# 6450 : videoini : videoini
# 6451 : apaharga : apaharga
# 6452 : mahalongkir : mahalongkir
# 6453 : disinikurir : disinikurir
# 6454 : kuotamemory : kuotamemory
# 6455 : ribetttngabisin : ribetttngabisin
# 6456 : antarantar : antarantar
# 6457 : luvvv : luvvv
# 6458 : kalengkaleng : kalengkaleng
# 6459 : berantem : antem
# 6460 : nyawa : nyawa
# 6461 : history : history
# 6462 : tololll : tololll
# 6463 : mlz : mlz
# 6464 : buriq : buriq
# 6465 : ledakan : ledak
# 6466 : nikmat : nikmat
# 6467 : harapkan : harap
# 6468 : benerkan : benerkan
# 6469 : gps : gps
# 6470 : andalkan : andal
# 6471 : situs : situs
# 6472 : beriklan : iklan
# 6473 : woyyy : woyyy
# 6474 : ramadhan : ramadhan
# 6475 : boskuh : boskuh
# 6476 : ente : ente
# 6477 : terbebani : beban
# 6478 : dihilangkannya : hilang
# 6479 : berpindah : pindah
# 6480 : memberatkan : berat
# 6481 : berdampak : dampak
# 6482 : potonganya : potonganya
# 6483 : rued : rued
# 6484 : sekrang : sekrang
# 6485 : digoogle : digoogle
# 6486 : idnama : idnama
# 6487 : bagaimna : bagaimna
# 6488 : dibawah : bawah
# 6489 : she : she
# 6490 : waktunyapayah : waktunyapayah
# 6491 : bagusdari : bagusdari
# 6492 : utamanya : utama
# 6493 : diturunindan : diturunindan
# 6494 : wkwkkws : wkwkkws
# 6495 : hahahha : hahahha
# 6496 : yes : yes
# 6497 : dipindah : pindah
# 6498 : sidoarjo : sidoarjo
# 6499 : sby : sby
# 6500 : terhambat : hambat
# 6501 : aplaus : aplaus
# 6502 : standby : standby
# 6503 : historis : historis
# 6504 : lemah : lemah
# 6505 : uplot : uplot
# 6506 : sejnisnnya : sejnisnnya
# 6507 : anjlok : anjlok
# 6508 : pict : pict
# 6509 : larang : larang
# 6510 : kesimpulanya : kesimpulanya
# 6511 : isntall : isntall
# 6512 : menjembatani : jembatan
# 6513 : baguzsmembantu : baguzsmembantu
# 6514 : pembaruan : baru
# 6515 : gapunya : gapunya
# 6516 : dimainin : dimainin
# 6517 : hatur : hatur
# 6518 : mudahmurahramah : mudahmurahramah
# 6519 : akangkah : akang
# 6520 : tiadakan : tiada
# 6521 : fahami : fahami
# 6522 : umk : umk
# 6523 : tambahkah : tambah
# 6524 : tokopediasering : tokopediasering
# 6525 : berulangkali : berulangkali
# 6526 : mantaptapi : mantaptapi
# 6527 : tapicara : tapicara
# 6528 : ambilnya : ambil
# 6529 : bocil : bocil
# 6530 : sulittidak : sulittidak
# 6531 : coins : coins
# 6532 : memfasilitasi : fasilitas
# 6533 : loss : loss
# 6534 : variasinya : variasi
# 6535 : hrg : hrg
# 6536 : murceeeeee : murceeeeee
# 6537 : yadi : yad
# 6538 : jozzz : jozzz
# 6539 : ceklis : ceklis
# 6540 : keatas : atas
# 6541 : sdngkn : sdngkn
# 6542 : brng : brng
# 6543 : dliat : dliat
# 6544 : okokok : okokok
# 6545 : seburukburuk : seburukburuk
# 6546 : dibenerin : dibenerin
# 6547 : botnya : bot
# 6548 : diakehi : diakehi
# 6549 : nee : nee
# 6550 : nylesein : nylesein
# 6551 : sake : sake
# 6552 : saptu : saptu
# 6553 : jelimet : jelimet
# 6554 : shooping : shooping
# 6555 : normalrusak : normalrusak
# 6556 : terbarunya : baru
# 6557 : tertinggi : tinggi
# 6558 : ribetmantaaabbb : ribetmantaaabbb
# 6559 : payaaah : payaaah
# 6560 : reting : reting
# 6561 : bsamlh : bsamlh
# 6562 : wif : wif
# 6563 : disimpan : simpan
# 6564 : diwishlist : diwishlist
# 6565 : chek : chek
# 6566 : meresahkan : resah
# 6567 : sekrng : sekrng
# 6568 : nabung : nabung
# 6569 : bjsa : bjsa
# 6570 : transaksibiasaya : transaksibiasaya
# 6571 : pembualatan : pembualatan
# 6572 : emastolong : emastolong
# 6573 : nabungklo : nabungklo
# 6574 : tokpedsuka : tokpedsuka
# 6575 : disinitapiitiap : disinitapiitiap
# 6576 : streaming : streaming
# 6577 : terusssapalagi : terusssapalagi
# 6578 : pengukur : ukur
# 6579 : telur : telur
# 6580 : rebus : rebus
# 6581 : fryer : fryer
# 6582 : kentang : kentang
# 6583 : kejuhaduhhhh : kejuhaduhhhh
# 6584 : terusss : terusss
# 6585 : iklanya : iklanya
# 6586 : belii : beli
# 6587 : muakkkklo : muakkkklo
# 6588 : dtk : dtk
# 6589 : okmalah : okmalah
# 6590 : lahhh : lahhh
# 6591 : durasinya : durasi
# 6592 : panjanggg : panjanggg
# 6593 : tebus : tebus
# 6594 : illfeel : illfeel
# 6595 : udahlah : udahlah
# 6596 : sekredibel : sekredibel
# 6597 : kemalasan : malas
# 6598 : ngantar : ngantar
# 6599 : diretur : retur
# 6600 : goodjobs : goodjobs
# 6601 : scrollscroll : scrollscroll
# 6602 : layar : layar
# 6603 : freeze : freeze
# 6604 : pure : pure
# 6605 : usulan : usul
# 6606 : fasilitas : fasilitas
# 6607 : tema : tema
# 6608 : rebahan : rebah
# 6609 : terkendalamohon : terkendalamohon
# 6610 : prioritaskanmakasih : prioritaskanmakasih
# 6611 : kerennnnbangeett : kerennnnbangeett
# 6612 : sekalii : sekali
# 6613 : coinnya : coinnya
# 6614 : transaksiku : transaksi
# 6615 : jelaskatanya : jelaskatanya
# 6616 : topedsu : topedsu
# 6617 : tjh : tjh
# 6618 : jian : jian
# 6619 : skipp : skipp
# 6620 : rekomendasijne : rekomendasijne
# 6621 : diindo : diindo
# 6622 : keterlambatannya : lambat
# 6623 : sinih : sih
# 6624 : pembelajaran : ajar
# 6625 : sinihtutup : sinihtutup
# 6626 : onlineshop : onlineshop
# 6627 : landscape : landscape
# 6628 : penyesuaian : sesuai
# 6629 : laingoodluck : laingoodluck
# 6630 : perform : perform
# 6631 : kalender : kalender
# 6632 : upedit : upedit
# 6633 : peralatan : alat
# 6634 : pm : pm
# 6635 : busa : busa
# 6636 : dapatkan : dapat
# 6637 : pencariany : pencariany
# 6638 : trmksh : trmksh
# 6639 : tagiha : tagiha
# 6640 : kooperatif : kooperatif
# 6641 : karenakan : karena
# 6642 : tulul : tulul
# 6643 : rekpmendasi : rekpmendasi
# 6644 : aplikadi : aplikadi
# 6645 : mumpung : mumpung
# 6646 : khan : khan
# 6647 : diutak : diutak
# 6648 : atik : atik
# 6649 : efek : efek
# 6650 : smart : smart
# 6651 : huruf : huruf
# 6652 : gag : gag
# 6653 : nyambung : nyambung
# 6654 : seribuan : ribu
# 6655 : dimunculin : dimunculin
# 6656 : hideout : hideout
# 6657 : tertibkan : tertib
# 6658 : seandainya : anda
# 6659 : hindari : hindar
# 6660 : didlmnya : didlmnya
# 6661 : bebrapa : bebrapa
# 6662 : okey : okey
# 6663 : lemgkap : lemgkap
# 6664 : hat : hat
# 6665 : too : too
# 6666 : easy : easy
# 6667 : dibekukan : beku
# 6668 : tahunnya : tahun
# 6669 : tai : tai
# 6670 : antrian : antri
# 6671 : jta : jta
# 6672 : quota : quota
# 6673 : scor : scor
# 6674 : freeongkir : freeongkir
# 6675 : suru : suru
# 6676 : sparpat : sparpat
# 6677 : sepeda : sepeda
# 6678 : akallll : akallll
# 6679 : minggupas : minggupas
# 6680 : bersangkutan : sangkut
# 6681 : terimaseller : terimaseller
# 6682 : nyaranin : nyaranin
# 6683 : tokopediakacau : tokopediakacau
# 6684 : dibayartransfer : dibayartransfer
# 6685 : gilaaaaaaa : gilaaaaaaa
# 6686 : bestt : bestt
# 6687 : hpnya : hpnya
# 6688 : ciamix : ciamix
# 6689 : mesan : mesan
# 6690 : banjarmasin : banjarmasin
# 6691 : banjar : banjar
# 6692 : teliti : teliti
# 6693 : bangetkomplain : bangetkomplain
# 6694 : carejawaban : carejawaban
# 6695 : asalan : asal
# 6696 : barannya : baran
# 6697 : over : over
# 6698 : memperlama : lama
# 6699 : asalasalan : asalasalan
# 6700 : sewenangwenang : sewenangwenang
# 6701 : mengganti : ganti
# 6702 : praktek : praktek
# 6703 : ketidakadilan : ketidakadilan
# 6704 : bgst : bgst
# 6705 : iklannyagk : iklannyagk
# 6706 : kepencet : pencet
# 6707 : dibaka : baka
# 6708 : iklannyaapa : iklannyaapa
# 6709 : pengecek : ecek
# 6710 : bangke : bangke
# 6711 : silangnya : silang
# 6712 : munculsama : munculsama
# 6713 : nontif : nontif
# 6714 : diarahin : diarahin
# 6715 : komunitas : komunitas
# 6716 : jekek : jekek
# 6717 : mntappppp : mntappppp
# 6718 : datengg : datengg
# 6719 : ilangg : ilangg
# 6720 : belanjaa : belanjaa
# 6721 : akuu : akuu
# 6722 : jugaa : jugaa
# 6723 : baguspengiriman : baguspengiriman
# 6724 : ciahh : ciahh
# 6725 : kritik : kritik
# 6726 : dibabat : babat
# 6727 : sebegitunya : begitu
# 6728 : copot : copot
# 6729 : baperan : baperan
# 6730 : apr : apr
# 6731 : hbs : hbs
# 6732 : recommendedthanks : recommendedthanks
# 6733 : gocarr : gocarr
# 6734 : gosen : gosen
# 6735 : apertemaen : apertemaen
# 6736 : dicilandak : dicilandak
# 6737 : roh : roh
# 6738 : nugroho : nugroho
# 6739 : sofapak : sofapak
# 6740 : nugrohonya : nugrohonya
# 6741 : salut : salut
# 6742 : eskrim : eskrim
# 6743 : mantaptpi : mantaptpi
# 6744 : kekurangan : kurang
# 6745 : tempatberlaku : tempatberlaku
# 6746 : barangcoba : barangcoba
# 6747 : lgiterimakasih : lgiterimakasih
# 6748 : kecap : kecap
# 6749 : bango : bango
# 6750 : ps : ps
# 6751 : nentuin : nentuin
# 6752 : enth : enth
# 6753 : keganti : ganti
# 6754 : dibalikkan : balik
# 6755 : taiiii : taiiii
# 6756 : lola : lola
# 6757 : ngeceklacak : ngeceklacak
# 6758 : alihalih : alihalih
# 6759 : keterbatasan : batas
# 6760 : membahagiakan : bahagia
# 6761 : he : he
# 6762 : dibagikan : bagi
# 6763 : suda : suda
# 6764 : scamer : scamer
# 6765 : bagikan : bagi
# 6766 : gembel : gembel
# 6767 : tuduh : tuduh
# 6768 : dicurigai : curiga
# 6769 : sensor : sensor
# 6770 : dukun : dukun
# 6771 : matiin : matiin
# 6772 : rezeki : rezeki
# 6773 : pendapatan : dapat
# 6774 : cut : cut
# 6775 : cakung : cakung
# 6776 : membuang : buang
# 6777 : jad : jad
# 6778 : hmmm : hmmm
# 6779 : bapakibu : bapakibu
# 6780 : lwt : lwt
# 6781 : menulis : tulis
# 6782 : dicuekkin : dicuekkin
# 6783 : penghargaan : harga
# 6784 : awards : awards
# 6785 : membantuterimakasihsemiga : membantuterimakasihsemiga
# 6786 : menindak : tindak
# 6787 : cengkareng : cengkareng
# 6788 : mengada : ada
# 6789 : trnyata : trnyata
# 6790 : jidatnya : jidat
# 6791 : tunda : tunda
# 6792 : berhentiin : berhentiin
# 6793 : alih : alih
# 6794 : khusunya : khusunya
# 6795 : mandeg : mandeg
# 6796 : ketegasanya : ketegasanya
# 6797 : bangetttttt : bangetttttt
# 6798 : hariii : hariii
# 6799 : woilahhhhhhhhhhhhh : woilahhhhhhhhhhhhh
# 6800 : mengambil : ambil
# 6801 : masbro : masbro
# 6802 : costumerterima : costumerterima
# 6803 : busetttt : busetttt
# 6804 : bangetsiap : bangetsiap
# 6805 : kntr : kntr
# 6806 : kebebasan : bebas
# 6807 : karung : karung
# 6808 : laptop : laptop
# 6809 : benerbenar : benerbenar
# 6810 : ringkasan : ringkas
# 6811 : kenaikan : naik
# 6812 : perbaikimasa : perbaikimasa
# 6813 : muat : muat
# 6814 : minuman : minum
# 6815 : cemilan : cemilan
# 6816 : ayam : ayam
# 6817 : daging : daging
# 6818 : sembako : sembako
# 6819 : botai : bota
# 6820 : bestyes : bestyes
# 6821 : ribetngasih : ribetngasih
# 6822 : diskondll : diskondll
# 6823 : otamatis : otamatis
# 6824 : diblocklalu : diblocklalu
# 6825 : sistembbrp : sistembbrp
# 6826 : direturn : direturn
# 6827 : sayagak : sayagak
# 6828 : ecommercetutup : ecommercetutup
# 6829 : kapokreturn : kapokreturn
# 6830 : ikhlasin : ikhlasin
# 6831 : dehmales : dehmales
# 6832 : ributin : ributin
# 6833 : receh : receh
# 6834 : jawabanya : jawabanya
# 6835 : dilaporkan : lapor
# 6836 : komple : komple
# 6837 : ditanyain : ditanyain
# 6838 : laporkanya : laporkanya
# 6839 : ade : ade
# 6840 : pngirimn : pngirimn
# 6841 : kluarga : kluarga
# 6842 : sgitu : sgitu
# 6843 : serah : serah
# 6844 : mentang : mentang
# 6845 : plsss : plsss
# 6846 : katrina : katrina
# 6847 : marshaaaaaaa : marshaaaaaaa
# 6848 : tegal : tegal
# 6849 : diperbaikin : diperbaikin
# 6850 : bdg : bdg
# 6851 : ngubah : ngubah
# 6852 : lgsng : lgsng
# 6853 : danbanyak : danbanyak
# 6854 : produkproduk : produkproduk
# 6855 : murahdan : murahdan
# 6856 : sekota : kota
# 6857 : pantang : pantang
# 6858 : xxx : xxx
# 6859 : dimatikan : mati
# 6860 : dinginkan : dingin
# 6861 : wisthlist : wisthlist
# 6862 : anggaran : anggar
# 6863 : terplanning : terplanning
# 6864 : daya : daya
# 6865 : dijalan : jalan
# 6866 : perut : perut
# 6867 : mules : mules
# 6868 : rekomendasibikin : rekomendasibikin
# 6869 : kapokbelanja : kapokbelanja
# 6870 : gerecep : gerecep
# 6871 : jamiman : jamiman
# 6872 : maacih : maacih
# 6873 : mwachhhhhh : mwachhhhhh
# 6874 : minclaim : minclaim
# 6875 : beragam : agam
# 6876 : hobi : hobi
# 6877 : balesan : balesan
# 6878 : tumpuk : tumpuk
# 6879 : packing : packing
# 6880 : mrmbayar : mrmbayar
# 6881 : familier : familier
# 6882 : dimengerti : erti
# 6883 : turunkan : turun
# 6884 : ngurusnya : ngurusnya
# 6885 : premi : premi
# 6886 : delivery : delivery
# 6887 : ditujuan : tuju
# 6888 : hopefully : hopefully
# 6889 : knows : knows
# 6890 : understands : understands
# 6891 : reason : reason
# 6892 : gave : gave
# 6893 : puazzz : puazzz
# 6894 : kodenya : kode
# 6895 : bgtttt : bgtttt
# 6896 : wasuuuuuuu : wasuuuuuuu
# 6897 : kaoooooou : kaoooooou
# 6898 : penyelesai : selesai
# 6899 : digerakkan : gerak
# 6900 : lebaran : lebaran
# 6901 : nihpaket : nihpaket
# 6902 : pending : pending
# 6903 : tersebar : sebar
# 6904 : akibat : akibat
# 6905 : berbelitbelit : berbelitbelit
# 6906 : berkedipkedip : berkedipkedip
# 6907 : dipencet : pencet
# 6908 : ngehang : ngehang
# 6909 : kebangkrutan : bangkrut
# 6910 : penipuanhati : penipuanhati
# 6911 : meja : meja
# 6912 : kadaluarsa : kadaluarsa
# 6913 : ngambilin : ngambilin
# 6914 : melayani : layan
# 6915 : sepersen : persen
# 6916 : balikkin : balikkin
# 6917 : nyepelin : nyepelin
# 6918 : alhmdulilah : alhmdulilah
# 6919 : telvon : telvon
# 6920 : gateway : gateway
# 6921 : bangetterpercayadan : bangetterpercayadan
# 6922 : teramanah : amanah
# 6923 : dukung : dukung
# 6924 : kebanggaan : bangga
# 6925 : webnya : webnya
# 6926 : dikenain : dikenain
# 6927 : kedatangannya : datang
# 6928 : disamakan : sama
# 6929 : umunya : umu
# 6930 : teruntuk : untuk
# 6931 : pimpinan : pimpin
# 6932 : jajaran : jajar
# 6933 : merchat : merchat
# 6934 : mercant : mercant
# 6935 : pendapatannya : dapat
# 6936 : kajian : kaji
# 6937 : ulangditurunkan : ulangditurunkan
# 6938 : aje : aje
# 6939 : udeh : udeh
# 6940 : janjix : janjix
# 6941 : omong : omong
# 6942 : murahx : murahx
# 6943 : promoij : promoij
# 6944 : luamaa : luamaa
# 6945 : bgttttt : bgttttt
# 6946 : develop : develop
# 6947 : diacakacak : diacakacak
# 6948 : difilter : filter
# 6949 : sebelumsebelumnya : sebelumsebelumnya
# 6950 : kelipatan : kelipat
# 6951 : rbkyknya : rbkyknya
# 6952 : terakir : terakir
# 6953 : mantabb : mantabb
# 6954 : returnya : retur
# 6955 : kejam : kejam
# 6956 : mikirmikir : mikirmikir
# 6957 : lelettt : lelettt
# 6958 : sumpaaahhh : sumpaaahhh
# 6959 : teruus : teruus
# 6960 : variasi : variasi
# 6961 : gimmic : gimmic
# 6962 : pendatang : datang
# 6963 : jugaaaaaaa : jugaaaaaaa
# 6964 : siiiiip : siiiiip
# 6965 : dehthnks : dehthnks
# 6966 : perbaharui : baharu
# 6967 : dipandang : pandang
# 6968 : calon : calon
# 6969 : affiliator : affiliator
# 6970 : tag : tag
# 6971 : seo : seo
# 6972 : okkkkkkkkkk : okkkkkkkkkk
# 6973 : lahhhhh : lahhhhh
# 6974 : urut : urut
# 6975 : dimiripin : dimiripin
# 6976 : patokan : patok
# 6977 : layout : layout
# 6978 : ngerekomendasiin : ngerekomendasiin
# 6979 : dipertahankan : tahan
# 6980 : semuagratis : semuagratis
# 6981 : dirugiin : dirugiin
# 6982 : dipotongnya : potong
# 6983 : nilep : nilep
# 6984 : costumernya : costumernya
# 6985 : jidat : jidat
# 6986 : penyok : penyok
# 6987 : dikenakan : kena
# 6988 : perampasan : ampas
# 6989 : kesepakatan : sepakat
# 6990 : asuransin : asuransin
# 6991 : telek : telek
# 6992 : chrome : chrome
# 6993 : latercicilan : latercicilan
# 6994 : haduhh : haduhh
# 6995 : pulsatidak : pulsatidak
# 6996 : bpjsair : bpjsair
# 6997 : pdamskrg : pdamskrg
# 6998 : mks : mks
# 6999 : okeeeee : okeeeee
# 7000 : bayarnya : bayar
# 7001 : tautin : tautin
# 7002 : toll : toll
# 7003 : mandiri : mandiri
# 7004 : bodh : bodh
# 7005 : ngiklan : ngiklan
# 7006 : mbuka : mbuka
# 7007 : menta : menta
# 7008 : juaaln : juaaln
# 7009 : jelekkkk : jelekkkk
# 7010 : overall : overall
# 7011 : siput : siput
# 7012 : yahh : yahh
# 7013 : tertandingi : tanding
# 7014 : play : play
# 7015 : instannya : instan
# 7016 : rela : rela
# 7017 : ubahnya : ubah
# 7018 : bgtpadahal : bgtpadahal
# 7019 : tokopediatapi : tokopediatapi
# 7020 : aktivasinya : aktivasinya
# 7021 : kacaw : kacaw
# 7022 : klaem : klaem
# 7023 : digunakanbanyak : digunakanbanyak
# 7024 : midah : midah
# 7025 : ceria : ceria
# 7026 : diblacklist : diblacklist
# 7027 : mutu : mutu
# 7028 : enakeun : enakeun
# 7029 : lam : lam
# 7030 : smga : smga
# 7031 : curi : curi
# 7032 : fiktif : fiktif
# 7033 : kin : kin
# 7034 : ngereturr : ngereturr
# 7035 : tambahi : tambah
# 7036 : sempurnakarena : sempurnakarena
# 7037 : meberikan : meberikan
# 7038 : vidio : vidio
# 7039 : gagaltidak : gagaltidak
# 7040 : dzalim : dzalim
# 7041 : yakecewa : yakecewa
# 7042 : toleransisekelas : toleransisekelas
# 7043 : blunder : blunder
# 7044 : geraknya : gerak
# 7045 : ngilangin : ngilangin
# 7046 : nyataaaaaakehilangan : nyataaaaaakehilangan
# 7047 : wkwkwksafetynya : wkwkwksafetynya
# 7048 : reg : reg
# 7049 : mantau : mantau
# 7050 : tg : tg
# 7051 : awowkwk : awowkwk
# 7052 : tokpeddari : tokpeddari
# 7053 : tokopediabarang : tokopediabarang
# 7054 : selesaikomplain : selesaikomplain
# 7055 : membantuekspedisi : membantuekspedisi
# 7056 : burukbarang : burukbarang
# 7057 : berkalidikompalin : berkalidikompalin
# 7058 : kejelasanmembuat : kejelasanmembuat
# 7059 : anjirrr : anjirrr
# 7060 : sekarangbantuan : sekarangbantuan
# 7061 : terusadmin : terusadmin
# 7062 : responjadinya : responjadinya
# 7063 : inisial : inisial
# 7064 : terjamun : terjamun
# 7065 : punyak : punyak
# 7066 : diutamakankasihan : diutamakankasihan
# 7067 : getahnya : getah
# 7068 : topedi : topedi
# 7069 : mengaktifkan : aktif
# 7070 : lather : lather
# 7071 : mihon : mihon
# 7072 : gedee : gedee
# 7073 : sdah : sdah
# 7074 : kardusnya : kardus
# 7075 : kaget : kaget
# 7076 : januari : januari
# 7077 : discont : discont
# 7078 : recom : recom
# 7079 : expreesssmasih : expreesssmasih
# 7080 : perusahan : usah
# 7081 : meminimalis : minimal
# 7082 : komplaineh : komplaineh
# 7083 : sebalik : balik
# 7084 : parahhhhhhhhhh : parahhhhhhhhhh
# 7085 : mesennya : mesennya
# 7086 : kering : kering
# 7087 : menjanjikan : janji
# 7088 : tangung : tangung
# 7089 : tujuansesuai : tujuansesuai
# 7090 : jugatpi : jugatpi
# 7091 : tngl : tngl
# 7092 : terakhirga : terakhirga
# 7093 : orensepengalaman : orensepengalaman
# 7094 : iniapa : iniapa
# 7095 : penyakit : sakit
# 7096 : gregetkenapa : gregetkenapa
# 7097 : donwload : donwload
# 7098 : terussaat : terussaat
# 7099 : dbuka : dbuka
# 7100 : browsmau : browsmau
# 7101 : udahan : udahan
# 7102 : dagangnya : dagang
# 7103 : lazadaburuk : lazadaburuk
# 7104 : untungbanyak : untungbanyak
# 7105 : pegiriman : pegiriman
# 7106 : ckckc : ckckc
# 7107 : resign : resign
# 7108 : piara : piara
# 7109 : bau : bau
# 7110 : jeas : jeas
# 7111 : astaghfirullah : astaghfirullah
# 7112 : batak : batak
# 7113 : sitemnya : sitemnya
# 7114 : bismilah : bismilah
# 7115 : penipuudah : penipuudah
# 7116 : cansel : cansel
# 7117 : bokep : bokep
# 7118 : sipenerima : sipenerima
# 7119 : berlanja : lanja
# 7120 : donwlod : donwlod
# 7121 : november : november
# 7122 : danarefund : danarefund
# 7123 : kelanjutandi : kelanjutandi
# 7124 : yyratttku : yyratttku
# 7125 : pelosok : pelosok
# 7126 : diperbaikilah : baik
# 7127 : prosedurnya : prosedur
# 7128 : bagustapi : bagustapi
# 7129 : affiliatorupload : affiliatorupload
# 7130 : nyangkutapa : nyangkutapa
# 7131 : pejelasan : jelas
# 7132 : punvideo : punvideo
# 7133 : menghasilkanlink : menghasilkanlink
# 7134 : aktip : aktip
# 7135 : dimasukkan : masuk
# 7136 : astag : astag
# 7137 : ajakacau : ajakacau
# 7138 : dikitdikit : dikitdikit
# 7139 : etol : etol
# 7140 : butuhkan : butuh
# 7141 : mengalahkan : kalah
# 7142 : km : km
# 7143 : samapi : samapi
# 7144 : lar : lar
# 7145 : pulsabarang : pulsabarang
# 7146 : jangkauan : jangkau
# 7147 : lokasinya : lokasi
# 7148 : tugasnya : tugas
# 7149 : dipedalaman : dalam
# 7150 : menabung : tabung
# 7151 : beranak : anak
# 7152 : pinak : pinak
# 7153 : ngepek : ngepek
# 7154 : papa : papa
# 7155 : prestasi : prestasi
# 7156 : prdia : prdia
# 7157 : sanhat : sanhat
# 7158 : memudahkn : memudahkn
# 7159 : brlanja : brlanja
# 7160 : cacatburuk : cacatburuk
# 7161 : gedean : gede
# 7162 : neko : neko
# 7163 : nyesal : nyesal
# 7164 : machanpro : machanpro
# 7165 : butuhin : butuhin
# 7166 : list : list
# 7167 : silelet : silelet
# 7168 : jabar : jabar
# 7169 : membenarkan : benar
# 7170 : ditumpukan : tumpu
# 7171 : lum : lum
# 7172 : dihubungin : dihubungin
# 7173 : berak : berak
# 7174 : pt : pt
# 7175 : mempelajari : ajar
# 7176 : awam : awam
# 7177 : urusanku : urus
# 7178 : mensanksi : sanksi
# 7179 : hina : hina
# 7180 : dicacimaki : dicacimaki
# 7181 : regulasi : regulasi
# 7182 : prosedurnyaupdate : prosedurnyaupdate
# 7183 : bisaseperti : bisaseperti
# 7184 : jelasjelas : jelasjelas
# 7185 : laginya : lagi
# 7186 : produkny : produkny
# 7187 : pengirimanyajadi : pengirimanyajadi
# 7188 : pembatalanpengembalian : pembatalanpengembalian
# 7189 : dipersulitbeda : dipersulitbeda
# 7190 : gwampang : gwampang
# 7191 : krim : krim
# 7192 : taptap : taptap
# 7193 : idaman : idam
# 7194 : oops : oops
# 7195 : koleksi : koleksi
# 7196 : baguas : baguas
# 7197 : murahin : murahin
# 7198 : meperbanya : meperbanya
# 7199 : hehehehh : hehehehh
# 7200 : mantaaaaapppp : mantaaaaapppp
# 7201 : dibanyakin : dibanyakin
# 7202 : nyarinya : nyarinya
# 7203 : rendom : rendom
# 7204 : range : range
# 7205 : kumaha : maha
# 7206 : komplin : komplin
# 7207 : tangani : tangan
# 7208 : plyanan : plyanan
# 7209 : well : well
# 7210 : referal : referal
# 7211 : dooong : dooong
# 7212 : trusted : trusted
# 7213 : tik : tik
# 7214 : guy : guy
# 7215 : trjadi : trjadi
# 7216 : dihilangin : dihilangin
# 7217 : mengindahkan : indah
# 7218 : perihal : perihal
# 7219 : kurirny : kurirny
# 7220 : pasca : pasca
# 7221 : pmbeli : pmbeli
# 7222 : datengpokoknya : datengpokoknya
# 7223 : gda : gda
# 7224 : buyers : buyers
# 7225 : sellers : sellers
# 7226 : fightingg : fightingg
# 7227 : apriluntuk : apriluntuk
# 7228 : beritahukan : beritahukan
# 7229 : payalater : payalater
# 7230 : sll : sll
# 7231 : bloksaya : bloksaya
# 7232 : keprluan : keprluan
# 7233 : jelasklu : jelasklu
# 7234 : salahnyableguk : salahnyableguk
# 7235 : foodnya : foodnya
# 7236 : jdii : jdii
# 7237 : kemanaiiin : kemanaiiin
# 7238 : uduh : uduh
# 7239 : penipuansy : penipuansy
# 7240 : barangkok : barangkok
# 7241 : rbtau : rbtau
# 7242 : jepittolong : jepittolong
# 7243 : dehdari : dehdari
# 7244 : bolokir : bolokir
# 7245 : jawabnama : jawabnama
# 7246 : sinarpenipu : sinarpenipu
# 7247 : laporkan : lapor
# 7248 : bewenang : bewenang
# 7249 : kecurigaan : curiga
# 7250 : kapooooooook : kapooooooook
# 7251 : tokopediauntuk : tokopediauntuk
# 7252 : pickupnya : pickupnya
# 7253 : sekalipadahal : sekalipadahal
# 7254 : jalannyauntuk : jalannyauntuk
# 7255 : sistemdengan : sistemdengan
# 7256 : phone : phone
# 7257 : expedisiinfo : expedisiinfo
# 7258 : sampekatanya : sampekatanya
# 7259 : nyatanyaaaa : nyatanyaaaa
# 7260 : ngikuti : ngikuti
# 7261 : persaratan : sarat
# 7262 : jamuran : jamur
# 7263 : masukannya : masuk
# 7264 : tempodan : tempodan
# 7265 : paraah : paraah
# 7266 : taw : taw
# 7267 : ngeheeee : ngeheeee
# 7268 : gabsa : gabsa
# 7269 : gentar : gentar
# 7270 : kacauga : kacauga
# 7271 : vapepood : vapepood
# 7272 : janaan : janaan
# 7273 : pqksa : pqksa
# 7274 : begog : begog
# 7275 : sue : sue
# 7276 : bismillah : bismillah
# 7277 : ppedia : ppedia
# 7278 : tunanetra : tunanetra
# 7279 : gakada : gakada
# 7280 : gmpang : gmpang
# 7281 : pollll : pollll
# 7282 : guncangan : guncang
# 7283 : blabla : blabla
# 7284 : mustinya : mustinya
# 7285 : ngisi : ngisi
# 7286 : rpk : rpk
# 7287 : semkin : semkin
# 7288 : casbackdiskon : casbackdiskon
# 7289 : menonaktifkan : nonaktif
# 7290 : fans : fans
# 7291 : facebooknya : facebooknya
# 7292 : berandanya : beranda
# 7293 : angkir : angkir
# 7294 : pokeeeee : pokeeeee
# 7295 : luarbiasa : luarbiasa
# 7296 : verry : verry
# 7297 : embelnya : embel
# 7298 : faedahnya : faedah
# 7299 : kepaksa : paksa
# 7300 : poolll : poolll
# 7301 : veri : veri
# 7302 : dylan : dylan
# 7303 : aufar : aufar
# 7304 : abdillah : abdillah
# 7305 : cobaa : cobaa
# 7306 : kacauuu : kacauuu
# 7307 : sanaempar : sanaempar
# 7308 : invasinya : invasi
# 7309 : ancurin : ancurin
# 7310 : tokpedlambatga : tokpedlambatga
# 7311 : jelasmenjijikan : jelasmenjijikan
# 7312 : lnjuttt : lnjuttt
# 7313 : juwos : juwos
# 7314 : krmnya : krmnya
# 7315 : tobat : tobat
# 7316 : propesional : propesional
# 7317 : begeeste : begeeste
# 7318 : maxsimalsudah : maxsimalsudah
# 7319 : boleeeh : boleeeh
# 7320 : sekalitapi : sekalitapi
# 7321 : pengirimankarna : pengirimankarna
# 7322 : pengirimankalau : pengirimankalau
# 7323 : rfun : rfun
# 7324 : volume : volume
# 7325 : dipertimbangkan : timbang
# 7326 : silakan : sila
# 7327 : mengecewakankalo : mengecewakankalo
# 7328 : jnepengiriman : jnepengiriman
# 7329 : aplikasinyasaya : aplikasinyasaya
# 7330 : lainwalaupun : lainwalaupun
# 7331 : semanggatt : semanggatt
# 7332 : kkk : kkk
# 7333 : add : add
# 7334 : belanj : belanj
# 7335 : cartdebit : cartdebit
# 7336 : gaasss : gaasss
# 7337 : truus : truus
# 7338 : buunggkuzz : buunggkuzz
# 7339 : direview : direview
# 7340 : selesaiselesai : selesaiselesai
# 7341 : ape : ape
# 7342 : rius : rius
# 7343 : giawa : giawa
# 7344 : stuk : stuk
# 7345 : dikeluarkan : keluar
# 7346 : penanganannya : tangan
# 7347 : updatee : updatee
# 7348 : anjiing : anjiing
# 7349 : gampan : gampan
# 7350 : mamposs : mamposs
# 7351 : pelayananya : pelayananya
# 7352 : sopilazada : sopilazada
# 7353 : sampaiasu : sampaiasu
# 7354 : offline : offline
# 7355 : puaaasss : puaaasss
# 7356 : enaknya : enak
# 7357 : nyampepelayanan : nyampepelayanan
# 7358 : onlinya : onlinya
# 7359 : pengirimannyaekpedisi : pengirimannyaekpedisi
# 7360 : rentan : rentan
# 7361 : neh : neh
# 7362 : medit : medit
# 7363 : pelayanann : pelayanann
# 7364 : ttep : ttep
# 7365 : sebenrnya : sebenrnya
# 7366 : ketentuannya : tentu
# 7367 : beralun : alun
# 7368 : pilhannya : pilhannya
# 7369 : digitalisasi : digitalisasi
# 7370 : telematika : telematika
# 7371 : smartphone : smartphone
# 7372 : olah : olah
# 7373 : raga : raga
# 7374 : kejelasanuang : kejelasanuang
# 7375 : masukbarang : masukbarang
# 7376 : datangudah : datangudah
# 7377 : nyeselin : nyeselin
# 7378 : mengulang : ulang
# 7379 : ketiknya : ketik
# 7380 : diaktifkan : aktif
# 7381 : orderannya : order
# 7382 : dhe : dhe
# 7383 : berpatokan : patok
# 7384 : kelokasi : lokasi
# 7385 : mabuk : mabuk
# 7386 : kokpesan : kokpesan
# 7387 : giman : gim
# 7388 : gampangnya : gampang
# 7389 : keluarkan : keluar
# 7390 : bernilai : nila
# 7391 : ekstra : ekstra
# 7392 : gratisin : gratisin
# 7393 : gopaylatercicil : gopaylatercicil
# 7394 : hny : hny
# 7395 : delete : delete
# 7396 : tokopediaemang : tokopediaemang
# 7397 : fungsinya : fungsi
# 7398 : berwarna : warna
# 7399 : saag : saag
# 7400 : ngotakexpedisi : ngotakexpedisi
# 7401 : ribuitu : ribuitu
# 7402 : harimau : harimau
# 7403 : minbarang : minbarang
# 7404 : kmrensekarang : kmrensekarang
# 7405 : lewt : lewt
# 7406 : dihargai : harga
# 7407 : gadget : gadget
# 7408 : splus : splus
# 7409 : launching : launching
# 7410 : feb : feb
# 7411 : sultra : sultra
# 7412 : pasaran : pasar
# 7413 : onlinekan : onlinekan
# 7414 : tawar : tawar
# 7415 : grgr : grgr
# 7416 : luck : luck
# 7417 : ikhlaskan : ikhlas
# 7418 : habs : habs
# 7419 : energi : energi
# 7420 : ngurusi : ngurusi
# 7421 : dissapointed : dissapointed
# 7422 : mencurangi : curang
# 7423 : heyy : heyy
# 7424 : thl : thl
# 7425 : ekpedisinya : ekpedisinya
# 7426 : hanger : hanger
# 7427 : maknyus : maknyus
# 7428 : barangmu : barang
# 7429 : digabur : digabur
# 7430 : dibayarkan : bayar
# 7431 : isa : isa
# 7432 : joooooooooooooooob : joooooooooooooooob
# 7433 : yaaah : yaaah
# 7434 : sgm : sgm
# 7435 : indomaretsetelah : indomaretsetelah
# 7436 : datangakhirnya : datangakhirnya
# 7437 : hilangsaya : hilangsaya
# 7438 : refundpdhl : refundpdhl
# 7439 : ngulang : ngulang
# 7440 : peroses : peroses
# 7441 : manjang : manjang
# 7442 : gasukanya : gasukanya
# 7443 : megang : megang
# 7444 : dstu : dstu
# 7445 : kta : kta
# 7446 : terbuka : buka
# 7447 : berkedok : kedok
# 7448 : masihhhh : masihhhh
# 7449 : berdagang : dagang
# 7450 : klau : klau
# 7451 : omel : omel
# 7452 : dikiranya : kira
# 7453 : minkok : minkok
# 7454 : xali : xali
# 7455 : senggknya : senggknya
# 7456 : gdbrus : gdbrus
# 7457 : lainsemoga : lainsemoga
# 7458 : banyakmkch : banyakmkch
# 7459 : kelebihan : lebih
# 7460 : telak : telak
# 7461 : caur : caur
# 7462 : advertising : advertising
# 7463 : banyakbahkan : banyakbahkan
# 7464 : musik : musik
# 7465 : adamenurut : adamenurut
# 7466 : dahulusaya : dahulusaya
# 7467 : dikurangiminimal : dikurangiminimal
# 7468 : helpfull : helpfull
# 7469 : mantaaaaaaaap : mantaaaaaaaap
# 7470 : memamg : memamg
# 7471 : njing : njing
# 7472 : menggiurkan : giur
# 7473 : liha : liha
# 7474 : promoitulah : promoitulah
# 7475 : tokopediabuanyaak : tokopediabuanyaak
# 7476 : kurirsudah : kurirsudah
# 7477 : diandalkanpenanganan : diandalkanpenanganan
# 7478 : kemauan : mau
# 7479 : pelanggankecewa : pelanggankecewa
# 7480 : buangeet : buangeet
# 7481 : topped : topped
# 7482 : verfikasi : verfikasi
# 7483 : helloooooo : helloooooo
# 7484 : malasmalas : malasmalas
# 7485 : tujuannya : tuju
# 7486 : tigakali : tigakali
# 7487 : garcepgarcep : garcepgarcep
# 7488 : peminat : minat
# 7489 : astagfirullah : astagfirullah
# 7490 : nyasaya : nyasaya
# 7491 : ongoing : ongoing
# 7492 : dongg : dongg
# 7493 : gan : gan
# 7494 : keuntungannya : untung
# 7495 : njebak : njebak
# 7496 : asuransinya : asuransi
# 7497 : rancangan : rancang
# 7498 : wes : wes
# 7499 : lintah : lintah
# 7500 : engak : engak
# 7501 : triliun : triliun
# 7502 : mengkhianati : khianat
# 7503 : koar : koar
# 7504 : ngaa : ngaa
# 7505 : perduli : duli
# 7506 : pengirimannyanyaaplikasi : pengirimannyanyaaplikasi
# 7507 : cepatjangan : cepatjangan
# 7508 : iki : iki
# 7509 : sihkok : sihkok
# 7510 : darkweb : darkweb
# 7511 : inovatif : inovatif
# 7512 : berkreasi : kreasi
# 7513 : donx : donx
# 7514 : sayamala : sayamala
# 7515 : fitri : fitri
# 7516 : terbit : terbit
# 7517 : pesananpaket : pesananpaket
# 7518 : lakukan : laku
# 7519 : bahasanya : bahasa
# 7520 : kenakan : kena
# 7521 : zalim : zalim
# 7522 : pengirimannnya : pengirimannnya
# 7523 : trace : trace
# 7524 : cukjancuk : cukjancuk
# 7525 : gae : gae
# 7526 : meneh : teh
# 7527 : kur : kur
# 7528 : latey : latey
# 7529 : mudahlengkaphematmurah : mudahlengkaphematmurah
# 7530 : codsaya : codsaya
# 7531 : berkurangnya : kurang
# 7532 : tangkap : tangkap
# 7533 : nakalklo : nakalklo
# 7534 : peliharalah : pelihara
# 7535 : konter : konter
# 7536 : fiturfitur : fiturfitur
# 7537 : terlau : terlau
# 7538 : sedunia : dunia
# 7539 : susahganti : susahganti
# 7540 : ribeteh : ribeteh
# 7541 : syariat : syariat
# 7542 : saingan : saing
# 7543 : kntol : kntol
# 7544 : apaapa : apaapa
# 7545 : aplikator : aplikator
# 7546 : untik : untik
# 7547 : pkek : pkek
# 7548 : anjink : anjink
# 7549 : perbaikii : perbaikii
# 7550 : bercanda : canda
# 7551 : rw : rw
# 7552 : patokannya : patok
# 7553 : te : te
# 7554 : nyaanjirrrrr : nyaanjirrrrr
# 7555 : lusa : lusa
# 7556 : maslksimal : maslksimal
# 7557 : diarea : area
# 7558 : shoap : shoap
# 7559 : blmlagi : blmlagi
# 7560 : pengnan : nan
# 7561 : dlll : dlll
# 7562 : pling : pling
# 7563 : prah : prah
# 7564 : diindomaret : diindomaret
# 7565 : disemua : semua
# 7566 : dhal : dhal
# 7567 : cobabelanja : cobabelanja
# 7568 : tauga : tauga
# 7569 : vvtt : vvtt
# 7570 : dntr : dntr
# 7571 : bb : bb
# 7572 : vtttggt : vtttggt
# 7573 : tt : tt
# 7574 : ttttgttttttttttgt : ttttgttttttttttgt
# 7575 : ggggtgggggggggg : ggggtgggggggggg
# 7576 : gggggggt : gggggggt
# 7577 : gde : gde
# 7578 : gggt : gggt
# 7579 : yd : yd
# 7580 : zw : zw
# 7581 : ezew : ezew
# 7582 : pengirimanestimasi : pengirimanestimasi
# 7583 : sampegak : sampegak
# 7584 : airsoft : airsoft
# 7585 : tool : tool
# 7586 : searchnya : searchnya
# 7587 : vga : vga
# 7588 : shopeee : shopeee
# 7589 : penjadwalan : jadwal
# 7590 : boborok : boborok
# 7591 : kerennnn : kerennnn
# 7592 : waw : waw
# 7593 : menginspirasi : inspirasi
# 7594 : jualanmantap : jualanmantap
# 7595 : slah : slah
# 7596 : nma : nma
# 7597 : projo : projo
# 7598 : rumh : rumh
# 7599 : lolee : lolee
# 7600 : beat : beat
# 7601 : stret : stret
# 7602 : loler : loler
# 7603 : mio : mio
# 7604 : tuker : tuker
# 7605 : cra : cra
# 7606 : kn : kn
# 7607 : mudahthankyou : mudahthankyou
# 7608 : batasitrimakasih : batasitrimakasih
# 7609 : berdua : dua
# 7610 : gagalnya : gagal
# 7611 : dipikirkan : pikir
# 7612 : du : du
# 7613 : koli : koli
# 7614 : suratnya : surat
# 7615 : ditingkatan : tingkat
# 7616 : nyalemot : nyalemot
# 7617 : muuuannntabbbb : muuuannntabbbb
# 7618 : mantaaabbzz : mantaaabbzz
# 7619 : mepet : mepet
# 7620 : nyabogor : nyabogor
# 7621 : semingguan : minggu
# 7622 : syarofil : syarofil
# 7623 : anam : anam
# 7624 : pcb : pcb
# 7625 : modul : modul
# 7626 : sebelom : bom
# 7627 : cock : cock
# 7628 : kembalin : kembalin
# 7629 : cpet : cpet
# 7630 : saudara : saudara
# 7631 : terendahtertinggi : terendahtertinggi
# 7632 : ulas : ulas
# 7633 : mentingin : mentingin
# 7634 : aing : aing
# 7635 : dkk : dkk
# 7636 : kembalilan : kembalilan
# 7637 : mengandung : kandung
# 7638 : gopaycicilan : gopaycicilan
# 7639 : byee : byee
# 7640 : tokopediaku : tokopediaku
# 7641 : tersayang : sayang
# 7642 : lovely : lovely
# 7643 : rekomdasi : rekomdasi
# 7644 : memuaskanbikin : memuaskanbikin
# 7645 : blanjageser : blanjageser
# 7646 : goood : goood
# 7647 : geregetan : gereget
# 7648 : dianternya : anter
# 7649 : terdekat : dekat
# 7650 : anterin : anterin
# 7651 : gorong : gorong
# 7652 : halah : halah
# 7653 : ribett : ribett
# 7654 : pokoknaman : pokoknaman
# 7655 : sinimakin : sinimakin
# 7656 : ngibul : ngibul
# 7657 : loe : loe
# 7658 : kelazada : kelazada
# 7659 : tkpedia : tkpedia
# 7660 : galaxy : galaxy
# 7661 : scrol : scrol
# 7662 : touchwiz : touchwiz
# 7663 : lajada : lajada
# 7664 : sdgkn : sdgkn
# 7665 : merge : merge
# 7666 : copas : copas
# 7667 : use : use
# 7668 : another : another
# 7669 : belaja : baja
# 7670 : persis : persis
# 7671 : trakhir : trakhir
# 7672 : ngestuck : ngestuck
# 7673 : sosial : sosial
# 7674 : kpindah : kpindah
# 7675 : laternya : laternya
# 7676 : mesinalat : mesinalat
# 7677 : industri : industri
# 7678 : piaraankan : piaraankan
# 7679 : drastis : drastis
# 7680 : walapun : walapun
# 7681 : serbu : serbu
# 7682 : bermaslahpenjual : bermaslahpenjual
# 7683 : bermasalahhanya : bermasalahhanya
# 7684 : exspedisi : exspedisi
# 7685 : burukselagi : burukselagi
# 7686 : merger : merger
# 7687 : sarankan : saran
# 7688 : inimasa : inimasa
# 7689 : jakut : jakut
# 7690 : hariekspedisi : hariekspedisi
# 7691 : tololjelas : tololjelas
# 7692 : shopeelazada : shopeelazada
# 7693 : sendiripengiriman : sendiripengiriman
# 7694 : timekadang : timekadang
# 7695 : waktubyang : waktubyang
# 7696 : horeka : horeka
# 7697 : pisau : pisau
# 7698 : ruixing : ruixing
# 7699 : kontek : kontek
# 7700 : ajapliss : ajapliss
# 7701 : with : with
# 7702 : manaaa : manaaa
# 7703 : rekompaket : rekompaket
# 7704 : sampaisampai : sampaisampai
# 7705 : nex : nex
# 7706 : guysss : guysss
# 7707 : terlengkap : lengkap
# 7708 : bangetpertama : bangetpertama
# 7709 : aplikasinyaudh : aplikasinyaudh
# 7710 : kejutan : kejut
# 7711 : datangny : datangny
# 7712 : luamaaa : luamaaa
# 7713 : puolll : puolll
# 7714 : medsos : medsos
# 7715 : konten : konten
# 7716 : penjajahan : jajah
# 7717 : brapanya : brapanya
# 7718 : tyta : tyta
# 7719 : majunya : maju
# 7720 : apaanikut : apaanikut
# 7721 : ribusaya : ribusaya
# 7722 : haha : haha
# 7723 : pelanggancustomer : pelanggancustomer
# 7724 : rawrrrr : rawrrrr
# 7725 : kesamaannya : sama
# 7726 : cobak : cobak
# 7727 : cikarang : cikarang
# 7728 : usa : usa
# 7729 : kantormu : kantor
# 7730 : ajaterus : ajaterus
# 7731 : bangetrumah : bangetrumah
# 7732 : kapokk : kapokk
# 7733 : syaa : syaa
# 7734 : utangnya : utang
# 7735 : ngakak : ngakak
# 7736 : motif : motif
# 7737 : oderan : oderan
# 7738 : ngegindar : ngegindar
# 7739 : adminny : adminny
# 7740 : kreatifitaslu : kreatifitaslu
# 7741 : sblmnya : sblmnya
# 7742 : goblok : goblok
# 7743 : bunuh : bunuh
# 7744 : ngerusak : ngerusak
# 7745 : bagusdulu : bagusdulu
# 7746 : utara : utara
# 7747 : tangerangpati : tangerangpati
# 7748 : tokoledia : tokoledia
# 7749 : yee : yee
# 7750 : beanfaat : beanfaat
# 7751 : belikan : belikan
# 7752 : yess : yess
# 7753 : maknyoss : maknyoss
# 7754 : benget : benget
# 7755 : dramanya : drama
# 7756 : sampaidana : sampaidana
# 7757 : janjikan : janji
# 7758 : jakartacirebon : jakartacirebon
# 7759 : deketnya : deketnya
# 7760 : sampaaaah : sampaaaah
# 7761 : sing : sing
# 7762 : cheackout : cheackout
# 7763 : gadikasih : gadikasih
# 7764 : investasi : investasi
# 7765 : digitalterus : digitalterus
# 7766 : penjualannya : jual
# 7767 : saldoternyata : saldoternyata
# 7768 : saldoku : saldo
# 7769 : rekomendasipengirim : rekomendasipengirim
# 7770 : sampaisemenjak : sampaisemenjak
# 7771 : rekomendasipengiriman : rekomendasipengiriman
# 7772 : lamabiasanya : lamabiasanya
# 7773 : sampaibenar : sampaibenar
# 7774 : refine : refine
# 7775 : persusah : susah
# 7776 : hellow : hellow
# 7777 : circle : circle
# 7778 : harnya : harnya
# 7779 : tokopeda : tokopeda
# 7780 : terbelakang : belakang
# 7781 : wkwkkw : wkwkkw
# 7782 : managemant : managemant
# 7783 : mebanyakan : mebanyakan
# 7784 : tertaut : taut
# 7785 : bay : bay
# 7786 : recommendedsukses : recommendedsukses
# 7787 : hpengajuan : hpengajuan
# 7788 : terusbelanja : terusbelanja
# 7789 : izinkan : izin
# 7790 : kado : kado
# 7791 : bokap : bokap
# 7792 : redmi : redmi
# 7793 : note : note
# 7794 : oppo : oppo
# 7795 : rekondisi : rekondisi
# 7796 : ninja : ninja
# 7797 : adilan : adil
# 7798 : bahkam : bahkam
# 7799 : ampasdikit : ampasdikit
# 7800 : blokirmasih : blokirmasih
# 7801 : incaran : incar
# 7802 : macingikan : macingikan
# 7803 : pembaruannya : baru
# 7804 : conofig : conofig
# 7805 : bgtcekout : bgtcekout
# 7806 : terimankasih : terimankasih
# 7807 : vertifikasi : vertifikasi
# 7808 : biken : biken
# 7809 : jakartamedan : jakartamedan
# 7810 : ongkirmantap : ongkirmantap
# 7811 : haluhnya : haluhnya
# 7812 : paksakan : paksa
# 7813 : tokopediamencegah : tokopediamencegah
# 7814 : ecommers : ecommers
# 7815 : tenda : tenda
# 7816 : gunung : gunung
# 7817 : berangkat : berangkat
# 7818 : bang : bang
# 7819 : berenti : renti
# 7820 : komik : komik
# 7821 : website : website
# 7822 : berdosa : dosa
# 7823 : kemanamana : kemanamana
# 7824 : words : words
# 7825 : diilangin : diilangin
# 7826 : demen : demen
# 7827 : kobo : kobo
# 7828 : kanaeru : kanaeru
# 7829 : bldnja : bldnja
# 7830 : belanjan : belanjan
# 7831 : ngerespon : ngerespon
# 7832 : kiya : kiya
# 7833 : dicuekin : dicuekin
# 7834 : kalimatnya : kalimat
# 7835 : manteppppppp : manteppppppp
# 7836 : slurrr : slurrr
# 7837 : bgtpdhlmsh : bgtpdhlmsh
# 7838 : soreapa : soreapa
# 7839 : chatweekend : chatweekend
# 7840 : waduuh : waduuh
# 7841 : maklumin : maklumin
# 7842 : lgsung : lgsung
# 7843 : sepadan : padan
# 7844 : pastinya : pasti
# 7845 : esmosi : esmosi
# 7846 : pengecualian : kecuali
# 7847 : meluas : luas
# 7848 : mengenali : nali
# 7849 : mengurutkan : urut
# 7850 : ara : ara
# 7851 : kore : kore
# 7852 : yatsui : yatsui
# 7853 : memboroskan : boros
# 7854 : baterai : baterai
# 7855 : dibersihkan : bersih
# 7856 : memori : memori
# 7857 : difokuskan : fokus
# 7858 : menggunakannya : guna
# 7859 : background : background
# 7860 : running : running
# 7861 : purna : purna
# 7862 : ditagih : tagih
# 7863 : utang : utang
# 7864 : ancem : ancem
# 7865 : leletpelacakan : leletpelacakan
# 7866 : yqng : yqng
# 7867 : jeblok : jeblok
# 7868 : tokpedpengiriman : tokpedpengiriman
# 7869 : nonggoltokopedia : nonggoltokopedia
# 7870 : ambildulu : ambildulu
# 7871 : beginisetelah : beginisetelah
# 7872 : asuk : asuk
# 7873 : terlacak : lacak
# 7874 : lsg : lsg
# 7875 : begok : begok
# 7876 : merchand : merchand
# 7877 : preses : preses
# 7878 : ajj : ajj
# 7879 : sederhanabiar : sederhanabiar
# 7880 : browsingnya : browsingnya
# 7881 : ajavoucher : ajavoucher
# 7882 : promoin : promoin
# 7883 : boss : boss
# 7884 : kekeliruan : keliru
# 7885 : memaklumi : maklum
# 7886 : kesibukan : sibuk
# 7887 : thinking : thinking
# 7888 : aza : aza
# 7889 : succes : succes
# 7890 : tokopediajual : tokopediajual
# 7891 : buntungkrna : buntungkrna
# 7892 : ngotakpadahal : ngotakpadahal
# 7893 : nyelesain : nyelesain
# 7894 : bonusnyaa : bonusnyaa
# 7895 : timnya : tim
# 7896 : lalai : lalai
# 7897 : customernya : customernya
# 7898 : penanangan : nanang
# 7899 : optimall : optimall
# 7900 : uokeh : uokeh
# 7901 : disambungin : disambungin
# 7902 : telponnya : telpon
# 7903 : bagt : bagt
# 7904 : dapt : dapt
# 7905 : mengatasi : atas
# 7906 : alot : alot
# 7907 : bungkusnya : bungkus
# 7908 : sobek : sobek
# 7909 : basah : basah
# 7910 : cianjur : cianjur
# 7911 : bagusbuat : bagusbuat
# 7912 : darurat : darurat
# 7913 : kpengen : kpengen
# 7914 : disk : disk
# 7915 : cenderung : cenderung
# 7916 : cancelin : cancelin
# 7917 : menyesuaikan : sesuai
# 7918 : satunyasatunya : satunyasatunya
# 7919 : menberikan : menberikan
# 7920 : kesediaan : sedia
# 7921 : alasannyaternyata : alasannyaternyata
# 7922 : berbohong : bohong
# 7923 : ngeprank : ngeprank
# 7924 : xinhuacf : xinhuacf
# 7925 : cazooooomn : cazooooomn
# 7926 : hv : hv
# 7927 : usahhoint : usahhoint
# 7928 : terbaeekkk : terbaeekkk
# 7929 : ruarrrrr : ruarrrrr
# 7930 : muantab : muantab
# 7931 : unyet : unyet
# 7932 : insaf : insaf
# 7933 : ditukar : tukar
# 7934 : tiarap : tiarap
# 7935 : gacorr : gacorr
# 7936 : siptpi : siptpi
# 7937 : dijalankan : jalan
# 7938 : inget : inget
# 7939 : kantonya : kanto
# 7940 : namaku : nama
# 7941 : aya : aya
# 7942 : fazawa : fazawa
# 7943 : recommend : recommend
# 7944 : barag : barag
# 7945 : mengabari : abar
# 7946 : packingnya : packingnya
# 7947 : safety : safety
# 7948 : masang : masang
# 7949 : pembelisangat : pembelisangat
# 7950 : nunggak : nunggak
# 7951 : eeehhh : eeehhh
# 7952 : pinjamnya : pinjam
# 7953 : aturannya : atur
# 7954 : ninjajnt : ninjajnt
# 7955 : mencuri : curi
# 7956 : menukar : tukar
# 7957 : cd : cd
# 7958 : tlp : tlp
# 7959 : namatdk : namatdk
# 7960 : sumber : sumber
# 7961 : penelpon : telpon
# 7962 : selingan : seling
# 7963 : adakarna : adakarna
# 7964 : adabeberapa : adabeberapa
# 7965 : hilanggak : hilanggak
# 7966 : awalkita : awalkita
# 7967 : tersimpanjadi : tersimpanjadi
# 7968 : samak : samak
# 7969 : tinggalliat : tinggalliat
# 7970 : wktnitu : wktnitu
# 7971 : dimanagk : dimanagk
# 7972 : sisah : sisah
# 7973 : caritokped : caritokped
# 7974 : shopeetiapkita : shopeetiapkita
# 7975 : lemana : lana
# 7976 : nyamau : nyamau
# 7977 : smaak : smaak
# 7978 : gtuu : gtuu
# 7979 : carilah : cari
# 7980 : saking : saking
# 7981 : diam : diam
# 7982 : berhak : hak
# 7983 : mengesalkan : kesal
# 7984 : membatalkannya : batal
# 7985 : karpa : karpa
# 7986 : mantapssss : mantapssss
# 7987 : sepelekan : sepele
# 7988 : dtg : dtg
# 7989 : msuk : msuk
# 7990 : ras : ras
# 7991 : heyyyy : heyyyy
# 7992 : kecewaaaa : kecewaaaa
# 7993 : gocap : gocap
# 7994 : terpotong : potong
# 7995 : anijirr : anijirr
# 7996 : bla : bla
# 7997 : suportif : suportif
# 7998 : parno : parno
# 7999 : boleeeeee : boleeeeee
# 8000 : impian : impi
# 8001 : kenyataan : nyata
# 8002 : syukur : syukur
# 8003 : sedalam : dalam
# 8004 : diprosessesuatu : diprosessesuatu
# 8005 : puasdengan : puasdengan
# 8006 : jelajahi : jelajah
# 8007 : berjalannya : jalan
# 8008 : diharapkan : harap
# 8009 : trimah : trimah
# 8010 : kesediaannya : sedia
# 8011 : rodok : rodok
# 8012 : syaulkadaluarsa : syaulkadaluarsa
# 8013 : kecwa : kecwa
# 8014 : fitu : fitu
# 8015 : hargai : harga
# 8016 : fulstt : fulstt
# 8017 : dekt : dekt
# 8018 : masuknya : masuk
# 8019 : tumbangnya : tumbang
# 8020 : trimss : trimss
# 8021 : kongsi : kongsi
# 8022 : mnikmati : mnikmati
# 8023 : jlek : jlek
# 8024 : hah : hah
# 8025 : sicopet : sicopet
# 8026 : bubar : bubar
# 8027 : bangetlama : bangetlama
# 8028 : ngelunjak : ngelunjak
# 8029 : kocakbarang : kocakbarang
# 8030 : padaha : padaha
# 8031 : sampaibenerin : sampaibenerin
# 8032 : aftersales : aftersales
# 8033 : lambatupdate : lambatupdate
# 8034 : updatebisa : updatebisa
# 8035 : kejelasanpokoknya : kejelasanpokoknya
# 8036 : njeh : njeh
# 8037 : monggo : monggo
# 8038 : lis : lis
# 8039 : buk : buk
# 8040 : bogoarum : bogoarum
# 8041 : pacalan : pacal
# 8042 : sumberagung : sumberagung
# 8043 : nitikan : nitikan
# 8044 : randugede : randugede
# 8045 : ngancar : ngancar
# 8046 : sarangan : sarangan
# 8047 : buluharjonjeh : buluharjonjeh
# 8048 : buluharjo : buluharjo
# 8049 : faavorit : faavorit
# 8050 : kebayang : bayang
# 8051 : nilainya : nilai
# 8052 : pelnggan : pelnggan
# 8053 : komitmen : komitmen
# 8054 : setianya : setia
# 8055 : gimanadeh : gimanadeh
# 8056 : baguskalo : baguskalo
# 8057 : benerjangan : benerjangan
# 8058 : doangsama : doangsama
# 8059 : berbedapadahal : berbedapadahal
# 8060 : pree : pree
# 8061 : naikwajib : naikwajib
# 8062 : nantinanti : nantinanti
# 8063 : sreg : sreg
# 8064 : pesawat : pesawat
# 8065 : yauntuk : yauntuk
# 8066 : kurirdan : kurirdan
# 8067 : kebanyak : banyak
# 8068 : tdak : tdak
# 8069 : hubbisa : hubbisa
# 8070 : jabodetabeksemangat : jabodetabeksemangat
# 8071 : berbenahapalagi : berbenahapalagi
# 8072 : berbenha : berbenha
# 8073 : samasoal : samasoal
# 8074 : pengirimanpenanganan : pengirimanpenanganan
# 8075 : tokopediaid : tokopediaid
# 8076 : penyampaian : sampai
# 8077 : berkalatapi : berkalatapi
# 8078 : nihilhati : nihilhati
# 8079 : fyi : fyi
# 8080 : niatnya : niat
# 8081 : charger : charger
# 8082 : seriharusnya : seriharusnya
# 8083 : poco : poco
# 8084 : gym : gym
# 8085 : lipbalm : lipbalm
# 8086 : aslii : asli
# 8087 : payahh : payahh
# 8088 : nnn : nnn
# 8089 : trouble : trouble
# 8090 : hrga : hrga
# 8091 : mrh : mrh
# 8092 : payllater : payllater
# 8093 : pakemakin : pakemakin
# 8094 : silambat : silambat
# 8095 : bersatu : satu
# 8096 : diperkotaan : kota
# 8097 : lemotttttt : lemotttttt
# 8098 : bangetdi : bangetdi
# 8099 : diblock : diblock
# 8100 : harimungkin : harimungkin
# 8101 : revisi : revisi
# 8102 : lunasi : lunas
# 8103 : penghasilan : hasil
# 8104 : riview : riview
# 8105 : nyadi : nyadi
# 8106 : timah : timah
# 8107 : rivew : rivew
# 8108 : ngelebihin : ngelebihin
# 8109 : tamu : tamu
# 8110 : muterin : muterin
# 8111 : sapxpress : sapxpress
# 8112 : seluler : seluler
# 8113 : assalamualaikum : assalamualaikum
# 8114 : tokpedsaya : tokpedsaya
# 8115 : tanyakenapa : tanyakenapa
# 8116 : ami : ami
# 8117 : jim : jim
# 8118 : voucerkode : voucerkode
# 8119 : tokopediasudah : tokopediasudah
# 8120 : bertahundan : bertahundan
# 8121 : diamondknp : diamondknp
# 8122 : syart : syart
# 8123 : ketentuanpadahal : ketentuanpadahal
# 8124 : kejahatanmanipulasi : kejahatanmanipulasi
# 8125 : maksudmohon : maksudmohon
# 8126 : diperiksa : periksa
# 8127 : amijimsaya : amijimsaya
# 8128 : hpmohon : hpmohon
# 8129 : ngentid : ngentid
# 8130 : reasonnya : reasonnya
# 8131 : geblek : geblek
# 8132 : kursus : kursus
# ...
# 11084 : tertibin : tertibin
# 11085 : abdete : abdete
# 11086 : pelangganyg : pelangganyg
# 11087 : digedein : digedein
# 11088 : ginisebenarnya : ginisebenarnya
# 11089 : computer : computer
# 11090 : effort : effort
# 11091 : panaspanasan : panaspanasan
# 11092 : confirm : confirm
# 11093 : ganyangka : ganyangka
# 11094 : haduuh : haduuh
# 11095 : ninggalin : ninggalin
# 11096 : dengki : dengki
# 11097 : koped : koped
# 11098 : diclear : diclear
# 11099 : diinstall : diinstall
# 11100 : updte : updte
# 11101 : tokopediaudah : tokopediaudah
# 11102 : jauhmaksutnya : jauhmaksutnya
# 11103 : loaaaaading : loaaaaading
# 11104 : biaxa : biaxa
# 11105 : ckep : ckep
# 11106 : coment : coment
# 11107 : aplks : aplks
# 11108 : hampur : hampur
# 11109 : ulasanusulan : ulasanusulan
# 11110 : luas : luas
# 11111 : memasukkan : masuk
# 11112 : mgkn : mgkn
# 11113 : sediain : ain
# 11114 : pkus : pkus
# 11115 : perbulan : bulan
# 11116 : duitin : duitin
# 11117 : postingannya : postingannya
# 11118 : melelahkan : lelah
# 11119 : ey : ey
# 11120 : hilankan : hilankan
# 11121 : gimick : gimick
# 11122 : amatiran : amatir
# 11123 : mempercayakan : percaya
# 11124 : bgmana : bgmana
# 11125 : apaapan : apaapan
# 11126 : luaamaaaaa : luaamaaaaa
# 11127 : perbatui : batu
# 11128 : pembayan : pembayan
# 11129 : uangpencaira : uangpencaira
# 11130 : danakarna : danakarna
# 11131 : rbgk : rbgk
# 11132 : ktpdan : ktpdan
# 11133 : kurasa : rasa
# 11134 : mantuap : mantuap
# 11135 : ngehank : ngehank
# 11136 : bett : bett
# 11137 : ditentuin : ditentuin
# 11138 : diterimatapi : diterimatapi
# 11139 : paketnyaklo : paketnyaklo
# 11140 : muda : muda
# 11141 : goooooooooodddd : goooooooooodddd
# 11142 : ggbisa : ggbisa
# 11143 : dremehin : dremehin
# 11144 : senemg : senemg
# 11145 : brngnya : brngnya
# 11146 : integrasi : integrasi
# 11147 : setting : setting
# 11148 : sunggu : sunggu
# 11149 : penyelamat : selamat
# 11150 : guyss : guyss
# 11151 : plise : plise
# 11152 : hatitokopedia : hatitokopedia
# 11153 : tokopediaslow : tokopediaslow
# 11154 : pod : pod
# 11155 : hide : hide
# 11156 : flashsale : flashsale
# 11157 : mampir : mampir
# 11158 : pengrman : pengrman
# 11159 : asah : asah
# 11160 : bisnsnya : bisnsnya
# 11161 : pengrmanya : pengrmanya
# 11162 : jamnya : jam
# 11163 : jni : jni
# 11164 : ngg : ngg
# 11165 : jooss : jooss
# 11166 : pembohongan : bohong
# 11167 : vidioin : vidioin
# 11168 : tokpedlama : tokpedlama
# 11169 : pengirimanudah : pengirimanudah
# 11170 : bisaa : bisaa
# 11171 : bismilllaaaaaaaaaah : bismilllaaaaaaaaaah
# 11172 : rete : rete
# 11173 : ngabisi : ngabisi
# 11174 : parahisi : parahisi
# 11175 : masukbutuh : masukbutuh
# 11176 : jamkalau : jamkalau
# 11177 : adakah : ada
# 11178 : moment : moment
# 11179 : hade : hade
# 11180 : xmantap : xmantap
# 11181 : berwajib : wajib
# 11182 : bergunaekspedisi : bergunaekspedisi
# 11183 : langsungpenjual : langsungpenjual
# 11184 : membantuestimasi : membantuestimasi
# 11185 : diundurpaket : diundurpaket
# 11186 : jalanjalansampah : jalanjalansampah
# 11187 : cessing : cessing
# 11188 : pemburu : buru
# 11189 : berita : berita
# 11190 : beredar : edar
# 11191 : korporatif : korporatif
# 11192 : burukseller : burukseller
# 11193 : pembelibarang : pembelibarang
# 11194 : habisbarang : habisbarang
# 11195 : dikirimmintta : dikirimmintta
# 11196 : ditolakmau : ditolakmau
# 11197 : erorpantesan : erorpantesan
# 11198 : dipahamisukses : dipahamisukses
# 11199 : ngerampok : ngerampok
# 11200 : yaaaabuat : yaaaabuat
# 11201 : insttalll : insttalll
# 11202 : tenannnnn : tenannnnn
# 11203 : nyampainya : nyampainya
# 11204 : ukang : ukang
# 11205 : berjuang : juang
# 11206 : zehahahawikwok : zehahahawikwok
# 11207 : arief : arief
# 11208 : pegadungan : gadung
# 11209 : dy : dy
# 11210 : tmpt : tmpt
# 11211 : esoknya : esok
# 11212 : bekasikok : bekasikok
# 11213 : potongangak : potongangak
# 11214 : klikbca : klikbca
# 11215 : funds : funds
# 11216 : edited : edited
# 11217 : stars : stars
# 11218 : ataudan : ataudan
# 11219 : pelanggar : langgar
# 11220 : promodiskon : promodiskon
# 11221 : dicegah : cegah
# 11222 : preventif : preventif
# 11223 : langanantokopedia : langanantokopedia
# 11224 : mdhn : mdhn
# 11225 : kikir : kikir
# 11226 : intruksi : intruksi
# 11227 : haru : haru
# 11228 : ferivikasi : ferivikasi
# 11229 : jelekmau : jelekmau
# 11230 : bangsat : bangsat
# 11231 : bangsatt : bangsatt
# 11232 : sayangkanmulai : sayangkanmulai
# 11233 : dai : dai
# 11234 : bermasalahsampai : bermasalahsampai
# 11235 : nyagimana : nyagimana
# 11236 : initerlalu : initerlalu
# 11237 : ternama : nama
# 11238 : seternama : nama
# 11239 : ratarata : ratarata
# 11240 : sesat : sesat
# 11241 : maxrb : maxrb
# 11242 : tauk : tauk
# 11243 : padat : padat
# 11244 : jalanjalan : jalanjalan
# 11245 : konsekwensinya : konsekwensinya
# 11246 : responding : responding
# 11247 : tutupberhentikan : tutupberhentikan
# 11248 : segeralah : segera
# 11249 : tibaberubah : tibaberubah
# 11250 : mendadaktanpa : mendadaktanpa
# 11251 : seriusly : seriusly
# 11252 : disapointed : disapointed
# 11253 : ceknya : cek
# 11254 : iniselain : iniselain
# 11255 : tokpe : tokpe
# 11256 : tidk : tidk
# 11257 : sebelahn : sebelahn
# 11258 : hilangpatut : hilangpatut
# 11259 : ksi : ksi
# 11260 : mempercepat : cepat
# 11261 : spinjam : spinjam
# 11262 : limitku : limit
# 11263 : belasan : bas
# 11264 : mengonfimasi : mengonfimasi
# 11265 : inbok : inbok
# 11266 : sbenernya : sbenernya
# 11267 : sempel : sempel
# 11268 : sekalj : sekalj
# 11269 : mohin : mohin
# 11270 : dtunggu : dtunggu
# 11271 : dj : dj
# 11272 : syvpesan : syvpesan
# 11273 : beku : beku
# 11274 : mngkin : mngkin
# 11275 : mengkonsumsi : konsumsi
# 11276 : jelasss : jelasss
# 11277 : rugiiiii : rugiiiii
# 11278 : kayaknyatp : kayaknyatp
# 11279 : vochertp : vochertp
# 11280 : sakitt : sakitt
# 11281 : anehuninstal : anehuninstal
# 11282 : tokpedakun : tokpedakun
# 11283 : hahahaha : hahahaha
# 11284 : gegayaann : gegayaann
# 11285 : ditmbah : ditmbah
# 11286 : teruskatanya : teruskatanya
# 11287 : sistemga : sistemga
# 11288 : jnte : jnte
# 11289 : barangbulanan : barangbulanan
# 11290 : xterus : xterus
# 11291 : ribudan : ribudan
# 11292 : ansangat : ansangat
# 11293 : tot : tot
# {'aplikasi': 'aplikasi', 'complete': 'complete', 'nyaman': 'nyaman', 'cepat': 'cepat', 'terpercaya': 'percaya', 'terimkasih': 'terimkasih', 'tokopedia': 'tokopedia', 'lemot': 'lot', 'bgt': 'bgt', 'pas': 'pas', 'dicancel': 'dicancel', 'vouchernya': 'vouchernya', 'angus': 'angus', 'fak': 'fak', 'apk': 'apk', 'sampah': 'sampah', 'loading': 'loading', 'mulu': 'mulu', 'pembayaran': 'bayar', 'gajelass': 'gajelass', 'anjjj': 'anjjj', 'kali': 'kali', 'akun': 'akun', 'pesanan': 'pesan', 'dibatalkan': 'batal', 'dgn': 'dgn', 'alasan': 'alas', 'indikasi': 'indikasi', 'kesamaan': 'sama', 'blablabla': 'blablabla', 'bagus': 'bagus', 'kurir': 'kurir', 'rekomendasi': 'rekomendasi', 'pengiriman': 'kirim', 'jarak': 'jarak', 'kota': 'kota', 'berdekatan': 'dekat', 'anteraja': 'anteraja', 'sicepat': 'sicepat', 'tracking': 'tracking', 'bikin': 'bikin', 'males': 'males', 'belanja': 'belanja', 'online': 'online', 'dibiarkan': 'biar', 'yg': 'yg', 'pindah': 'pindah', 'hapus': 'hapus', 'rusak': 'rusak', 'reputasi': 'reputasi', 'makasih': 'makasih', 'mantap': 'mantap', 'aplikasinya': 'aplikasi', 'keren': 'keren', 'bagusss': 'bagusss', 'tmbhn': 'tmbhn', 'diskonnya': 'diskon', 'yaaa': 'yaaa', 'sebernya': 'sebernya', 'suka': 'suka', 'dana': 'dana', 'ferund': 'ferund', 'ngk': 'ngk', 'ditarik': 'tarik', 'belanjakan': 'belanja', 'next': 'next', 'day': 'day', 'reguler': 'reguler', 'iklan': 'iklan', 'game': 'game', 'dialihkan': 'alih', 'paksa': 'paksa', 'playsore': 'playsore', 'menggangu': 'menggangu', 'bermain': 'main', 'ga': 'ga', 'pilihan': 'pilih', 'barang': 'barang', 'ckp': 'ckp', 'gw': 'gw', 'privat': 'privat', 'dibuka': 'buka', 'kulirnya': 'kulir', 'pesan': 'pesan', 'tgl': 'tgl', 'tagl': 'tagl', 'sdh': 'sdh', 'depok': 'depok', 'msh': 'msh', 'dpk': 'dpk', 'komplain': 'komplain', 'marah': 'marah', 'siang': 'siang', 'ya': 'ya', 'dibawa': 'bawa', 'kulur': 'kulur', 'jam': 'jam', 'smpe': 'smpe', 'rmh': 'rmh', 'kardus': 'kardus', 'kebuka': 'buka', 'kurirnya': 'kurir', 'gak': 'gak', 'sopan': 'sopan', 'cod': 'cod', 'retur': 'retur', 'apps': 'apps', 'langganan': 'langgan', 'berbayar': 'bayar', 'pilih': 'pilih', 'jasa': 'jasa', 'expedisi': 'expedisi', 'manapun': 'mana', 'tetep': 'tetep', 'ajah': 'ajah', 'kalah': 'kalah', 'pelit': 'pelit', 'vocher': 'vocher', 'sesuai': 'sesuai', 'dikit': 'dikit', 'batalkan': 'batal', 'sistem': 'sistem', 'tolong': 'tolong', 'perbaiki': 'baik', 'banget': 'banget', 'terima': 'terima', 'kasih': 'kasih', 'layanan': 'layan', 'kartu': 'kartu', 'tokopedianya': 'tokopedianya', 'oke': 'oke', 'mantab': 'mantab', 'penjual': 'jual', 'market': 'market', 'place': 'place', 'menu': 'menu', 'fitur': 'fitur', 'mudah': 'mudah', 'pahami': 'paham', 'pusat': 'pusat', 'resolusi': 'resolusi', 'fair': 'fair', 'pembeli': 'beli', 'keberatan': 'berat', 'ongkos': 'ongkos', 'kirim': 'kirim', 'banding': 'banding', 'gandeng': 'gandeng', 'gojek': 'gojek', 'gratis': 'gratis', 'ongkir': 'ongkir', 'kecewa': 'kecewa', 'pakai': 'pakai', 'seminggu': 'minggu', 'blm': 'blm', 'stuck': 'stuck', 'gudang': 'gudang', 'pergerakan': 'gera', 'bobrok': 'bobrok', 'banner': 'banner', 'hoax': 'hoax', 'ok': 'ok', 'parah': 'parah', 'transaksi': 'transaksi', 'udah': 'udah', 'seneng': 'neng', 'dapet': 'dapet', 'voucher': 'voucher', 'eh': 'eh', 'langsung': 'langsung', 'dibatalin': 'dibatalin', 'aja': 'aja', 'ilang': 'ilang', 'bertahun': 'tahun', 'toped': 'toped', 'bebas': 'bebas', 'lempar': 'lempar', 'ekspedisi': 'ekspedisi', 'sapx': 'sapx', 'lemotnya': 'lot', 'ampun': 'ampun', 'kompeten': 'kompeten', 'expired': 'expired', 'dikasih': 'kasih', 'perpanjangan': 'panjang', 'estimasi': 'estimasi', 'intinya': 'inti', 'performance': 'performance', 'deh': 'deh', 'cs': 'cs', 'sombong': 'sombong', 'sejenisnya': 'jenis', 'membantu': 'bantu', 'menyusahkan': 'susah', 'niat': 'niat', 'cari': 'cari', 'diskon': 'diskon', 'pake': 'pake', 'ibuk': 'ibuk', 'tpi': 'tpi', 'ngrasa': 'ngrasa', 'tipu': 'tipu', 'pengguna': 'guna', 'voucer': 'voucer', 'rp': 'rp', 'bayar': 'bayar', 'berhasil': 'hasil', 'detik': 'detik', ...
# ------------------------
#                                               content  score  \
# 0   aplikasi paling complete nyaman cepat terperca...      5
# 1   Lemot bgt, pas dicancel malahan vouchernya ang...      1
# 2        Apk sampah loading Mulu waktu mau pembayaran      1
# 3   APK GAJELASS ANJJJ, BARU PERTAMA KALI BUAT AKU...      1
# 4                                     Tokopedia bagus      5
# 5   Sejak ada kurir rekomendasi, pengiriman malah ...      3
# 6                       makasih mantap aplikasinya👍👍👍      5
# 7                                               keren      5
# 8                  bagusss, tmbhn diskonnya yaaa.....      5
# 9   sebernya suka cuma kenapa dana ferund di bawah...      3
# 10                     Kurir next day rasa reguler...      1
# 11  Kepada pihak Tokopedia... kalau mau bikin ikla...      1
# 12       Kenapa sekarang ga ada pilihan jumlah barang      5
# 13  Ini ckp sekali gw belanja di sini, barang priv...      1
# 14                                             mantap      5
# 15        Tidak bisa cod saya padahal ga pernah retur      1
# 16                                               baik      5
# 17               apps langganan buat berbayar online👍      5
# 18                                              Bagus      5
# 19                                             mantap      4
#
#                                            text_clean  \
# 0   aplikasi paling complete nyaman cepat terperca...
# 1   lemot bgt pas dicancel malahan vouchernya angu...
# 2        apk sampah loading mulu waktu mau pembayaran
# 3   apk gajelass anjjj baru pertama kali buat akun...
# 4                                     tokopedia bagus
# 5   sejak ada kurir rekomendasi pengiriman malah j...
# 6                          makasih mantap aplikasinya
# 7                                               keren
# 8                        bagusss tmbhn diskonnya yaaa
# 9   sebernya suka cuma kenapa dana ferund di bawah...
# 10                        kurir next day rasa reguler
# 11  kepada pihak tokopedia kalau mau bikin iklan d...
# 12       kenapa sekarang ga ada pilihan jumlah barang
# 13  ini ckp sekali gw belanja di sini barang priva...
# 14                                             mantap
# 15        tidak bisa cod saya padahal ga pernah retur
# 16                                               baik
# 17                apps langganan buat berbayar online
# 18                                              bagus
# 19                                             mantap
#
#                                         text_StopWord  \
# 0   aplikasi complete nyaman cepat terpercaya teri...
# 1         lemot bgt pas dicancel vouchernya angus fak
# 2                  apk sampah loading mulu pembayaran
# 3   apk gajelass anjjj kali akun pesanan dibatalka...
# 4                                     tokopedia bagus
# 5   kurir rekomendasi pengiriman jarak kota berdek...
# 6                          makasih mantap aplikasinya
# 7                                               keren
# 8                        bagusss tmbhn diskonnya yaaa
# 9    sebernya suka dana ferund ngk ditarik belanjakan
# 10                             kurir next day reguler
# 11  tokopedia bikin iklan game dialihkan paksa pla...
# 12                                  ga pilihan barang
# 13  ckp gw belanja barang privat gw dibuka kulirny...
# 14                                             mantap
# 15                                       cod ga retur
# 16
# 17                     apps langganan berbayar online
# 18                                              bagus
# 19                                             mantap
#
#                                           text_tokens  \
# 0   [aplikasi, complete, nyaman, cepat, terpercaya...
# 1   [lemot, bgt, pas, dicancel, vouchernya, angus,...
# 2            [apk, sampah, loading, mulu, pembayaran]
# 3   [apk, gajelass, anjjj, kali, akun, pesanan, di...
# 4                                  [tokopedia, bagus]
# 5   [kurir, rekomendasi, pengiriman, jarak, kota, ...
# 6                      [makasih, mantap, aplikasinya]
# 7                                             [keren]
# 8                   [bagusss, tmbhn, diskonnya, yaaa]
# 9   [sebernya, suka, dana, ferund, ngk, ditarik, b...
# 10                        [kurir, next, day, reguler]
# 11  [tokopedia, bikin, iklan, game, dialihkan, pak...
# 12                              [ga, pilihan, barang]
# 13  [ckp, gw, belanja, barang, privat, gw, dibuka,...
# 14                                           [mantap]
# 15                                   [cod, ga, retur]
# 16                                                 []
# 17                [apps, langganan, berbayar, online]
# 18                                            [bagus]
# 19                                           [mantap]
#
#                                        text_steamindo
# 0   aplikasi complete nyaman cepat percaya terimka...
# 1           lot bgt pas dicancel vouchernya angus fak
# 2                       apk sampah loading mulu bayar
# 3   apk gajelass anjjj kali akun pesan batal dgn a...
# 4                                     tokopedia bagus
# 5   kurir rekomendasi kirim jarak kota dekat anter...
# 6                             makasih mantap aplikasi
# 7                                               keren
# 8                           bagusss tmbhn diskon yaaa
# 9         sebernya suka dana ferund ngk tarik belanja
# 10                             kurir next day reguler
# 11  tokopedia bikin iklan game alih paksa playsore...
# 12                                    ga pilih barang
# 13  ckp gw belanja barang privat gw buka kulir gw ...
# 14                                             mantap
# 15                                       cod ga retur
# 16
# 17                          apps langgan bayar online
# 18                                              bagus
# 19                                             mantap

# %%
data_clean.to_csv('tokopedia.csv', index= False) #kemudian simpan hasil text preprocessing ke file csv
