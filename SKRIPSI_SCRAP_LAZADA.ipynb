# %%
# !pip install google-play-scraper
# Out:
# Collecting google-play-scraper
#   Downloading google_play_scraper-1.2.7-py3-none-any.whl (28 kB)
# Installing collected packages: google-play-scraper
# Successfully installed google-play-scraper-1.2.7

# %%
import google_play_scraper

# %%
app_id = 'com.lazada.android'

# %%
from google_play_scraper import Sort
from google_play_scraper.constants.element import ElementSpecs
from google_play_scraper.constants.regex import Regex
from google_play_scraper.constants.request import Formats
from google_play_scraper.utils.request import post

import pandas as pd
from datetime import datetime
from tqdm import tqdm
import time
import json
from time import sleep
from typing import List, Optional, Tuple

# %%
MAX_COUNT_EACH_FETCH = 199


class _ContinuationToken:
    __slots__ = (
        "token",
        "lang",
        "country",
        "sort",
        "count",
        "filter_score_with",
        "filter_device_with",
    )

    def __init__(
        self, token, lang, country, sort, count, filter_score_with, filter_device_with
    ):
        self.token = token
        self.lang = lang
        self.country = country
        self.sort = sort
        self.count = count
        self.filter_score_with = filter_score_with
        self.filter_device_with = filter_device_with


def _fetch_review_items(
    url: str,
    app_id: str,
    sort: int,
    count: int,
    filter_score_with: Optional[int],
    filter_device_with: Optional[int],
    pagination_token: Optional[str],
):
    dom = post(
        url,
        Formats.Reviews.build_body(
            app_id,
            sort,
            count,
            "null" if filter_score_with is None else filter_score_with,
            "null" if filter_device_with is None else filter_device_with,
            pagination_token,
        ),
        {"content-type": "application/x-www-form-urlencoded"},
    )
    match = json.loads(Regex.REVIEWS.findall(dom)[0])

    return json.loads(match[0][2])[0], json.loads(match[0][2])[-2][-1]


def reviews(
    app_id: str,
    lang: str = "en",
    country: str = "us",
    sort: Sort = Sort.MOST_RELEVANT,
    count: int = 100,
    filter_score_with: int = None,
    filter_device_with: int = None,
    continuation_token: _ContinuationToken = None,
) -> Tuple[List[dict], _ContinuationToken]:
    sort = sort.value

    if continuation_token is not None:
        token = continuation_token.token

        if token is None:
            return (
                [],
                continuation_token,
            )

        lang = continuation_token.lang
        country = continuation_token.country
        sort = continuation_token.sort
        count = continuation_token.count
        filter_score_with = continuation_token.filter_score_with
        filter_device_with = continuation_token.filter_device_with
    else:
        token = None

    url = Formats.Reviews.build(lang=lang, country=country)

    _fetch_count = count

    result = []

    while True:
        if _fetch_count == 0:
            break

        if _fetch_count > MAX_COUNT_EACH_FETCH:
            _fetch_count = MAX_COUNT_EACH_FETCH

        try:
            review_items, token = _fetch_review_items(
                url,
                app_id,
                sort,
                _fetch_count,
                filter_score_with,
                filter_device_with,
                token,
            )
        except (TypeError, IndexError):
            #funnan MOD start
            token = continuation_token.token
            continue
            #MOD end

        for review in review_items:
            result.append(
                {
                    k: spec.extract_content(review)
                    for k, spec in ElementSpecs.Review.items()
                }
            )

        _fetch_count = count - len(result)

        if isinstance(token, list):
            token = None
            break

    return (
        result,
        _ContinuationToken(
            token, lang, country, sort, count, filter_score_with, filter_device_with
        ),
    )


def reviews_all(app_id: str, sleep_milliseconds: int = 0, **kwargs) -> list:
    kwargs.pop("count", None)
    kwargs.pop("continuation_token", None)

    continuation_token = None

    result = []

    while True:
        _result, continuation_token = reviews(
            app_id,
            count=MAX_COUNT_EACH_FETCH,
            continuation_token=continuation_token,
            **kwargs
        )

        result += _result

        if continuation_token.token is None:
            break

        if sleep_milliseconds:
            sleep(sleep_milliseconds / 1000)

    return result

# %%
reviews_count = 10000

# %%
result = []
continuation_token = None


with tqdm(total=reviews_count, position=0, leave=True) as pbar:
    while len(result) < reviews_count:
        new_result, continuation_token = reviews(
            app_id,
            continuation_token=continuation_token,
            lang='id', #The language of review
            country='id', #Country for which you want to scrape
            sort=Sort.NEWEST,
            filter_score_with=None,
            count=199 #No need to change this
        )
        if not new_result:
            break
        result.extend(new_result)
        pbar.update(len(new_result))
# Out:
# 10149it [00:13, 742.59it/s]

# %%
import numpy as np
df = pd.DataFrame(np.array(result),columns=['review'])

df = df.join(pd.DataFrame(df.pop('review').tolist()))

df.head()
# Out:
#                                reviewId         userName  \
# 0  08b0e3d0-5802-4466-92db-46b736b2ec0b      Rendy Wahyu
# 1  c4a41ad2-178d-494c-8ea8-1622441c4ea3    tiara virgina
# 2  e9ae32ff-1e09-4ec0-8183-70804812f017    Satria Minang
# 3  ecd87c43-4d41-4522-a7ae-a32e412a4e62    Firdza Firdza
# 4  7b1d0a47-6b50-4093-8dab-cefb33cab028  Triyanto Banjar
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/a/ACg8oc...
# 1  https://play-lh.googleusercontent.com/a/ACg8oc...
# 2  https://play-lh.googleusercontent.com/a/ACg8oc...
# 3  https://play-lh.googleusercontent.com/a-/ALV-U...
# 4  https://play-lh.googleusercontent.com/a-/ALV-U...
#
#                        content  score  thumbsUpCount reviewCreatedVersion  \
# 0                        bagus      5              0               7.52.0
# 1            barangnya bagus 👍      5              0               7.52.0
# 2  kenapa gak bisa cod lagi ya      4              0                 None
# 3                         good      5              0               7.52.0
# 4                       mntapp      5              0               7.51.0
#
#                    at replyContent repliedAt appVersion
# 0 2024-06-14 16:18:31         None       NaT     7.52.0
# 1 2024-06-14 16:17:59         None       NaT     7.52.0
# 2 2024-06-14 16:16:12         None       NaT       None
# 3 2024-06-14 16:13:51         None       NaT     7.52.0
# 4 2024-06-14 16:12:17         None       NaT     7.51.0

# %%
len(df)
# Out:
# 10149

# %%
df[['userName', 'score','at', 'content']].head()  #dari scrapping tsb didapatkan banyak sekali kolom, kemudian kolom" tsb kita filter
                                                        #sehingga didapatkan kolom username, score, at dan content
# Out:
#           userName  score                  at                      content
# 0      Rendy Wahyu      5 2024-06-14 16:18:31                        bagus
# 1    tiara virgina      5 2024-06-14 16:17:59            barangnya bagus 👍
# 2    Satria Minang      4 2024-06-14 16:16:12  kenapa gak bisa cod lagi ya
# 3    Firdza Firdza      5 2024-06-14 16:13:51                         good
# 4  Triyanto Banjar      5 2024-06-14 16:12:17                       mntapp

# %%
df=df[['content', 'score']]#karena kita hanya membutuhkan kolom content dan score maka kita lakukan filter kolom lgi hing
df.head()
# Out:
#                        content  score
# 0                        bagus      5
# 1            barangnya bagus 👍      5
# 2  kenapa gak bisa cod lagi ya      4
# 3                         good      5
# 4                       mntapp      5

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10149 entries, 0 to 10148
# Data columns (total 2 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   content  10149 non-null  object
#  1   score    10149 non-null  int64
# dtypes: int64(1), object(1)
# memory usage: 158.7+ KB

# %%
df.isna()
# Out:
#        content  score
# 0        False  False
# 1        False  False
# 2        False  False
# 3        False  False
# 4        False  False
# ...        ...    ...
# 10144    False  False
# 10145    False  False
# 10146    False  False
# 10147    False  False
# 10148    False  False
#
# [10149 rows x 2 columns]

# %%
df.describe()
# Out:
#               score
# count  10149.000000
# mean       4.395408
# std        1.255819
# min        1.000000
# 25%        5.000000
# 50%        5.000000
# 75%        5.000000
# max        5.000000

# %%
df.isnull().sum()
# Out:
# content    0
# score      0
# dtype: int64

# %%
df.to_csv("hasil-scrap-lazada.csv", index = False) #simpan csv

# %% [markdown]
# # **PREPROCESSING**

# %% [markdown]
# Case Folding

# %%
import re
def  clean_text(df, text_field, new_text_field_name):
    df[new_text_field_name] = df[text_field].str.lower()
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"(@[A-Za-z0-9]+)|([^0-9A-Za-z \t])|(\w+:\/\/\S+)|^rt|http.+?", "", elem))
    # remove numbers
    df[new_text_field_name] = df[new_text_field_name].apply(lambda elem: re.sub(r"\d+", "", elem))
    return df

# %%
df['text_clean'] = df['content'].str.lower()
df['text_clean']
data_clean = clean_text(df, 'content', 'text_clean')
data_clean.head(10)
# Out:
#                                              content  score  \
# 0                                              bagus      5
# 1                                  barangnya bagus 👍      5
# 2                        kenapa gak bisa cod lagi ya      4
# 3                                               good      5
# 4                                             mntapp      5
# 5      banyak diskon pengiriman aman pengemasan baik      5
# 6                         memudahkan ibu2 yg bekerja      5
# 7      semoga cepat sampai dan tidak mengecewakan ..      5
# 8  saya puas blanja di lazada,barangnya bagus den...      5
# 9                                              dryio      5
#
#                                           text_clean
# 0                                              bagus
# 1                                   barangnya bagus
# 2                        kenapa gak bisa cod lagi ya
# 3                                               good
# 4                                             mntapp
# 5      banyak diskon pengiriman aman pengemasan baik
# 6                          memudahkan ibu yg bekerja
# 7        semoga cepat sampai dan tidak mengecewakan
# 8  saya puas blanja di lazadabarangnya bagus deng...
# 9                                              dryio

# %% [markdown]
# Stopword Removal

# %%
import nltk.corpus
nltk.download('stopwords')
from nltk.corpus import stopwords
stop = stopwords.words('indonesian')
data_clean['text_StopWord'] = data_clean['text_clean'].apply(lambda x:' '.join([word for word in x.split() if word not in (stop)]))
data_clean.head(50)
# Out:
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
#                                               content  score  \
# 0                                               bagus      5
# 1                                   barangnya bagus 👍      5
# 2                         kenapa gak bisa cod lagi ya      4
# 3                                                good      5
# 4                                              mntapp      5
# 5       banyak diskon pengiriman aman pengemasan baik      5
# 6                          memudahkan ibu2 yg bekerja      5
# 7       semoga cepat sampai dan tidak mengecewakan ..      5
# 8   saya puas blanja di lazada,barangnya bagus den...      5
# 9                                               dryio      5
# 10                                                  👍      5
# 11                                               baik      5
# 12                    Murah murah harga nya di Lazada      5
# 13               Lumayan buat nambah ilmu pengetahuan      5
# 14                                               Good      5
# 15                                         segitu dlu      3
# 16                                       proses cepat      5
# 17        bagus sangat memuaskan dan rekomended keren      5
# 18             sangat memuaskan belanja di lazada 😊🥰😍      5
# 19                                      trmksh lazada      5
# 20    Murah" ya penguna baru kebanyakan harga nya 0Rp      5
# 21                        pukonya mantul mantam betul      5
# 22                                             mantap      5
# 23                   belanja sangat mudah dan efisien      5
# 24                                               puas      4
# 25                      Kenapah Lazada Gangguan terus      5
# 26                                                  👌      5
# 27  Ongkir tmbh mhl dan gk tersedia gratis ongkir nya      1
# 28                                       Mitha Fachmi      4
# 29                                      mantap lazada      5
# 30                                   Iklan mengganggu      1
# 31                                        sangat baik      5
# 32  Tolong di tertibkan seller yan tidak amanah / ...      5
# 33                                                 ok      5
# 34                   Pengembalian dananya lama banget      1
# 35                                     sangat canggih      5
# 36                                             mantap      5
# 37  Kenapa akun saya gak bisa menggunakan metode c...      3
# 38  Pengiriman super lama saya beli dari tgl 8 tib...      3
# 39                                              Hebat      5
# 40                                    Lazada the best      5
# 41                             pengiririman nya cepat      5
# 42  Gratis ongkir? Hanya teks saja, aslinya hanya ...      1
# 43  semoga brang datang sesuai pesenan ya, toko jg...      5
# 44                         Masih enak an versi lama..      5
# 45                   Barang asli dan mudah di percaya      5
# 46                                                COD      3
# 47                                                 ok      5
# 48                                       dua aja dulu      2
# 49                                             mantap      5
#
#                                            text_clean  \
# 0                                               bagus
# 1                                    barangnya bagus
# 2                         kenapa gak bisa cod lagi ya
# 3                                                good
# 4                                              mntapp
# 5       banyak diskon pengiriman aman pengemasan baik
# 6                           memudahkan ibu yg bekerja
# 7         semoga cepat sampai dan tidak mengecewakan
# 8   saya puas blanja di lazadabarangnya bagus deng...
# 9                                               dryio
# 10
# 11                                               baik
# 12                    murah murah harga nya di lazada
# 13               lumayan buat nambah ilmu pengetahuan
# 14                                               good
# 15                                         segitu dlu
# 16                                       proses cepat
# 17        bagus sangat memuaskan dan rekomended keren
# 18                sangat memuaskan belanja di lazada
# 19                                      trmksh lazada
# 20      murah ya penguna baru kebanyakan harga nya rp
# 21                        pukonya mantul mantam betul
# 22                                             mantap
# 23                   belanja sangat mudah dan efisien
# 24                                               puas
# 25                      kenapah lazada gangguan terus
# 26
# 27  ongkir tmbh mhl dan gk tersedia gratis ongkir nya
# 28                                       mitha fachmi
# 29                                      mantap lazada
# 30                                   iklan mengganggu
# 31                                        sangat baik
# 32  tolong di tertibkan seller yan tidak amanah  n...
# 33                                                 ok
# 34                   pengembalian dananya lama banget
# 35                                     sangat canggih
# 36                                             mantap
# 37  kenapa akun saya gak bisa menggunakan metode c...
# 38  pengiriman super lama saya beli dari tgl  tiba...
# 39                                              hebat
# 40                                    lazada the best
# 41                             pengiririman nya cepat
# 42  gratis ongkir hanya teks saja aslinya hanya di...
# 43  semoga brang datang sesuai pesenan ya toko jg ...
# 44                           masih enak an versi lama
# 45                   barang asli dan mudah di percaya
# 46                                                cod
# 47                                                 ok
# 48                                       dua aja dulu
# 49                                             mantap
#
#                                         text_StopWord
# 0                                               bagus
# 1                                     barangnya bagus
# 2                                          gak cod ya
# 3                                                good
# 4                                              mntapp
# 5                   diskon pengiriman aman pengemasan
# 6                                       memudahkan yg
# 7                           semoga cepat mengecewakan
# 8   puas blanja lazadabarangnya bagus harga yg ter...
# 9                                               dryio
# 10
# 11
# 12                       murah murah harga nya lazada
# 13                    lumayan nambah ilmu pengetahuan
# 14                                               good
# 15                                         segitu dlu
# 16                                       proses cepat
# 17                   bagus memuaskan rekomended keren
# 18                           memuaskan belanja lazada
# 19                                      trmksh lazada
# 20           murah ya penguna kebanyakan harga nya rp
# 21                              pukonya mantul mantam
# 22                                             mantap
# 23                              belanja mudah efisien
# 24                                               puas
# 25                            kenapah lazada gangguan
# 26
# 27      ongkir tmbh mhl gk tersedia gratis ongkir nya
# 28                                       mitha fachmi
# 29                                      mantap lazada
# 30                                   iklan mengganggu
# 31
# 32  tolong tertibkan seller yan amanah nakal curan...
# 33                                                 ok
# 34                        pengembalian dananya banget
# 35                                            canggih
# 36                                             mantap
# 37  akun gak metode cod ganti akunpun g tolong ban...
# 38               pengiriman super beli tgl tgl haduhh
# 39                                              hebat
# 40                                    lazada the best
# 41                             pengiririman nya cepat
# 42  gratis ongkir teks aslinya dipotong ga berbagi...
# 43      semoga brang sesuai pesenan ya toko jg amanah
# 44                                      enak an versi
# 45                          barang asli mudah percaya
# 46                                                cod
# 47                                                 ok
# 48                                                aja
# 49                                             mantap

# %% [markdown]
# **Tokenizing**

# %%
nltk.download('punkt')
from nltk.tokenize import sent_tokenize, word_tokenize
data_clean['text_tokens'] = data_clean['text_StopWord'].apply(lambda x: word_tokenize(x))
data_clean.head()
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
#                        content  score                   text_clean  \
# 0                        bagus      5                        bagus
# 1            barangnya bagus 👍      5             barangnya bagus
# 2  kenapa gak bisa cod lagi ya      4  kenapa gak bisa cod lagi ya
# 3                         good      5                         good
# 4                       mntapp      5                       mntapp
#
#      text_StopWord         text_tokens
# 0            bagus             [bagus]
# 1  barangnya bagus  [barangnya, bagus]
# 2       gak cod ya      [gak, cod, ya]
# 3             good              [good]
# 4           mntapp            [mntapp]

# %% [markdown]
# **Stemming**

# %%
# !pip install Sastrawi
# Out:
# Collecting Sastrawi
#   Downloading Sastrawi-1.0.1-py2.py3-none-any.whl (209 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 209.7/209.7 kB 5.7 MB/s eta 0:00:00
# Installing collected packages: Sastrawi
# Successfully installed Sastrawi-1.0.1

# %%
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# %%
#-----------------STEMMING -----------------
from Sastrawi.Stemmer.StemmerFactory import StemmerFactory
#import swifter


# create stemmer
factory = StemmerFactory()
stemmer = factory.create_stemmer()

# stemmed
def stemmed_wrapper(term):
    return stemmer.stem(term)

term_dict = {}
hitung=0

for document in data_clean['text_tokens']:
    for term in document:
        if term not in term_dict:
            term_dict[term] = ' '

print(len(term_dict))
print("------------------------")
for term in term_dict:
    term_dict[term] = stemmed_wrapper(term)
    hitung+=1
    print(hitung,":",term,":" ,term_dict[term])

print(term_dict)
print("------------------------")

# apply stemmed term to dataframe
def get_stemmed_term(document):
    return [term_dict[term] for term in document]


#script ini bisa dipisah dari eksekusinya setelah pembacaaan term selesai
data_clean['text_steamindo'] = data_clean['text_tokens'].apply(lambda x:' '.join(get_stemmed_term(x)))
data_clean.head(20)
# Out:
# Output streaming akan dipotong hingga 5000 baris terakhir.
# 2300 : borong : borong
# 2301 : sua : sua
# 2302 : berkurang : kurang
# 2303 : apik : apik
# 2304 : menjual : jual
# 2305 : photo : photo
# 2306 : dikantong : kantong
# 2307 : loginpdhal : loginpdhal
# 2308 : wifi : wifi
# 2309 : bermutu : mutu
# 2310 : trms : trms
# 2311 : permasalahan : masalah
# 2312 : optimalkan : optimal
# 2313 : mantapp : mantapp
# 2314 : okee : okee
# 2315 : lohhh : lohhh
# 2316 : knapa : knapa
# 2317 : mantabb : mantabb
# 2318 : man : man
# 2319 : faat : faat
# 2320 : pokonyah : pokonyah
# 2321 : tamba : tamba
# 2322 : melebihi : lebih
# 2323 : batas : batas
# 2324 : ditunggu : tunggu
# 2325 : kuwalitas : kuwalitas
# 2326 : makasi : makas
# 2327 : membntuuntuk : membntuuntuk
# 2328 : maci : maci
# 2329 : blaja : blaja
# 2330 : nati : nati
# 2331 : hamba : hamba
# 2332 : urusan : urus
# 2333 : gajelasmain : gajelasmain
# 2334 : nolkecewa : nolkecewa
# 2335 : eww : eww
# 2336 : pass : pass
# 2337 : dibuka : buka
# 2338 : barangyang : barangyang
# 2339 : mudahmurah : mudahmurah
# 2340 : persis : persis
# 2341 : iklankan : iklan
# 2342 : deskripsinya : deskripsi
# 2343 : skli : skli
# 2344 : sbnarnya : sbnarnya
# 2345 : prnh : prnh
# 2346 : kcwabeli : kcwabeli
# 2347 : lazadakrna : lazadakrna
# 2348 : kasurku : kasur
# 2349 : smlm : smlm
# 2350 : kra : kra
# 2351 : keciltp : keciltp
# 2352 : bangetpantesan : bangetpantesan
# 2353 : suksespengiriman : suksespengiriman
# 2354 : cepatkurir : cepatkurir
# 2355 : ramahsemoga : ramahsemoga
# 2356 : captcha : captcha
# 2357 : baiik : baiik
# 2358 : raih : raih
# 2359 : pokotnya : pokotnya
# 2360 : trimkasih : trimkasih
# 2361 : harapkan : harap
# 2362 : tdnya : tdnya
# 2363 : dibandingkan : banding
# 2364 : kacang : kacang
# 2365 : mede : mede
# 2366 : kg : kg
# 2367 : sp : sp
# 2368 : rmh : rmh
# 2369 : berisi : isi
# 2370 : ons : ons
# 2371 : mank : mank
# 2372 : bguus : bguus
# 2373 : pngriman : pngriman
# 2374 : breestolong : breestolong
# 2375 : cri : cri
# 2376 : bnaramnah : bnaramnah
# 2377 : puass : puass
# 2378 : lazana : lazana
# 2379 : terburuk : buruk
# 2380 : relevan : relevan
# 2381 : permasalahannya : masalah
# 2382 : fix : fix
# 2383 : ditujuan : tuju
# 2384 : dirubah : rubah
# 2385 : bertambah : tambah
# 2386 : kopi : kopi
# 2387 : syuuukaaa : syuuukaaa
# 2388 : bangetttt : bangetttt
# 2389 : baguus : baguus
# 2390 : merge : merge
# 2391 : boss : boss
# 2392 : style : style
# 2393 : lazzrewd : lazzrewd
# 2394 : tanggapan : tanggap
# 2395 : prmasalahan : prmasalahan
# 2396 : riwayat : riwayat
# 2397 : tertulis : tulis
# 2398 : boos : boos
# 2399 : menukarkai : menukarkai
# 2400 : geme : geme
# 2401 : shingga : shingga
# 2402 : smentara : smentara
# 2403 : terselesaikan : selesai
# 2404 : rekomend : rekomend
# 2405 : wasa : wasa
# 2406 : penagihan : tagih
# 2407 : kasar : kasar
# 2408 : perjalanan : jalan
# 2409 : tua : tua
# 2410 : ngomel : ngomel
# 2411 : omel : omel
# 2412 : percobaan : coba
# 2413 : hrgnya : hrgnya
# 2414 : dirumah : rumah
# 2415 : pergi : pergi
# 2416 : cr : cr
# 2417 : syuukaa : syuukaa
# 2418 : poto : poto
# 2419 : ninjavan : ninjavan
# 2420 : taii : taii
# 2421 : iiii : iiii
# 2422 : eeeee : eeeee
# 2423 : saranin : saranin
# 2424 : pemakaiannya : pakai
# 2425 : refundcs : refundcs
# 2426 : org : org
# 2427 : balea : balea
# 2428 : computer : computer
# 2429 : tulisan : tulis
# 2430 : catatan : catat
# 2431 : ntr : ntr
# 2432 : pesennya : sen
# 2433 : lagigratis : lagigratis
# 2434 : adaongkir : adaongkir
# 2435 : hehhjejejje : hehhjejejje
# 2436 : baikkkk : baikkkk
# 2437 : smangatt : smangatt
# 2438 : sukaaaa : sukaaaa
# 2439 : cabang : cabang
# 2440 : boot : boot
# 2441 : makanan : makan
# 2442 : relate : relate
# 2443 : pakainya : pakai
# 2444 : mgkn : mgkn
# 2445 : alami : alami
# 2446 : spt : spt
# 2447 : live : live
# 2448 : replynya : replynya
# 2449 : pengirim : kirim
# 2450 : tks : tks
# 2451 : thanks : thanks
# 2452 : nonaktifin : nonaktifin
# 2453 : bertele : tele
# 2454 : ngehapus : ngehapus
# 2455 : directly : directly
# 2456 : updated : updated
# 2457 : menonaktifkan : nonaktif
# 2458 : again : again
# 2459 : direset : direset
# 2460 : passwordnya : passwordnya
# 2461 : nyangkut : nyangkut
# 2462 : didevice : didevice
# 2463 : kaum : kaum
# 2464 : prestasinya : prestasi
# 2465 : josss : josss
# 2466 : inimahhhhhhy : inimahhhhhhy
# 2467 : semuaaaa : semuaaaa
# 2468 : mantappppp : mantappppp
# 2469 : cepatkemasan : cepatkemasan
# 2470 : berterima : terima
# 2471 : seleraku : selera
# 2472 : tampat : tampat
# 2473 : bosku : bos
# 2474 : sukanya : suka
# 2475 : ngadat : ngadat
# 2476 : ngaco : ngaco
# 2477 : benahi : benah
# 2478 : terkait : kait
# 2479 : seharus : harus
# 2480 : melenceng : lenceng
# 2481 : contoh : contoh
# 2482 : filter : filter
# 2483 : udara : udara
# 2484 : chainsaw : chainsaw
# 2485 : motor : motor
# 2486 : beat : beat
# 2487 : pasang : pasang
# 2488 : rendah : rendah
# 2489 : sistemnya : sistem
# 2490 : apasal : apasal
# 2491 : teruk : teruk
# 2492 : ip : ip
# 2493 : sabtu : sabtu
# 2494 : selasa : selasa
# 2495 : tt : tt
# 2496 : enyah : enyah
# 2497 : mengemasmengirimkan : mengemasmengirimkan
# 2498 : minimal : minimal
# 2499 : kya : kya
# 2500 : beroda : roda
# 2501 : baiksesuai : baiksesuai
# 2502 : pesanankurirnya : pesanankurirnya
# 2503 : ramai : ramai
# 2504 : senneng : senneng
# 2505 : wooww : wooww
# 2506 : lazrewad : lazrewad
# 2507 : ditipu : tipu
# 2508 : thd : thd
# 2509 : dispenser : dispenser
# 2510 : cosmos : cosmos
# 2511 : td : td
# 2512 : terjadil : terjadil
# 2513 : moduspenipuan : moduspenipuan
# 2514 : viralkan : viralkan
# 2515 : kekecewaan : kecewa
# 2516 : netizen : netizen
# 2517 : kalayak : kalayak
# 2518 : maklum : maklum
# 2519 : nympe : nympe
# 2520 : pajang : pajang
# 2521 : kerjanya : kerja
# 2522 : yapaket : yapaket
# 2523 : ngestuck : ngestuck
# 2524 : muluklo : muluklo
# 2525 : barangkirim : barangkirim
# 2526 : duluan : duluan
# 2527 : kirimmasa : kirimmasa
# 2528 : duluingiliran : duluingiliran
# 2529 : mesen : mesen
# 2530 : kirimbahkan : kirimbahkan
# 2531 : kotaaneh : kotaaneh
# 2532 : sumpahhnungguin : sumpahhnungguin
# 2533 : masalahnyaklo : masalahnyaklo
# 2534 : daun : daun
# 2535 : papatolong : papatolong
# 2536 : benerin : benerin
# 2537 : ginikasian : ginikasian
# 2538 : trims : trims
# 2539 : lazadablanja : lazadablanja
# 2540 : laris : laris
# 2541 : manis : manis
# 2542 : sikses : sikses
# 2543 : berbelanjasemoga : berbelanjasemoga
# 2544 : depannya : depan
# 2545 : meningkatkan : tingkat
# 2546 : kenyamanan : nyaman
# 2547 : penggunanyaterima : penggunanyaterima
# 2548 : kasihwassalaam : kasihwassalaam
# 2549 : pengajuan : aju
# 2550 : lancartapi : lancartapi
# 2551 : pasan : pas
# 2552 : kesalahan : salah
# 2553 : kwalitasnya : kwalitasnya
# 2554 : tujuanterimakasih : tujuanterimakasih
# 2555 : cekout : cekout
# 2556 : pastinya : pasti
# 2557 : goyang : goyang
# 2558 : ragukan : ragu
# 2559 : kagum : kagum
# 2560 : sesui : sesui
# 2561 : kepuasan : puas
# 2562 : utama : utama
# 2563 : sukak : sukak
# 2564 : diskonnyaaa : diskonnyaaa
# 2565 : goood : goood
# 2566 : sma : sma
# 2567 : negeri : negeri
# 2568 : krja : krja
# 2569 : iik : iik
# 2570 : lakukan : laku
# 2571 : okiku : okiku
# 2572 : ikk : ikk
# 2573 : knj : knj
# 2574 : kokknkkkkk : kokknkkkkk
# 2575 : oot : oot
# 2576 : ikkkkk : ikkkkk
# 2577 : zz : zz
# 2578 : jnnnnnnjnnnnnnnnnnkkn : jnnnnnnjnnnnnnnnnnkkn
# 2579 : un : un
# 2580 : bekas : bekas
# 2581 : mitsubishi : mitsubishi
# 2582 : kirimkan : kirim
# 2583 : ikkkkkknjnnnnjnknnknnr : ikkkkkknjnnnnjnknnknnr
# 2584 : okan : okan
# 2585 : pintu : pintu
# 2586 : gerbang : gerbang
# 2587 : akal : akal
# 2588 : komik : komik
# 2589 : mm : mm
# 2590 : ikkkkiinginkannyamik : ikkkkiinginkannyamik
# 2591 : one : one
# 2592 : novel : novel
# 2593 : film : film
# 2594 : dibilang : bilang
# 2595 : membantuterima : membantuterima
# 2596 : bangusss : bangusss
# 2597 : rumahtangga : rumahtangga
# 2598 : dicari : cari
# 2599 : tampilan : tampil
# 2600 : have : have
# 2601 : been : been
# 2602 : here : here
# 2603 : expektasi : expektasi
# 2604 : pokokx : pokokx
# 2605 : mantaaaaaap : mantaaaaaap
# 2606 : my : my
# 2607 : living : living
# 2608 : wifiharus : wifiharus
# 2609 : datasedangkan : datasedangkan
# 2610 : pengaturan : atur
# 2611 : dipahami : paham
# 2612 : menu : menu
# 2613 : coice : coice
# 2614 : ketegasan : tegas
# 2615 : nyasama : nyasama
# 2616 : tingkatin : tingkatin
# 2617 : donglama : donglama
# 2618 : mkan : mkan
# 2619 : haribelom : haribelom
# 2620 : jalan : jalan
# 2621 : tim : tim
# 2622 : keburu : keburu
# 2623 : terbalik : balik
# 2624 : checkout : checkout
# 2625 : grgr : grgr
# 2626 : cv : cv
# 2627 : digunain : digunain
# 2628 : yekan : yekan
# 2629 : siiiiiip : siiiiiip
# 2630 : terbilang : bilang
# 2631 : transfer : transfer
# 2632 : bri : bri
# 2633 : brimo : brimo
# 2634 : skrang : skrang
# 2635 : kocak : kocak
# 2636 : nicee : nicee
# 2637 : syarat : syarat
# 2638 : kebaya : kebaya
# 2639 : belm : belm
# 2640 : tarik : tarik
# 2641 : rancak : rancak
# 2642 : bana : bana
# 2643 : lingkungan : lingkung
# 2644 : orangorang : orangorang
# 2645 : ngeler : ngeler
# 2646 : memeberikan : memeberikan
# 2647 : retur : retur
# 2648 : promonyaa : promonyaa
# 2649 : apaandah : apaandah
# 2650 : pbcui : pbcui
# 2651 : anehh : anehh
# 2652 : alesannya : alesannya
# 2653 : pembatasan : batas
# 2654 : pdhlbayar : pdhlbayar
# 2655 : anehkalo : anehkalo
# 2656 : paylaternya : paylaternya
# 2657 : hrgai : hrgai
# 2658 : naiktrus : naiktrus
# 2659 : pergiman : gim
# 2660 : smula : smula
# 2661 : discond : discond
# 2662 : okk : okk
# 2663 : smogah : smogah
# 2664 : keluhan : keluh
# 2665 : tampah : tampah
# 2666 : kepasar : pasar
# 2667 : bunga : bunga
# 2668 : whatsapp : whatsapp
# 2669 : messenger : messenger
# 2670 : pusing : pusing
# 2671 : malam : malam
# 2672 : berisik : berisik
# 2673 : berhanti : berhanti
# 2674 : ding : ding
# 2675 : kaget : kaget
# 2676 : nyeri : nyeri
# 2677 : maknyos : maknyos
# 2678 : laaah : laaah
# 2679 : lazadadan : lazadadan
# 2680 : mengecewakansukses : mengecewakansukses
# 2681 : gaq : gaq
# 2682 : komentar : komentar
# 2683 : apapa : apapa
# 2684 : youtube : youtube
# 2685 : norak : norak
# 2686 : eee : eee
# 2687 : dpat : dpat
# 2688 : minya : mi
# 2689 : detergent : detergent
# 2690 : pad : pad
# 2691 : biyang : biyang
# 2692 : goodjob : goodjob
# 2693 : mantao : mantao
# 2694 : terusssss : terusssss
# 2695 : hilangin : hilangin
# 2696 : kerumah : rumah
# 2697 : batasan : batas
# 2698 : ancer : ancer
# 2699 : shareloc : shareloc
# 2700 : belanjagratis : belanjagratis
# 2701 : melimpah : limpah
# 2702 : buangbuang : buangbuang
# 2703 : membutuhkan : butuh
# 2704 : berminggu : minggu
# 2705 : perbaikan : baik
# 2706 : tahan : tahan
# 2707 : dimarahin : dimarahin
# 2708 : tema : tema
# 2709 : halim : halim
# 2710 : diperbarui : baru
# 2711 : marah : marah
# 2712 : nemen : nemen
# 2713 : kasihan : kasihan
# 2714 : miskin : miskin
# 2715 : rbot : rbot
# 2716 : manusia : manusia
# 2717 : ngobrol : ngobrol
# 2718 : enjoy : enjoy
# 2719 : pengbalian : balian
# 2720 : pilihannya : pilih
# 2721 : rebetmau : rebetmau
# 2722 : tfcod : tfcod
# 2723 : cucimata : cucimata
# 2724 : racun : racun
# 2725 : oketapi : oketapi
# 2726 : gan : gan
# 2727 : bahanya : bahanya
# 2728 : adm : adm
# 2729 : asikk : asikk
# 2730 : yoo : yoo
# 2731 : woi : woi
# 2732 : bosisi : bosisi
# 2733 : dibayarmalah : dibayarmalah
# 2734 : pulsanyawoi : pulsanyawoi
# 2735 : nenurun : nenurun
# 2736 : biarkan : biar
# 2737 : berlarut : larut
# 2738 : larut : larut
# 2739 : cuyyy : cuyyy
# 2740 : bro : bro
# 2741 : developer : developer
# 2742 : mentingin : mentingin
# 2743 : pikirlah : pikir
# 2744 : open : open
# 2745 : dampak : dampak
# 2746 : jeda : jeda
# 2747 : detik : detik
# 2748 : hang : hang
# 2749 : screen : screen
# 2750 : kebuka : buka
# 2751 : bayangkan : bayang
# 2752 : berkelas : kelas
# 2753 : a : a
# 2754 : ram : ram
# 2755 : gb : gb
# 2756 : startup : startup
# 2757 : ror : ror
# 2758 : cpt : cpt
# 2759 : mantulll : mantulll
# 2760 : bari : bari
# 2761 : mencoba : coba
# 2762 : ansuran : ansuran
# 2763 : hambatan : hambat
# 2764 : kode : kode
# 2765 : mang : mang
# 2766 : packing : packing
# 2767 : scan : scan
# 2768 : pelayan : layan
# 2769 : buang : buang
# 2770 : hilangjika : hilangjika
# 2771 : membenarkan : benar
# 2772 : ratingnya : ratingnya
# 2773 : masya : masya
# 2774 : mski : mski
# 2775 : kdg : kdg
# 2776 : segi : segi
# 2777 : kereta : kereta
# 2778 : mainan : main
# 2779 : truck : truck
# 2780 : sisni : sisni
# 2781 : kerren : kerren
# 2782 : th : th
# 2783 : peringatkan : ingat
# 2784 : ketat : ketat
# 2785 : pengawasan : awas
# 2786 : lemotabis : lemotabis
# 2787 : prbaharuissah : prbaharuissah
# 2788 : bt : bt
# 2789 : bukanya : buka
# 2790 : alhamdhulilah : alhamdhulilah
# 2791 : kesannya : kesan
# 2792 : selanjnya : selanjnya
# 2793 : hri : hri
# 2794 : hus : hus
# 2795 : ja : ja
# 2796 : jelassss : jelassss
# 2797 : did : did
# 2798 : gudjob : gudjob
# 2799 : xiaomi : xiaomi
# 2800 : siram : siram
# 2801 : padi : padi
# 2802 : sa : sa
# 2803 : ngat : ngat
# 2804 : trmkasih : trmkasih
# 2805 : mumer : mumer
# 2806 : dicoba : coba
# 2807 : ookk : ookk
# 2808 : semangat : semangat
# 2809 : coooookk : coooookk
# 2810 : jawabgk : jawabgk
# 2811 : lazpinjam : lazpinjam
# 2812 : ook : ook
# 2813 : klw : klw
# 2814 : lajadah : lajadah
# 2815 : pembayarab : pembayarab
# 2816 : zangat : zangat
# 2817 : mashabi : mashabi
# 2818 : igor : igor
# 2819 : area : area
# 2820 : angke : angke
# 2821 : jambora : jambora
# 2822 : jakbar : jakbar
# 2823 : adain : adain
# 2824 : komplainan : komplain
# 2825 : report : report
# 2826 : ngomong : ngomong
# 2827 : gapunya : gapunya
# 2828 : nyolot : nyolot
# 2829 : etikanya : etika
# 2830 : bangku : bangku
# 2831 : sekolah : sekolah
# 2832 : busuk : busuk
# 2833 : disiap : siap
# 2834 : diserahkan : serah
# 2835 : seenak : enak
# 2836 : jidat : jidat
# 2837 : acc : acc
# 2838 : dipick : dipick
# 2839 : petang : petang
# 2840 : diretur : retur
# 2841 : kau : kau
# 2842 : komisi : komisi
# 2843 : menghilangkan : hilang
# 2844 : dikantor : kantor
# 2845 : libur : libur
# 2846 : piket : piket
# 2847 : penerimaan : terima
# 2848 : upgrade : upgrade
# 2849 : berguna : guna
# 2850 : go : go
# 2851 : sangan : sangan
# 2852 : jutaan : juta
# 2853 : diselesaikan : selesai
# 2854 : buktinya : bukti
# 2855 : tliti : tliti
# 2856 : wes : wes
# 2857 : menipu : tipu
# 2858 : reaksi : reaksi
# 2859 : korbannya : korban
# 2860 : follow : follow
# 2861 : goodtp : goodtp
# 2862 : dak : dak
# 2863 : pos : pos
# 2864 : sekarah : karah
# 2865 : motong : motong
# 2866 : freong : freong
# 2867 : rbnyatolong : rbnyatolong
# 2868 : nyuk : nyuk
# 2869 : berkat : berkat
# 2870 : velnja : velnja
# 2871 : apapu : apapu
# 2872 : bajak : bajak
# 2873 : es : es
# 2874 : ae : ae
# 2875 : sesamaaas : sesamaaas
# 2876 : zx : zx
# 2877 : zar : zar
# 2878 : sial : sial
# 2879 : bodo : bodo
# 2880 : gahag : gahag
# 2881 : selaluuuu : selaluuuu
# 2882 : kemajuan : maju
# 2883 : teknologi : teknologi
# 2884 : diawali : awal
# 2885 : tes : tes
# 2886 : sueeee : sueeee
# 2887 : assalamualaikum : assalamualaikum
# 2888 : warahmatullahi : warahmatullahi
# 2889 : wb : wb
# 2890 : misaljnejtsi : misaljnejtsi
# 2891 : expressposdll : expressposdll
# 2892 : minum : minum
# 2893 : blangkejaren : blangkejaren
# 2894 : aceh : aceh
# 2895 : mahaaal : mahaaal
# 2896 : playlaterku : playlaterku
# 2897 : kunci : kunci
# 2898 : kekunci : kunci
# 2899 : audah : audah
# 2900 : status : status
# 2901 : siatem : siatem
# 2902 : sumpah : sumpah
# 2903 : akunnya : akun
# 2904 : google : google
# 2905 : jir : jir
# 2906 : ditempatbaru : ditempatbaru
# 2907 : dilempar : lempar
# 2908 : dianter : anter
# 2909 : dibayar : bayar
# 2910 : garagara : garagara
# 2911 : april : april
# 2912 : yantojd : yantojd
# 2913 : jakarta : jakarta
# 2914 : penanganannya : tangan
# 2915 : memperkerjakan : kerja
# 2916 : attitude : attitude
# 2917 : menyalahgunakan : menyalahgunakan
# 2918 : barng : barng
# 2919 : komen : komen
# 2920 : positif : positif
# 2921 : jaminan : jamin
# 2922 : flashsale : flashsale
# 2923 : terpaksa : paksa
# 2924 : ketoko : toko
# 2925 : rumaj : rumaj
# 2926 : terhubung : hubung
# 2927 : skali : skali
# 2928 : playananyh : playananyh
# 2929 : ngandelin : ngandelin
# 2930 : ug : ug
# 2931 : bales : bales
# 2932 : jngn : jngn
# 2933 : rsk : rsk
# 2934 : dtnggu : dtnggu
# 2935 : gacorrrr : gacorrrr
# 2936 : bgaus : bgaus
# 2937 : cok : cok
# 2938 : wp : wp
# 2939 : kagak : kagak
# 2940 : anjirr : anjirr
# 2941 : mak : mak
# 2942 : as : as
# 2943 : ongkirmurah : ongkirmurah
# 2944 : anying : anying
# 2945 : mengancam : ancam
# 2946 : membunuh : bunuh
# 2947 : keluarga : keluarga
# 2948 : bangsatttt : bangsatttt
# 2949 : enek : enek
# 2950 : lazaadaa : lazaadaa
# 2951 : plnggn : plnggn
# 2952 : baruhrgnya : baruhrgnya
# 2953 : lagisupaya : lagisupaya
# 2954 : ketagihan : tagih
# 2955 : war : war
# 2956 : memperbaiki : baik
# 2957 : bedalagi : bedalagi
# 2958 : kalaucaku : kalaucaku
# 2959 : tulisannya : tulis
# 2960 : benci : benci
# 2961 : gabenee : gabenee
# 2962 : anjir : anjir
# 2963 : screnrecord : screnrecord
# 2964 : ipong : ipong
# 2965 : fb : fb
# 2966 : refres : refres
# 2967 : android : android
# 2968 : mengantarnya : antar
# 2969 : kesedot : sedot
# 2970 : sbebas : sbebas
# 2971 : hebatkan : hebat
# 2972 : dilayani : layan
# 2973 : storenya : storenya
# 2974 : dibatalin : dibatalin
# 2975 : mutar : mutar
# 2976 : tabarokallah : tabarokallah
# 2977 : nnti : nnti
# 2978 : lagiterimakasih : lagiterimakasih
# 2979 : makinn : makinn
# 2980 : mmk : mmk
# 2981 : adamlk : adamlk
# 2982 : yeah : yeah
# 2983 : hey : hey
# 2984 : am : am
# 2985 : sorry : sorry
# 2986 : dont : dont
# 2987 : look : look
# 2988 : im : im
# 2989 : gon : gon
# 2990 : with : with
# 2991 : does : does
# 2992 : philip : philip
# 2993 : bbi : bbi
# 2994 : yups : yups
# 2995 : sopanan : sopan
# 2996 : mengantar : antar
# 2997 : ajari : ajar
# 2998 : mencoreng : coreng
# 2999 : brand : brand
# 3000 : srg : srg
# 3001 : gtatis : gtatis
# 3002 : istimewa : istimewa
# 3003 : perusahaan : usaha
# 3004 : gunain : gunain
# 3005 : mantaaabpemakaian : mantaaabpemakaian
# 3006 : semogga : semogga
# 3007 : hush : hush
# 3008 : puppies : puppies
# 3009 : mall : mall
# 3010 : gilaemg : gilaemg
# 3011 : jobmsntulll : jobmsntulll
# 3012 : bnget : bnget
# 3013 : cream : cream
# 3014 : abng : abng
# 3015 : serigala : serigala
# 3016 : berani : berani
# 3017 : bagussssss : bagussssss
# 3018 : iklane : iklane
# 3019 : nyepeti : nyepeti
# 3020 : tenan : tenan
# 3021 : belanga : belanga
# 3022 : luaarr : luaarr
# 3023 : biasaa : biasaa
# 3024 : bast : bast
# 3025 : akurat : akurat
# 3026 : daptar : daptar
# 3027 : bljar : bljar
# 3028 : sportipitasnya : sportipitasnya
# 3029 : lapak : lapak
# 3030 : bergabung : gabung
# 3031 : hihi : hihi
# 3032 : tunai : tunai
# 3033 : rekeningpadahal : rekeningpadahal
# 3034 : terkirimwaduh : terkirimwaduh
# 3035 : kacau : kacau
# 3036 : tiada : tiada
# 3037 : duanya : dua
# 3038 : ceoet : ceoet
# 3039 : jelasin : jelasin
# 3040 : masak : masak
# 3041 : biyaya : biyaya
# 3042 : hitung : hitung
# 3043 : utara : utara
# 3044 : surabaya : surabaya
# 3045 : timur : timur
# 3046 : medan : medan
# 3047 : kab : kab
# 3048 : bogor : bogor
# 3049 : bekasi : bekas
# 3050 : tangerang : tangerang
# 3051 : krim : krim
# 3052 : bangka : bangka
# 3053 : okirnya : okirnya
# 3054 : okir : okir
# 3055 : minn : minn
# 3056 : suv : suv
# 3057 : berkatajos : berkatajos
# 3058 : truss : truss
# 3059 : kacamata : kacamata
# 3060 : pulpen : pulpen
# 3061 : mmbantu : mmbantu
# 3062 : sbuk : sbuk
# 3063 : mnyenangkan : mnyenangkan
# 3064 : stiap : stiap
# 3065 : psanan : psanan
# 3066 : prnah : prnah
# 3067 : ggal : ggal
# 3068 : banyaknya : banyak
# 3069 : gedegedean : gedegedean
# 3070 : lainlain : lainlain
# 3071 : performa : performa
# 3072 : ly : ly
# 3073 : gimn : gimn
# 3074 : ketahan : tahan
# 3075 : menghambat : hambat
# 3076 : tan : tan
# 3077 : bot : bot
# 3078 : gmana : gmana
# 3079 : bgtharga : bgtharga
# 3080 : murahvoucher : murahvoucher
# 3081 : sblah : sblah
# 3082 : padamu : pada
# 3083 : sediakan : sedia
# 3084 : dongkaya : dongkaya
# 3085 : ngirimnya : ngirimnya
# 3086 : telitipesanan : telitipesanan
# 3087 : segituudah : segituudah
# 3088 : pembelidan : bidan
# 3089 : penilaian : nilai
# 3090 : gratus : gratus
# 3091 : ksih : ksih
# 3092 : tlong : tlong
# 3093 : sring : sring
# 3094 : mkin : mkin
# 3095 : nain : nain
# 3096 : ditlp : ditlp
# 3097 : pinjman : pinjman
# 3098 : ditolak : tolak
# 3099 : melulu : melulu
# 3100 : ehhh : ehhh
# 3101 : wajib : wajib
# 3102 : dipesen : sen
# 3103 : kepencet : pencet
# 3104 : bngethampir : bngethampir
# 3105 : logintolong : logintolong
# 3106 : expediturnya : expediturnya
# 3107 : pay : pay
# 3108 : itung : itung
# 3109 : sebulan : bulan
# 3110 : big : big
# 3111 : tergiur : giur
# 3112 : sponsor : sponsor
# 3113 : instagram : instagram
# 3114 : tokoh : tokoh
# 3115 : beneran : beneran
# 3116 : barangnyah : barangnyah
# 3117 : vendor : vendor
# 3118 : amanahmasa : amanahmasa
# 3119 : smp : smp
# 3120 : xudah : xudah
# 3121 : pelanggandistatus : pelanggandistatus
# 3122 : mencukupi : cukup
# 3123 : sellerkecewa : sellerkecewa
# 3124 : lazadaudah : lazadaudah
# 3125 : acara : acara
# 3126 : dirolling : dirolling
# 3127 : kuriraku : kuriraku
# 3128 : pelangganmu : langgan
# 3129 : dikecewakan : kecewa
# 3130 : mantaapp : mantaapp
# 3131 : tehbestbisa : tehbestbisa
# 3132 : keluarbisa : keluarbisa
# 3133 : bagusoke : bagusoke
# 3134 : l : l
# 3135 : nganter : nganter
# 3136 : perketat : ketat
# 3137 : halo : halo
# 3138 : keluhkan : keluh
# 3139 : perihal : perihal
# 3140 : memotong : potong
# 3141 : terpotong : potong
# 3142 : melanjutkan : lanjut
# 3143 : bantuannya : bantu
# 3144 : utang : utang
# 3145 : senangkan : senang
# 3146 : consumen : consumen
# 3147 : tol : tol
# 3148 : pasokan : pasok
# 3149 : abg : abg
# 3150 : smpsma : smpsma
# 3151 : nomer : nomer
# 3152 : banyk : banyk
# 3153 : goooddddd : goooddddd
# 3154 : repotharus : repotharus
# 3155 : antarkan : antar
# 3156 : nyumm : nyumm
# 3157 : epep : epep
# 3158 : huhu : huhu
# 3159 : twt : twt
# 3160 : tmbah : tmbah
# 3161 : sskali : sskali
# 3162 : freeongkir : freeongkir
# 3163 : minbel : minbel
# 3164 : rebutan : rebut
# 3165 : ijo : ijo
# 3166 : kurira : kurira
# 3167 : perbaikin : perbaikin
# 3168 : bagusbarng : bagusbarng
# 3169 : dianterin : dianterin
# 3170 : diskong : diskong
# 3171 : sajapokoknya : sajapokoknya
# 3172 : kenapaa : kenapaa
# 3173 : ovo : ovo
# 3174 : paham : paham
# 3175 : cuan : cuan
# 3176 : wae : wae
# 3177 : servicenya : servicenya
# 3178 : murahbrang : murahbrang
# 3179 : gededan : gededan
# 3180 : ongkirrpuassss : ongkirrpuassss
# 3181 : terhapus : hapus
# 3182 : updatemohon : updatemohon
# 3183 : dimanapun : mana
# 3184 : kenpa : kenpa
# 3185 : setial : setial
# 3186 : huj : huj
# 3187 : bajunya : baju
# 3188 : tempatku : tempat
# 3189 : hasil : hasil
# 3190 : pegiriman : pegiriman
# 3191 : jobs : jobs
# 3192 : emasnya : emas
# 3193 : titiktitik : titiktitik
# 3194 : koma : koma
# 3195 : titik : titik
# 3196 : kuncinya : kunci
# 3197 : aktivitas : aktivitas
# 3198 : beraktivitas : aktivitas
# 3199 : fungsi : fungsi
# 3200 : sosmed : sosmed
# 3201 : sosial : sosial
# 3202 : media : media
# 3203 : mensos : mensos
# 3204 : bag : bag
# 3205 : irit : irit
# 3206 : mengurangi : kurang
# 3207 : vocernya : vocernya
# 3208 : dadakan : dada
# 3209 : maksi : maksi
# 3210 : gunkan : gun
# 3211 : bnyakin : bnyakin
# 3212 : pengin : pengin
# 3213 : batasi : batas
# 3214 : lzda : lzda
# 3215 : diautkan : diautkan
# 3216 : berkelasoke : berkelasoke
# 3217 : maksih : maksih
# 3218 : penjelasan : jelas
# 3219 : gut : gut
# 3220 : for : for
# 3221 : lanzada : lanzada
# 3222 : later : later
# 3223 : swon : swon
# 3224 : nuhun : nuhun
# 3225 : brblnja : brblnja
# 3226 : upx : upx
# 3227 : bokeb : bokeb
# 3228 : rus : rus
# 3229 : menanggapi : tanggap
# 3230 : pemakai : pakai
# 3231 : halnya : hal
# 3232 : berkedok : kedok
# 3233 : berimbas : imbas
# 3234 : rahayu : rahayu
# 3235 : sagung : sagung
# 3236 : dumadi : dumadi
# 3237 : dlusukses : dlusukses
# 3238 : majutrus : majutrus
# 3239 : vocerrr : vocerrr
# 3240 : fashion : fashion
# 3241 : kecewakan : kecewa
# 3242 : basmi : basmi
# 3243 : deletkurir : deletkurir
# 3244 : darah : darah
# 3245 : tinggilex : tinggilex
# 3246 : idcari : idcari
# 3247 : karyawan : karyawan
# 3248 : aplkasi : aplkasi
# 3249 : bego : bego
# 3250 : ngambil : ngambil
# 3251 : menjemen : menjemen
# 3252 : brok : brok
# 3253 : otak : otak
# 3254 : okay : okay
# 3255 : sperti : sperti
# 3256 : motipasi : motipasi
# 3257 : bngus : bngus
# 3258 : sekalipuaasss : sekalipuaasss
# 3259 : berbicaranya : bicara
# 3260 : nadatidak : nadatidak
# 3261 : gituhhh : gituhhh
# 3262 : jozzz : jozzz
# 3263 : berantas : berantas
# 3264 : kw : kw
# 3265 : kasian : kasi
# 3266 : masi : mas
# 3267 : kwin : kwin
# 3268 : lokalnya : lokal
# 3269 : alhamdulilah : alhamdulilah
# 3270 : cakep : cakep
# 3271 : smga : smga
# 3272 : sellu : sellu
# 3273 : slama : slama
# 3274 : belannja : belannja
# 3275 : waktutrimakasih : waktutrimakasih
# 3276 : sayasemoga : sayasemoga
# 3277 : bentar : bentar
# 3278 : tahta : tahta
# 3279 : ttidak : ttidak
# 3280 : mematuhi : patuh
# 3281 : kekerasan : keras
# 3282 : lainyya : lainyya
# 3283 : kejadian : jadi
# 3284 : evaluasi : evaluasi
# 3285 : motif : motif
# 3286 : cus : cus
# 3287 : lgsug : lgsug
# 3288 : bget : bget
# 3289 : profesional : profesional
# 3290 : gas : gas
# 3291 : kendor : kendor
# 3292 : trim : trim
# 3293 : perdana : perdana
# 3294 : sinikecewa : sinikecewa
# 3295 : billiard : billiard
# 3296 : pengadduan : pengadduan
# 3297 : nunggin : nunggin
# 3298 : mksh : mksh
# 3299 : muhamad : muhamad
# 3300 : riski : riski
# 3301 : terimakasi : terimakasi
# 3302 : rowrrrrrr : rowrrrrrr
# 3303 : disc : disc
# 3304 : gedex : gedex
# 3305 : loveh : loveh
# 3306 : apaternyata : apaternyata
# 3307 : bedadan : bedadan
# 3308 : nais : nais
# 3309 : mudahhrga : mudahhrga
# 3310 : ngk : ngk
# 3311 : ketik : ketik
# 3312 : denganyg : denganyg
# 3313 : apaaan : apaaan
# 3314 : log : log
# 3315 : dicarikan : cari
# 3316 : bangua : bangua
# 3317 : kebukabuka : kebukabuka
# 3318 : deskripsitolong : deskripsitolong
# 3319 : audit : audit
# 3320 : pantau : pantau
# 3321 : hai : hai
# 3322 : kelazada : kelazada
# 3323 : diverifikasi : verifikasi
# 3324 : maaantaaapp : maaantaaapp
# 3325 : puaspengirimannya : puaspengirimannya
# 3326 : mantaps : mantaps
# 3327 : rekomendit : rekomendit
# 3328 : sedih : sedih
# 3329 : jiwa : jiwa
# 3330 : mlu : mlu
# 3331 : semingguan : minggu
# 3332 : saldonya : saldo
# 3333 : ska : ska
# 3334 : sebenar : benar
# 3335 : persulit : sulit
# 3336 : vanid : vanid
# 3337 : pngiriman : pngiriman
# 3338 : banyakin : banyakin
# 3339 : prioritas : prioritas
# 3340 : bgtu : bgtu
# 3341 : diskonkurirnya : diskonkurirnya
# 3342 : tetangga : tetangga
# 3343 : mls : mls
# 3344 : nganterin : nganterin
# 3345 : saran : saran
# 3346 : khusus : khusus
# 3347 : masingmasing : masingmasing
# 3348 : dipermudah : mudah
# 3349 : brgnya : brgnya
# 3350 : didaerah : daerah
# 3351 : disaring : saring
# 3352 : ditemukan : temu
# 3353 : disekitar : sekitar
# 3354 : bingitsssss : bingitsssss
# 3355 : o : o
# 3356 : seg : seg
# 3357 : jamin : jamin
# 3358 : barangnyaaa : barangnyaaa
# 3359 : belja : belja
# 3360 : dilajada : dilajada
# 3361 : panenberasnya : panenberasnya
# 3362 : jakartaor : jakartaor
# 3363 : jabotabekternyata : jabotabekternyata
# 3364 : bagusnyaada : bagusnyaada
# 3365 : kompensasinya : kompensasi
# 3366 : gopatner : gopatner
# 3367 : ngisih : ngisih
# 3368 : pembeliantapi : pembeliantapi
# 3369 : pembayarannya : bayar
# 3370 : bca : bca
# 3371 : slesai : slesai
# 3372 : dipelajari : ajar
# 3373 : plis : plis
# 3374 : bonusnya : bonus
# 3375 : kaka : kaka
# 3376 : wawa : wawa
# 3377 : click : click
# 3378 : diskondiskonnya : diskondiskonnya
# 3379 : seringsering : seringsering
# 3380 : mantaaab : mantaaab
# 3381 : mungkinqqqqqqqqqqqq : mungkinqqqqqqqqqqqq
# 3382 : badabest : badabest
# 3383 : pokonamah : pokonamah
# 3384 : beragam : agam
# 3385 : adadan : adad
# 3386 : temakasih : temakasih
# 3387 : lazadagoooooood : lazadagoooooood
# 3388 : hh : hh
# 3389 : bagusi : bagus
# 3390 : lazadatp : lazadatp
# 3391 : dri : dri
# 3392 : nyharga : nyharga
# 3393 : menemukan : temu
# 3394 : costumer : costumer
# 3395 : vaoucher : vaoucher
# 3396 : diturunin : diturunin
# 3397 : dgan : dgan
# 3398 : memangkas : mangkas
# 3399 : mantabsukses : mantabsukses
# 3400 : berhubung : hubung
# 3401 : pesannya : pesan
# 3402 : expired : expired
# 3403 : terjauh : jauh
# 3404 : masukjadi : masukjadi
# 3405 : masukan : masuk
# 3406 : nmr : nmr
# 3407 : telplangsung : telplangsung
# 3408 : teryata : teryata
# 3409 : bkan : bkan
# 3410 : lamaakun : lamaakun
# 3411 : lgbaru : lgbaru
# 3412 : pict : pict
# 3413 : okeee : okeee
# 3414 : product : product
# 3415 : dimasukan : masuk
# 3416 : keranjang : keranjang
# 3417 : ikutan : ikut
# 3418 : ngikut : ngikut
# 3419 : promosi : promosi
# 3420 : diproduksi : produksi
# 3421 : mis : mis
# 3422 : jmlh : jmlh
# 3423 : bijimane : bijimane
# 3424 : ceritanye : ceritanye
# 3425 : alias : alias
# 3426 : fair : fair
# 3427 : ttg : ttg
# 3428 : lazadatinggal : lazadatinggal
# 3429 : kemauan : mau
# 3430 : pesananbisa : pesananbisa
# 3431 : ribetlazada : ribetlazada
# 3432 : verivikasi : verivikasi
# 3433 : luntur : luntur
# 3434 : tinanium : tinanium
# 3435 : beast : beast
# 3436 : statusnya : status
# 3437 : verry : verry
# 3438 : mnta : mnta
# 3439 : dluan : dluan
# 3440 : jhosss : jhosss
# 3441 : sj : sj
# 3442 : sbgai : sbgai
# 3443 : seolaholah : seolaholah
# 3444 : dipaksakan : paksa
# 3445 : expedisijasa : expedisijasa
# 3446 : pdhal : pdhal
# 3447 : trmasuk : trmasuk
# 3448 : ndk : ndk
# 3449 : sedikitaplg : sedikitaplg
# 3450 : mrk : mrk
# 3451 : pnrima : pnrima
# 3452 : salahtdk : salahtdk
# 3453 : perangkat : perangkat
# 3454 : pelayanannyatrm : pelayanannyatrm
# 3455 : nie : nie
# 3456 : ruet : ruet
# 3457 : chah : chah
# 3458 : unilever : unilever
# 3459 : smpai : smpai
# 3460 : kpan : kpan
# 3461 : tglnya : tglnya
# 3462 : realpict : realpict
# 3463 : happy : happy
# 3464 : shoping : shoping
# 3465 : rel : rel
# 3466 : nglak : nglak
# 3467 : terkena : kena
# 3468 : pembatasanpadahal : pembatasanpadahal
# 3469 : sensitif : sensitif
# 3470 : rewards : rewards
# 3471 : kebeli : kebel
# 3472 : makasii : makasii
# 3473 : kesel : kesel
# 3474 : pliss : pliss
# 3475 : semudah : mudah
# 3476 : yaw : yaw
# 3477 : rugii : rugi
# 3478 : sgat : sgat
# 3479 : senggol : senggol
# 3480 : mamus : mamus
# 3481 : orderan : order
# 3482 : buagett : buagett
# 3483 : merasakan : rasa
# 3484 : hematnya : hemat
# 3485 : ol : ol
# 3486 : seba : seba
# 3487 : sebi : sebi
# 3488 : nerimanya : nerimanya
# 3489 : rumahlah : rumah
# 3490 : jalanlah : jalan
# 3491 : pembayaaran : pembayaaran
# 3492 : lebihkan : lebih
# 3493 : kq : kq
# 3494 : perubahan : ubah
# 3495 : kerennn : kerennn
# 3496 : lahsemua : lahsemua
# 3497 : lzada : lzada
# 3498 : abil : abil
# 3499 : qku : qku
# 3500 : ahahaha : ahahaha
# 3501 : memuskan : mus
# 3502 : hoby : hoby
# 3503 : hematbanyak : hematbanyak
# 3504 : sukaaa : sukaaa
# 3505 : meria : ria
# 3506 : jossssss : jossssss
# 3507 : trauma : trauma
# 3508 : disni : disni
# 3509 : kbnykan : kbnykan
# 3510 : konfir : konfir
# 3511 : gbisa : gbisa
# 3512 : jellek : jellek
# 3513 : playstore : playstore
# 3514 : jelleekkk : jelleekkk
# 3515 : burriiqqq : burriiqqq
# 3516 : developernya : developer
# 3517 : bahasa : bahasa
# 3518 : eek : eek
# 3519 : kah : kah
# 3520 : burrik : burrik
# 3521 : amet : amet
# 3522 : bahasamu : bahasa
# 3523 : ngomen : ngomen
# 3524 : fisik : fisik
# 3525 : benefit : benefit
# 3526 : seruh : seruh
# 3527 : andai : andai
# 3528 : lazadaaa : lazadaaa
# 3529 : estee : estee
# 3530 : pelayananx : pelayananx
# 3531 : tidik : tidik
# 3532 : plale : plale
# 3533 : ceritananti : ceritananti
# 3534 : bangga : bangga
# 3535 : promosikan : promosi
# 3536 : mati : mati
# 3537 : review : review
# 3538 : anehnya : aneh
# 3539 : mensortir : sortir
# 3540 : memblok : blok
# 3541 : pertahan : tahan
# 3542 : ssbelah : ssbelah
# 3543 : bagusan : bagus
# 3544 : diupdate : diupdate
# 3545 : murahsering : murahsering
# 3546 : ongkirpengiriman : ongkirpengiriman
# 3547 : srkali : srkali
# 3548 : do : do
# 3549 : sanga : sanga
# 3550 : sampek : sampek
# 3551 : gerandong : gerandong
# 3552 : sukai : suka
# 3553 : lazadaapalagi : lazadaapalagi
# 3554 : lagih : lagih
# 3555 : lazadaproduk : lazadaproduk
# 3556 : memuaskansaya : memuaskansaya
# 3557 : pgn : pgn
# 3558 : murmer : murmer
# 3559 : dehh : dehh
# 3560 : gercep : gercep
# 3561 : tala : tala
# 3562 : tele : tele
# 3563 : staff : staff
# 3564 : penjualnya : jual
# 3565 : cair : cair
# 3566 : unk : unk
# 3567 : ols : ols
# 3568 : ketinggalan : tinggal
# 3569 : cepatlah : cepat
# 3570 : fiber : fiber
# 3571 : optik : optik
# 3572 : lu : lu
# 3573 : dimna : dimna
# 3574 : mna : mna
# 3575 : gwa : gwa
# 3576 : jjur : jjur
# 3577 : nd : nd
# 3578 : amnh : amnh
# 3579 : emu : emu
# 3580 : emul : emul
# 3581 : mkasih : mkasih
# 3582 : baraakaallahu : baraakaallahu
# 3583 : fiikum : fiikum
# 3584 : syukron : syukron
# 3585 : jazzaakumulloh : jazzaakumulloh
# 3586 : khoirant : khoirant
# 3587 : katsiron : katsiron
# 3588 : istiqomah : istiqomah
# 3589 : kewalitas : kewalitas
# 3590 : banding : banding
# 3591 : kru : kru
# 3592 : lainterima : lainterima
# 3593 : manatap : manatap
# 3594 : bosen : bosen
# 3595 : aupdate : aupdate
# 3596 : mf : mf
# 3597 : ntah : ntah
# 3598 : tampilkan : tampil
# 3599 : tolonglah : tolong
# 3600 : jahat : jahat
# 3601 : sieh : sieh
# 3602 : joooooooossssss : joooooooossssss
# 3603 : kebijaksanaannyapenjual : kebijaksanaannyapenjual
# 3604 : fjc : fjc
# 3605 : marts : marts
# 3606 : samudra : samudra
# 3607 : sembako : sembako
# 3608 : klou : klou
# 3609 : ituu : ituu
# 3610 : jualankami : jualankami
# 3611 : dikecewakanga : dikecewakanga
# 3612 : otomatisnanti : otomatisnanti
# 3613 : ubah : ubah
# 3614 : brjalan : brjalan
# 3615 : selayaknya : layak
# 3616 : alhasil : alhasil
# 3617 : tukang : tukang
# 3618 : byr : byr
# 3619 : lngsg : lngsg
# 3620 : cancl : cancl
# 3621 : maklumin : maklumin
# 3622 : lngsung : lngsung
# 3623 : ngutang : ngutang
# 3624 : tutupajh : tutupajh
# 3625 : semuga : semuga
# 3626 : bagusblanja : bagusblanja
# 3627 : praktismakasih : praktismakasih
# 3628 : bismillah : bismillah
# 3629 : mantappppopppp : mantappppopppp
# 3630 : ampli : ampli
# 3631 : mini : mini
# 3632 : belutud : belutud
# 3633 : talo : talo
# 3634 : kabupaten : kabupaten
# 3635 : seluma : seluma
# 3636 : bengkulu : bengkulu
# 3637 : bay : bay
# 3638 : jundra : jundra
# 3639 : jayya : jayya
# 3640 : damn : damn
# 3641 : okeeee : okeeee
# 3642 : dtg : dtg
# 3643 : baikbagus : baikbagus
# 3644 : lamabarang : lamabarang
# 3645 : mutermuter : mutermuter
# 3646 : transit : transit
# 3647 : membaikuntuk : membaikuntuk
# 3648 : lemott : lemott
# 3649 : puassss : puassss
# 3650 : pollltetap : pollltetap
# 3651 : kualitasy : kualitasy
# 3652 : sinii : sini
# 3653 : maaannn : maaannn
# 3654 : tttaaa : tttaaa
# 3655 : pppp : pppp
# 3656 : ll : ll
# 3657 : yaaklu : yaaklu
# 3658 : masyaallah : masyaallah
# 3659 : disaat : saat
# 3660 : abalbarang : abalbarang
# 3661 : pajangudah : pajangudah
# 3662 : lazadamending : lazadamending
# 3663 : ajah : ajah
# 3664 : sukaaaaa : sukaaaaa
# 3665 : gajekas : gajekas
# 3666 : untul : untul
# 3667 : lazpay : lazpay
# 3668 : lazbonya : lazbonya
# 3669 : bukak : bukak
# 3670 : bgttt : bgttt
# 3671 : lazadaaselain : lazadaaselain
# 3672 : bgttttapi : bgttttapi
# 3673 : murcemakin : murcemakin
# 3674 : cintahhh : cintahhh
# 3675 : mahhh : mahhh
# 3676 : hebatt : hebatt
# 3677 : vocernyaa : vocernyaa
# 3678 : mksih : mksih
# 3679 : snbgat : snbgat
# 3680 : jnj : jnj
# 3681 : zeen : zeen
# 3682 : amanahh : amanahh
# 3683 : beb : beb
# 3684 : debes : debes
# 3685 : mnurutku : mnurutku
# 3686 : lazadabeda : lazadabeda
# 3687 : pembayaranya : pembayaranya
# 3688 : cidga : cidga
# 3689 : tempathrus : tempathrus
# 3690 : lazadaskrg : lazadaskrg
# 3691 : bagussbgt : bagussbgt
# 3692 : pokoknyasukses : pokoknyasukses
# 3693 : yandex : yandex
# 3694 : kus : kus
# 3695 : bugil : bugil
# 3696 : terimkasih : terimkasih
# 3697 : sarang : sarang
# 3698 : tawon : tawon
# 3699 : risfek : risfek
# 3700 : kapuas : kapuas
# 3701 : hulu : hulu
# 3702 : kalimantan : kalimantan
# 3703 : bandingkan : banding
# 3704 : mintaaaaa : mintaaaaa
# 3705 : h : h
# 3706 : itungan : itungan
# 3707 : menit : menit
# 3708 : food : food
# 3709 : cesback : cesback
# 3710 : install : install
# 3711 : bagettt : bagettt
# 3712 : gantu : gantu
# 3713 : berhebti : berhebti
# 3714 : cepatharga : cepatharga
# 3715 : bagussssssssssss : bagussssssssssss
# 3716 : gda : gda
# 3717 : samsek : samsek
# 3718 : barumalah : barumalah
# 3719 : dpake : dpake
# 3720 : siiiplah : siiiplah
# 3721 : sebenernya : sebenernya
# 3722 : lazadacuma : lazadacuma
# 3723 : kurirnyaharusnya : kurirnyaharusnya
# 3724 : atw : atw
# 3725 : keterangannya : terang
# 3726 : ditegor : ditegor
# 3727 : galak : galak
# 3728 : maantap : maantap
# 3729 : semapat : semapat
# 3730 : bajuzsering : bajuzsering
# 3731 : force : force
# 3732 : close : close
# 3733 : bsgus : bsgus
# 3734 : ngerasa : ngerasa
# 3735 : topper : topper
# 3736 : hiasan : hias
# 3737 : kue : kue
# 3738 : balon : balon
# 3739 : amanahbarang : amanahbarang
# 3740 : iklankecewa : iklankecewa
# 3741 : bjr : bjr
# 3742 : tsel : tsel
# 3743 : lemotnya : lot
# 3744 : loading : loading
# 3745 : cache : cache
# 3746 : pic : pic
# 3747 : lamapayah : lamapayah
# 3748 : ordernya : order
# 3749 : nyampainya : nyampainya
# 3750 : promonyaaa : promonyaaa
# 3751 : terosss : terosss
# 3752 : pokoknah : pokoknah
# 3753 : ongkiramanah : ongkiramanah
# 3754 : batalkandengan : batalkandengan
# 3755 : habiskalo : habiskalo
# 3756 : pajanggedeg : pajanggedeg
# 3757 : mantaaabs : mantaaabs
# 3758 : terimah : terimah
# 3759 : ngerasain : ngerasain
# 3760 : pancen : pancen
# 3761 : juoossss : juoossss
# 3762 : dimanamana : dimanamana
# 3763 : kpop : kpop
# 3764 : penagihanya : penagihanya
# 3765 : mengerikan : keri
# 3766 : dendanya : denda
# 3767 : daripda : daripda
# 3768 : otw : otw
# 3769 : easy : easy
# 3770 : cheap : cheap
# 3771 : safe : safe
# 3772 : kelar : kelar
# 3773 : memuaskansdh : memuaskansdh
# 3774 : lazadaternyata : lazadaternyata
# 3775 : harganyatp : harganyatp
# 3776 : bgssmg : bgssmg
# 3777 : number : number
# 3778 : trm : trm
# 3779 : lcd : lcd
# 3780 : perfoma : perfoma
# 3781 : kecuali : kecuali
# 3782 : diple : diple
# 3783 : dipilih : pilih
# 3784 : bagong : bagong
# 3785 : gelo : gelo
# 3786 : blesak : blesak
# 3787 : membatalkannya : batal
# 3788 : mengembalikan : kembali
# 3789 : apresiasi : apresiasi
# 3790 : sahabat : sahabat
# 3791 : mesih : mesih
# 3792 : ngemis : ngemis
# 3793 : sumatra : sumatra
# 3794 : amal : amal
# 3795 : owner : owner
# 3796 : surga : surga
# 3797 : berasa : asa
# 3798 : ditraktir : traktir
# 3799 : lexid : lexid
# 3800 : serahin : serahin
# 3801 : kdang : kdang
# 3802 : smpek : smpek
# 3803 : mantappppppp : mantappppppp
# 3804 : ditindaklanjutiharus : ditindaklanjutiharus
# 3805 : diblacklist : diblacklist
# 3806 : jempol : jempol
# 3807 : condong : condong
# 3808 : iphone : iphone
# 3809 : refrrsh : refrrsh
# 3810 : refresh : refresh
# 3811 : yak : yak
# 3812 : berduit : duit
# 3813 : stigma : stigma
# 3814 : ipon : ipon
# 3815 : berharap : harap
# 3816 : keteusan : keteusan
# 3817 : satunya : satu
# 3818 : ngincer : ngincer
# 3819 : pencari : cari
# 3820 : abistu : abistu
# 3821 : opini : opini
# 3822 : whats : whats
# 3823 : really : really
# 3824 : ngah : ngah
# 3825 : nyesal : nyesal
# 3826 : terlemot : lot
# 3827 : qr : qr
# 3828 : penerimaannya : terima
# 3829 : dibeli : beli
# 3830 : udin : udin
# 3831 : asep : asep
# 3832 : saepdln : saepdln
# 3833 : menguntungkan : untung
# 3834 : telaten : telaten
# 3835 : keberatan : berat
# 3836 : pulau : pulau
# 3837 : jawa : jawa
# 3838 : bandar : bandar
# 3839 : lampung : lampung
# 3840 : dilampung : lampung
# 3841 : gatauuu : gatauuu
# 3842 : duluu : duluu
# 3843 : muraahh : muraahh
# 3844 : sedunia : dunia
# 3845 : tanggung : tanggung
# 3846 : kerugian : rugi
# 3847 : userhati : userhati
# 3848 : hatisistemnya : hatisistemnya
# 3849 : jelascoba : jelascoba
# 3850 : menang : menang
# 3851 : dihaati : dihaati
# 3852 : adil : adil
# 3853 : mayan : mayan
# 3854 : flas : flas
# 3855 : sale : sale
# 3856 : tulisanny : tulisanny
# 3857 : memus : mus
# 3858 : mantapplazada : mantapplazada
# 3859 : murahkan : murah
# 3860 : baiiik : baiiik
# 3861 : kerenpridukta : kerenpridukta
# 3862 : matam : matam
# 3863 : bagyus : bagyus
# 3864 : yes : yes
# 3865 : krana : krana
# 3866 : mura : mura
# 3867 : blum : blum
# 3868 : maasyaa : maasyaa
# 3869 : allaaah : allaaah
# 3870 : utamakan : utama
# 3871 : heeh : heeh
# 3872 : idolaku : idola
# 3873 : lazzada : lazzada
# 3874 : mantaplah : mantap
# 3875 : maksimal : maksimal
# 3876 : kereennn : kereennn
# 3877 : seles : les
# 3878 : cepatdan : cepatdan
# 3879 : kreeeen : kreeeen
# 3880 : cintaaaa : cintaaaa
# 3881 : nautin : nautin
# 3882 : puasss : puasss
# 3883 : bagagus : bagagus
# 3884 : kerjasamanya : kerjasamanya
# 3885 : kayanya : kaya
# 3886 : cm : cm
# 3887 : promooo : promooo
# 3888 : mantaplazada : mantaplazada
# 3889 : exis : exis
# 3890 : expres : expres
# 3891 : lumutan : lumut
# 3892 : semngat : semngat
# 3893 : jya : jya
# 3894 : apalah : apa
# 3895 : km : km
# 3896 : wanita : wanita
# 3897 : cadar : cadar
# 3898 : kurap : kurap
# 3899 : panunya : panunya
# 3900 : ootimal : ootimal
# 3901 : menjaga : jaga
# 3902 : okklo : okklo
# 3903 : ditelitisemoga : ditelitisemoga
# 3904 : memilah : mem
# 3905 : pelapak : lapak
# 3906 : amanahbagi : amanahbagi
# 3907 : ulah : ulah
# 3908 : coret : coret
# 3909 : duluh : duluh
# 3910 : baruh : baruh
# 3911 : keamanannya : aman
# 3912 : sekalii : sekali
# 3913 : edit : edit
# 3914 : yaaa : yaaa
# 3915 : keterangangannya : keterangangannya
# 3916 : solusinya : solusi
# 3917 : nurul : nurul
# 3918 : pelagansetia : pelagansetia
# 3919 : zonk : zonk
# 3920 : menemani : tani
# 3921 : rapi : rapi
# 3922 : jaj : jaj
# 3923 : najis : najis
# 3924 : koplok : koplok
# 3925 : amanahhh : amanahhh
# 3926 : timbangan : timbang
# 3927 : ancur : ancur
# 3928 : terserah : serah
# 3929 : matiin : matiin
# 3930 : ulas : ulas
# 3931 : apasih : apasih
# 3932 : lapl : lapl
# 3933 : wwlll : wwlll
# 3934 : awwo : awwo
# 3935 : oollll : oollll
# 3936 : olll : olll
# 3937 : repotrepot : repotrepot
# 3938 : sesuatupokona : sesuatupokona
# 3939 : dechsukses : dechsukses
# 3940 : bulangratis : bulangratis
# 3941 : migratis : migratis
# 3942 : sepeda : sepeda
# 3943 : listrik : listrik
# 3944 : luckyegg : luckyegg
# 3945 : pantengin : pantengin
# 3946 : lopppee : lopppee
# 3947 : grup : grup
# 3948 : diskonan : diskon
# 3949 : unistal : unistal
# 3950 : kmpreettt : kmpreettt
# 3951 : apps : apps
# 3952 : onmir : onmir
# 3953 : bngsaattt : bngsaattt
# 3954 : tungguin : tungguin
# 3955 : pemakaian : pakai
# 3956 : ratarata : ratarata
# 3957 : terpangpang : terpangpang
# 3958 : bohongin : bohongin
# 3959 : range : range
# 3960 : garansi : garansi
# 3961 : perkecil : kecil
# 3962 : siippp : siippp
# 3963 : hidupkusaat : hidupkusaat
# 3964 : tipis : tipis
# 3965 : kantongbebas : kantongbebas
# 3966 : jebol : jebol
# 3967 : gilak : gilak
# 3968 : soopi : soopi
# 3969 : beras : beras
# 3970 : thxyou : thxyou
# 3971 : bngtgratis : bngtgratis
# 3972 : sarankan : saran
# 3973 : selektif : selektif
# 3974 : bestttt : bestttt
# 3975 : marbels : marbels
# 3976 : keamanan : aman
# 3977 : imel : imel
# 3978 : inbox : inbox
# 3979 : alternatif : alternatif
# 3980 : autentikasi : autentikasi
# 3981 : naut : naut
# 3982 : ajukan : aju
# 3983 : credit : credit
# 3984 : okeeokeokeee : okeeokeokeee
# 3985 : cpet : cpet
# 3986 : menjengkelkan : jengkel
# 3987 : sing : sing
# 3988 : amanan : aman
# 3989 : sgag : sgag
# 3990 : smart : smart
# 3991 : plyanan : plyanan
# 3992 : goodchoice : goodchoice
# 3993 : bertahuntahun : bertahuntahun
# 3994 : lazadabaru : lazadabaru
# 3995 : susu : susu
# 3996 : sampaimasih : sampaimasih
# 3997 : mandek : mandek
# 3998 : sidoarjodibatalin : sidoarjodibatalin
# 3999 : wkwkwk : wkwkwk
# 4000 : kalia : kalia
# 4001 : dibatin : batin
# 4002 : harg : harg
# 4003 : nt : nt
# 4004 : puasnya : puas
# 4005 : memuas : muas
# 4006 : ajuin : ajuin
# 4007 : loveeeeee : loveeeeee
# 4008 : ayah : ayah
# 4009 : beliau : beliau
# 4010 : buta : buta
# 4011 : berangkat : berangkat
# 4012 : ringkih : ringkih
# 4013 : memikul : pikul
# 4014 : mimpimimpi : mimpimimpi
# 4015 : pundaknya : pundak
# 4016 : anaknya : anak
# 4017 : keringat : keringat
# 4018 : ikhlas : ikhlas
# 4019 : mengorbankannya : korban
# 4020 : kumaha : maha
# 4021 : barudak : barudak
# 4022 : wellll : wellll
# 4023 : taun : taun
# 4024 : ribuan : ribu
# 4025 : pylater : pylater
# 4026 : succes : succes
# 4027 : percepat : cepat
# 4028 : euy : euy
# 4029 : gogde : gogde
# 4030 : mantapnya : mantap
# 4031 : smakin : smakin
# 4032 : laazada : laazada
# 4033 : denda : denda
# 4034 : lawas : lawas
# 4035 : respek : respek
# 4036 : apliksi : apliksi
# 4037 : aplikasih : aplikasih
# 4038 : senanq : senanq
# 4039 : sihhh : sihhh
# 4040 : yees : yees
# 4041 : komplitbanyak : komplitbanyak
# 4042 : terjangkaumantap : terjangkaumantap
# 4043 : pengirimansekarang : pengirimansekarang
# 4044 : peruban : uban
# 4045 : kinerja : kerja
# 4046 : lainnyasekarang : lainnyasekarang
# 4047 : jtsaya : jtsaya
# 4048 : janjian : janji
# 4049 : ditengah : tengah
# 4050 : jalanga : jalanga
# 4051 : cstapa : cstapa
# 4052 : situ : situ
# 4053 : pemesan : mes
# 4054 : dilakukakn : dilakukakn
# 4055 : troma : troma
# 4056 : payment : payment
# 4057 : transferbarang : transferbarang
# 4058 : remaks : remaks
# 4059 : reschdule : reschdule
# 4060 : konfirm : konfirm
# 4061 : bayarnyabah : bayarnyabah
# 4062 : danatpi : danatpi
# 4063 : mke : mke
# 4064 : notifikasinya : notifikasi
# 4065 : ngegaguin : ngegaguin
# 4066 : memuaskncepat : memuaskncepat
# 4067 : pengirimantepat : pengirimantepat
# 4068 : waktupokonya : waktupokonya
# 4069 : mantp : mantp
# 4070 : edebes : edebes
# 4071 : practisedan : practisedan
# 4072 : bravo : bravo
# 4073 : lazadathanks : lazadathanks
# 4074 : pen : pen
# 4075 : airsoftgun : airsoftgun
# 4076 : sngatt : sngatt
# 4077 : akuh : akuh
# 4078 : donlowd : donlowd
# 4079 : sekalinya : sekali
# 4080 : promosinya : promosi
# 4081 : ngebatalin : ngebatalin
# 4082 : kuning : kuning
# 4083 : wlwpun : wlwpun
# 4084 : dihapus : hapus
# 4085 : heheee : heheee
# 4086 : bangt : bangt
# 4087 : kebijaksaan : kebijaksaan
# 4088 : tagihan : tagih
# 4089 : alfamartindomart : alfamartindomart
# 4090 : kebijksaan : kebijksaan
# 4091 : topppp : topppp
# 4092 : sangsat : sangsat
# 4093 : reating : reating
# 4094 : superrrrrrrrr : superrrrrrrrr
# 4095 : kereb : kereb
# 4096 : hasila : hasila
# 4097 : thankyou : thankyou
# 4098 : lopeeee : lopeeee
# 4099 : sekebon : kebon
# 4100 : gajls : gajls
# 4101 : dwi : dwi
# 4102 : winarso : winarso
# 4103 : okeeeeeee : okeeeeeee
# 4104 : cokkk : cokkk
# 4105 : mendhooo : mendhooo
# 4106 : sebentr : sebentr
# 4107 : masukmya : masukmya
# 4108 : nyelel : nyelel
# 4109 : castamer : castamer
# 4110 : e : e
# 4111 : commerce : commerce
# 4112 : ditinjau : tinjau
# 4113 : dibenerin : dibenerin
# 4114 : selesaikan : selesai
# 4115 : lazrewardnya : lazrewardnya
# 4116 : jngan : jngan
# 4117 : laintetap : laintetap
# 4118 : uhuuy : uhuuy
# 4119 : sodap : sodap
# 4120 : nye : nye
# 4121 : diragukan : ragu
# 4122 : demianend : demianend
# 4123 : anjerrr : anjerrr
# 4124 : hangus : hangus
# 4125 : sia : sia
# 4126 : tanam : tanam
# 4127 : tapai : tapai
# 4128 : terpercays : terpercays
# 4129 : lunasin : lunasin
# 4130 : parahh : parahh
# 4131 : mengatas : atas
# 4132 : namakan : nama
# 4133 : pemenang : menang
# 4134 : hack : hack
# 4135 : baikbeda : baikbeda
# 4136 : dulusekarang : dulusekarang
# 4137 : laintrus : laintrus
# 4138 : terpercya : terpercya
# 4139 : palik : palik
# 4140 : paman : paman
# 4141 : oppoas : oppoas
# 4142 : nyala : nyala
# 4143 : jm : jm
# 4144 : respo : respo
# 4145 : sabarmau : sabarmau
# 4146 : kabar : kabar
# 4147 : mantaaabb : mantaaabb
# 4148 : oky : oky
# 4149 : bates : bates
# 4150 : boongan : boongan
# 4151 : gayaan : gaya
# 4152 : pmbayaran : pmbayaran
# 4153 : kredivo : kredivo
# 4154 : gliran : gliran
# 4155 : ngajuin : ngajuin
# 4156 : hapuss : hapuss
# 4157 : drpda : drpda
# 4158 : accesoriess : accesoriess
# 4159 : suksrs : suksrs
# 4160 : berpungsi : pungsi
# 4161 : baikini : baikini
# 4162 : teh : teh
# 4163 : ternya : ter
# 4164 : hadehhhhg : hadehhhhg
# 4165 : sejuta : juta
# 4166 : peminat : minat
# 4167 : sejahterakan : sejahtera
# 4168 : abang : abang
# 4169 : pinjol : pinjol
# 4170 : bunganya : bunga
# 4171 : tagih : tagih
# 4172 : gilaaaa : gilaaaa
# 4173 : bagusssss : bagusssss
# 4174 : gram : gram
# 4175 : lope : lope
# 4176 : lpoe : lpoe
# 4177 : semogaamanah : semogaamanah
# 4178 : uno : uno
# 4179 : spesial : spesial
# 4180 : card : card
# 4181 : editon : editon
# 4182 : flip : flip
# 4183 : mempunyainya : punya
# 4184 : yaya : yaya
# 4185 : bbrapa : bbrapa
# 4186 : bungan : bung
# 4187 : kapoklah : kapok
# 4188 : depkolektornya : depkolektornya
# 4189 : serem : rem
# 4190 : hadeuh : hadeuh
# 4191 : berkwalitas : berkwalitas
# 4192 : syang : syang
# 4193 : kebawa : bawa
# 4194 : barokah : barokah
# 4195 : rizki : rizki
# 4196 : lamban : lamban
# 4197 : san : san
# 4198 : ujungnya : ujung
# 4199 : penyelesaian : selesai
# 4200 : aelaku : aelaku
# 4201 : ajalah : aja
# 4202 : gandos : gandos
# 4203 : seharga : harga
# 4204 : ygy : ygy
# 4205 : bsik : bsik
# 4206 : apli : apli
# 4207 : nampilin : nampilin
# 4208 : tanda : tanda
# 4209 : htc : htc
# 4210 : hud : hud
# 4211 : cucu : cucu
# 4212 : fifi : fifi
# 4213 : iffjfnfigrjtiitirieid : iffjfnfigrjtiitirieid
# 4214 : vroofbigkgki : vroofbigkgki
# 4215 : eieirufuue : eieirufuue
# 4216 : figiiriefi : figiiriefi
# 4217 : roof : roof
# 4218 : ongkirnyaaaa : ongkirnyaaaa
# 4219 : srmoga : srmoga
# 4220 : teurs : teurs
# 4221 : balas : balas
# 4222 : nyelesain : nyelesain
# 4223 : ngelek : ngelek
# 4224 : pernh : pernh
# 4225 : slh : slh
# 4226 : dugaan : duga
# 4227 : jengekl : jengekl
# 4228 : stts : stts
# 4229 : ditmpt : ditmpt
# 4230 : pket : pket
# 4231 : bnr : bnr
# 4232 : msuk : msuk
# 4233 : pkai : pkai
# 4234 : peket : peket
# 4235 : asti : asti
# 4236 : okeyy : okeyy
# 4237 : lengkaphemat : lengkaphemat
# 4238 : resah : resah
# 4239 : sasaran : sasar
# 4240 : salahkan : salah
# 4241 : menau : tau
# 4242 : tengok : tengok
# 4243 : smuanya : smuanya
# 4244 : menjualnya : jual
# 4245 : hargapromo : hargapromo
# 4246 : pertahankankalo : pertahankankalo
# 4247 : kreditnya : kredit
# 4248 : turunkan : turun
# 4249 : setting : setting
# 4250 : terbiasa : biasa
# 4251 : blnjanya : blnjanya
# 4252 : hapal : hapal
# 4253 : mn : mn
# 4254 : terpelihara : pelihara
# 4255 : amatt : amatt
# 4256 : membantuu : membantuu
# 4257 : bangettttttt : bangettttttt
# 4258 : beruntung : untung
# 4259 : meriahh : meriahh
# 4260 : banyakk : banyakk
# 4261 : diskonn : diskonn
# 4262 : nex : nex
# 4263 : terusan : terus
# 4264 : persetujuan : tuju
# 4265 : njir : njir
# 4266 : juta : juta
# 4267 : sanagtt : sanagtt
# 4268 : bosque : bosque
# 4269 : msntap : msntap
# 4270 : potongn : potongn
# 4271 : fasilitas : fasilitas
# ...
# 7067 : jxmco : jxmco
# 7068 : jxjxo : jxjxo
# 7069 : xc : xc
# 7070 : db : db
# 7071 : xs : xs
# 7072 : hxkd : hxkd
# 7073 : xnsi : xnsi
# 7074 : cw : cw
# 7075 : bk : bk
# 7076 : kssikshx : kssikshx
# 7077 : mengembangkan : kembang
# 7078 : renak : renak
# 7079 : renik : renik
# 7080 : ehhhh : ehhhh
# 7081 : tautaunya : tautaunya
# 7082 : rumitny : rumitny
# 7083 : verifikasiny : verifikasiny
# 7084 : tllu : tllu
# 7085 : sabgat : sabgat
# 7086 : bereh : bereh
# 7087 : baeg : baeg
# 7088 : gantung : gantung
# 7089 : dibikin : bikin
# 7090 : cobain : cobain
# 7091 : ajja : ajja
# 7092 : murahhhh : murahhhh
# 7093 : kecmatan : kecmatan
# 7094 : jmanis : jmanis
# 7095 : pelanggaran : langgar
# 7096 : bngttt : bngttt
# 7097 : teus : teus
# 7098 : re : re
# 7099 : ek : ek
# 7100 : sampaialhasil : sampaialhasil
# 7101 : nokia : nokia
# 7102 : smgkn : smgkn
# 7103 : jelekudh : jelekudh
# 7104 : ajaa : ajaa
# 7105 : pesenannyaa : pesenannyaa
# 7106 : onlien : onlien
# 7107 : samsul : samsul
# 7108 : mikirin : mikirin
# 7109 : toou : toou
# 7110 : jntjne : jntjne
# 7111 : duh : duh
# 7112 : diskoun : diskoun
# 7113 : jozz : jozz
# 7114 : relatif : relatif
# 7115 : jaman : jaman
# 7116 : nihh : nihh
# 7117 : nyaupdate : nyaupdate
# 7118 : kyn : kyn
# 7119 : gelandangan : gelandang
# 7120 : gni : gni
# 7121 : jem : jem
# 7122 : kerudung : kerudung
# 7123 : maliang : maliang
# 7124 : pangicuah : pangicuah
# 7125 : amng : amng
# 7126 : untuku : untuku
# 7127 : sanangat : sanangat
# 7128 : laja : laja
# 7129 : lajadanya : lajadanya
# 7130 : bertagung : bertagung
# 7131 : sayagya : sayagya
# 7132 : betull : betull
# 7133 : loging : loging
# 7134 : shh : shh
# 7135 : see : see
# 7136 : nkqjdbuywm : nkqjdbuywm
# 7137 : peta : peta
# 7138 : travel : travel
# 7139 : bestwalau : bestwalau
# 7140 : kotorpesen : kotorpesen
# 7141 : nyusahin : nyusahin
# 7142 : rakyat : rakyat
# 7143 : barangkalo : barangkalo
# 7144 : bagusdan : bagusdan
# 7145 : layangan : layang
# 7146 : maksud : maksud
# 7147 : bertanggungjawab : bertanggungjawab
# 7148 : sklii : sklii
# 7149 : kainya : kainya
# 7150 : pesanansemoga : pesanansemoga
# 7151 : sukkak : sukkak
# 7152 : batesin : batesin
# 7153 : annya : annya
# 7154 : coban : coban
# 7155 : lancarkan : lancar
# 7156 : pengajuanyatokonya : pengajuanyatokonya
# 7157 : kh : kh
# 7158 : ramahsukses : ramahsukses
# 7159 : jop : jop
# 7160 : aguuuus : aguuuus
# 7161 : seringgratis : seringgratis
# 7162 : manteppak : manteppak
# 7163 : lazads : lazads
# 7164 : mewaspadai : waspada
# 7165 : gurus : gurus
# 7166 : vaca : vaca
# 7167 : haduh : haduh
# 7168 : digitalmedia : digitalmedia
# 7169 : bagussssssss : bagussssssss
# 7170 : mempermudahkan : mudah
# 7171 : tbk : tbk
# 7172 : dulusaya : dulusaya
# 7173 : shi : shi
# 7174 : lazadapelayananya : lazadapelayananya
# 7175 : listening : listening
# 7176 : buy : buy
# 7177 : or : or
# 7178 : dvd : dvd
# 7179 : jatim : jatim
# 7180 : ringanpelayanan : ringanpelayanan
# 7181 : memuaskanpengiriman : memuaskanpengiriman
# 7182 : selisihnya : selisih
# 7183 : lazadapayleter : lazadapayleter
# 7184 : curigai : curiga
# 7185 : plyter : plyter
# 7186 : lanjutkan : lanjut
# 7187 : diamankan : aman
# 7188 : complen : complen
# 7189 : freeong : freeong
# 7190 : fiture : fiture
# 7191 : voucherdiskon : voucherdiskon
# 7192 : date : date
# 7193 : lazadayang : lazadayang
# 7194 : pesananmisal : pesananmisal
# 7195 : kanapakah : kanapakah
# 7196 : inipantas : inipantas
# 7197 : bidang : bidang
# 7198 : apapundalam : apapundalam
# 7199 : nyajangan : nyajangan
# 7200 : kepentingan : penting
# 7201 : thee : thee
# 7202 : trlalu : trlalu
# 7203 : terbaiksalam : terbaiksalam
# 7204 : slalutokonya : slalutokonya
# 7205 : dilazadaresponya : dilazadaresponya
# 7206 : utuh : utuh
# 7207 : wsktu : wsktu
# 7208 : banyakan : banyak
# 7209 : membalasnya : balas
# 7210 : msak : msak
# 7211 : ynx : ynx
# 7212 : ribetdan : ribetdan
# 7213 : keyword : keyword
# 7214 : nyebar : nyebar
# 7215 : bangetgratis : bangetgratis
# 7216 : mencewakan : mencewakan
# 7217 : nyaaaaa : nyaaaaa
# 7218 : sss : sss
# 7219 : urungkan : urung
# 7220 : kereeennnn : kereeennnn
# 7221 : terpencil : pencil
# 7222 : tepatnya : tepat
# 7223 : baiksemoga : baiksemoga
# 7224 : trasnfer : trasnfer
# 7225 : toop : toop
# 7226 : tingkatan : tingkat
# 7227 : komplein : komplein
# 7228 : mehala : mehala
# 7229 : bwangeeet : bwangeeet
# 7230 : koreksi : koreksi
# 7231 : kampung : kampung
# 7232 : disana : sana
# 7233 : mlh : mlh
# 7234 : limitnya : limit
# 7235 : hadehhh : hadehhh
# 7236 : limitlazpaylaternyapembayaran : limitlazpaylaternyapembayaran
# 7237 : lancardan : lancardan
# 7238 : tokcer : tokcer
# 7239 : limittp : limittp
# 7240 : lumayanlah : lumayan
# 7241 : komunikasi : komunikasi
# 7242 : ridak : ridak
# 7243 : lantaran : lantar
# 7244 : wqh : wqh
# 7245 : dikuasai : asai
# 7246 : aring : aring
# 7247 : planet : planet
# 7248 : pantes : pantes
# 7249 : lazadamemang : lazadamemang
# 7250 : kepakai : pakai
# 7251 : lunasinkalo : lunasinkalo
# 7252 : lazadanyaudah : lazadanyaudah
# 7253 : ongkirdan : ongkirdan
# 7254 : istri : istri
# 7255 : hf : hf
# 7256 : blutut : blutut
# 7257 : hlp : hlp
# 7258 : kumplit : kumplit
# 7259 : keriset : riset
# 7260 : sandi : sandi
# 7261 : kokjdi : kokjdi
# 7262 : robotlah : robot
# 7263 : ionhhh : ionhhh
# 7264 : mantabbgratis : mantabbgratis
# 7265 : ongkirharga : ongkirharga
# 7266 : maubuat : maubuat
# 7267 : kedepannyamakasih : kedepannyamakasih
# 7268 : bobol : bobol
# 7269 : xsaldo : xsaldo
# 7270 : latarnya : latar
# 7271 : okkkkk : okkkkk
# 7272 : mudahk : mudahk
# 7273 : karennn : karennn
# 7274 : sllalu : sllalu
# 7275 : disconnya : disconnya
# 7276 : bangetbarangnya : bangetbarangnya
# 7277 : hilangan : hilang
# 7278 : kontrol : kontrol
# 7279 : kreen : kreen
# 7280 : terang : terang
# 7281 : pesananjika : pesananjika
# 7282 : rek : rek
# 7283 : lazadacepat : lazadacepat
# 7284 : binta : binta
# 7285 : taon : taon
# 7286 : primer : primer
# 7287 : sekunder : sekunder
# 7288 : nyaharga : nyaharga
# 7289 : mencarinya : cari
# 7290 : kiik : kiik
# 7291 : belanjatrushadiahnya : belanjatrushadiahnya
# 7292 : perbaharui : baharu
# 7293 : angsurin : angsurin
# 7294 : kenak : nak
# 7295 : sinidi : sidi
# 7296 : ads : ads
# 7297 : pepekkkkkkk : pepekkkkkkk
# {'bagus': 'bagus', 'barangnya': 'barang', 'gak': 'gak', 'cod': 'cod', 'ya': 'ya', 'good': 'good', 'mntapp': 'mntapp', 'diskon': 'diskon', 'pengiriman': 'kirim', 'aman': 'aman', 'pengemasan': 'emas', 'memudahkan': 'mudah', 'yg': 'yg', 'semoga': 'moga', 'cepat': 'cepat', 'mengecewakan': 'kecewa', 'puas': 'puas', 'blanja': 'blanja', 'lazadabarangnya': 'lazadabarangnya', 'harga': 'harga', 'terjangkau': 'jangkau', 'dryio': 'dryio', 'murah': 'murah', 'nya': 'nya', 'lazada': 'lazada', 'lumayan': 'lumayan', 'nambah': 'nambah', 'ilmu': 'ilmu', 'pengetahuan': 'tahu', 'segitu': 'segitu', 'dlu': 'dlu', 'proses': 'proses', 'memuaskan': 'muas', 'rekomended': 'rekomended', 'keren': 'keren', 'belanja': 'belanja', 'trmksh': 'trmksh', 'penguna': 'penguna', 'kebanyakan': 'banyak', 'rp': 'rp', 'pukonya': 'pukonya', 'mantul': 'mantul', 'mantam': 'mantam', 'mantap': 'mantap', 'mudah': 'mudah', 'efisien': 'efisien', 'kenapah': 'kenapah', 'gangguan': 'ganggu', 'ongkir': 'ongkir', 'tmbh': 'tmbh', 'mhl': 'mhl', 'gk': 'gk', 'tersedia': 'sedia', 'gratis': 'gratis', 'mitha': 'mitha', 'fachmi': 'fachmi', 'iklan': 'iklan', 'mengganggu': 'ganggu', 'tolong': 'tolong', 'tertibkan': 'tertib', 'seller': 'seller', 'yan': 'yan', 'amanah': 'amanah', 'nakal': 'nakal', 'curang': 'curang', 'senang': 'senang', 'terimakasih': 'terimakasih', 'ok': 'ok', 'pengembalian': 'kembali', 'dananya': 'dana', 'banget': 'banget', 'canggih': 'canggih', 'akun': 'akun', 'metode': 'metode', 'ganti': 'ganti', 'akunpun': 'akun', 'g': 'g', 'bantu': 'bantu', 'jualan': 'jual', 'super': 'super', 'beli': 'beli', 'tgl': 'tgl', 'haduhh': 'haduhh', 'hebat': 'hebat', 'the': 'the', 'best': 'best', 'pengiririman': 'pengiririman', 'teks': 'teks', 'aslinya': 'asli', 'dipotong': 'potong', 'ga': 'ga', 'berbagi': 'bagi', 'voucher': 'voucher', 'sprti': 'sprti', 'memakai': 'pakai', 'brang': 'brang', 'sesuai': 'sesuai', 'pesenan': 'sen', 'toko': 'toko', 'jg': 'jg', 'enak': 'enak', 'an': 'an', 'versi': 'versi', 'barang': 'barang', 'asli': 'asli', 'percaya': 'percaya', 'aja': 'aja', 'aplikasi': 'aplikasi', 'kooon': 'kooon', 'mulu': 'mulu', 'update': 'update', 'nice': 'nice', 'masuk': 'masuk', 'sukses': 'sukses', 'paket': 'paket', 'jarak': 'jarak', 'deket': 'deket', 'habis': 'habis', 'pikir': 'pikir', 'kali': 'kali', 'telat': 'telat', 'nyampee': 'nyampee', 'nerima': 'nerima', 'on': 'on', 'job': 'job', 'kecewa': 'kecewa', 'beratt': 'beratt', 'oke': 'oke', 'ngan': 'ngan', 'marahal': 'marahal', 'ken': 'ken', 'ah': 'ah', 'bisi': 'bis', 'centang': 'centang', 'lazadabon': 'lazadabon', 'bekukan': 'beku', 'kemarin': 'kemarin', 'tlpn': 'tlpn', 'suruh': 'suruh', 'pinjam': 'pinjam', 'karna': 'karna', 'pembayaran': 'bayar', 'cek': 'cek', 'jos': 'jos', 'sanggar': 'sanggar', 'embelpengiriman': 'embelpengiriman', 'suka': 'suka', 'ny': 'ny', 'rusak': 'rusak', 'rapih': 'rapih', 'berantakan': 'beranta', 'tebih': 'tebih', 'tampa': 'tampa', 'gimana': 'gimana', 'sih': 'sih', 'pesen': 'sen', 'estimasi': 'estimasi', 'sampe': 'sampe', 'trus': 'trus', 'skrg': 'skrg', 'kemas': 'kemas', 'brg': 'brg', 'sisa': 'sisa', 'dikemas': 'kemas', 'kmrn': 'kmrn', 'cancel': 'cancel', 'maksa': 'maksa', 'pdhl': 'pdhl', 'ampe': 'ampe', 'pengemasannya': 'emas', 'pokoknya': 'pokok', 'tolak': 'tolak', 'kedepan': 'depan', 'rumah': 'rumah', 'mahal': 'mahal', 'sip': 'sip', 'bosq': 'bosq', 'ribet': 'ribet', 'chat': 'chat', 'chatan': 'chatan', 'penjual': 'jual', 'kekirim': 'kirim', 'mntap': 'mntap', 'promo': 'promo', 'berbelanja': 'belanja', 'love': 'love', 'it': 'it', 'thank': 'thank', 'you': 'you', 'bnyk': 'bnyk', 'untungnya': 'untung', 'membantu': 'bantu', 'berblanjamksh': 'berblanjamksh', 'complain': 'complain', 'mines': 'mes', 'pelayanannya': 'layan', 'menampilkan': 'tampil', 'berkualitas': 'kualitas', 'kurirnya': 'kurir', 'ramah': 'ramah', 'sopan': 'sopan', 'bintang': 'bintang', 'alhamdulillah': 'alhamdulillah', 'sllu': 'sllu', 'dn': 'dn', 'ttp': 'ttp', 'ber': 'ber', 'kualitas': 'kualitas', 'membantubelanja': 'membantubelanja', 'nyaman': 'nyaman', 'cumn' ...
# ------------------------
#                                               content  score  \
# 0                                               bagus      5
# 1                                   barangnya bagus 👍      5
# 2                         kenapa gak bisa cod lagi ya      4
# 3                                                good      5
# 4                                              mntapp      5
# 5       banyak diskon pengiriman aman pengemasan baik      5
# 6                          memudahkan ibu2 yg bekerja      5
# 7       semoga cepat sampai dan tidak mengecewakan ..      5
# 8   saya puas blanja di lazada,barangnya bagus den...      5
# 9                                               dryio      5
# 10                                                  👍      5
# 11                                               baik      5
# 12                    Murah murah harga nya di Lazada      5
# 13               Lumayan buat nambah ilmu pengetahuan      5
# 14                                               Good      5
# 15                                         segitu dlu      3
# 16                                       proses cepat      5
# 17        bagus sangat memuaskan dan rekomended keren      5
# 18             sangat memuaskan belanja di lazada 😊🥰😍      5
# 19                                      trmksh lazada      5
#
#                                            text_clean  \
# 0                                               bagus
# 1                                    barangnya bagus
# 2                         kenapa gak bisa cod lagi ya
# 3                                                good
# 4                                              mntapp
# 5       banyak diskon pengiriman aman pengemasan baik
# 6                           memudahkan ibu yg bekerja
# 7         semoga cepat sampai dan tidak mengecewakan
# 8   saya puas blanja di lazadabarangnya bagus deng...
# 9                                               dryio
# 10
# 11                                               baik
# 12                    murah murah harga nya di lazada
# 13               lumayan buat nambah ilmu pengetahuan
# 14                                               good
# 15                                         segitu dlu
# 16                                       proses cepat
# 17        bagus sangat memuaskan dan rekomended keren
# 18                sangat memuaskan belanja di lazada
# 19                                      trmksh lazada
#
#                                         text_StopWord  \
# 0                                               bagus
# 1                                     barangnya bagus
# 2                                          gak cod ya
# 3                                                good
# 4                                              mntapp
# 5                   diskon pengiriman aman pengemasan
# 6                                       memudahkan yg
# 7                           semoga cepat mengecewakan
# 8   puas blanja lazadabarangnya bagus harga yg ter...
# 9                                               dryio
# 10
# 11
# 12                       murah murah harga nya lazada
# 13                    lumayan nambah ilmu pengetahuan
# 14                                               good
# 15                                         segitu dlu
# 16                                       proses cepat
# 17                   bagus memuaskan rekomended keren
# 18                           memuaskan belanja lazada
# 19                                      trmksh lazada
#
#                                           text_tokens  \
# 0                                             [bagus]
# 1                                  [barangnya, bagus]
# 2                                      [gak, cod, ya]
# 3                                              [good]
# 4                                            [mntapp]
# 5              [diskon, pengiriman, aman, pengemasan]
# 6                                    [memudahkan, yg]
# 7                       [semoga, cepat, mengecewakan]
# 8   [puas, blanja, lazadabarangnya, bagus, harga, ...
# 9                                             [dryio]
# 10                                                 []
# 11                                                 []
# 12                 [murah, murah, harga, nya, lazada]
# 13               [lumayan, nambah, ilmu, pengetahuan]
# 14                                             [good]
# 15                                      [segitu, dlu]
# 16                                    [proses, cepat]
# 17              [bagus, memuaskan, rekomended, keren]
# 18                       [memuaskan, belanja, lazada]
# 19                                   [trmksh, lazada]
#
#                                        text_steamindo
# 0                                               bagus
# 1                                        barang bagus
# 2                                          gak cod ya
# 3                                                good
# 4                                              mntapp
# 5                              diskon kirim aman emas
# 6                                            mudah yg
# 7                                   moga cepat kecewa
# 8   puas blanja lazadabarangnya bagus harga yg jan...
# 9                                               dryio
# 10
# 11
# 12                       murah murah harga nya lazada
# 13                           lumayan nambah ilmu tahu
# 14                                               good
# 15                                         segitu dlu
# 16                                       proses cepat
# 17                        bagus muas rekomended keren
# 18                                muas belanja lazada
# 19                                      trmksh lazada

# %%
data_clean.to_csv('lazada.csv', index= False) #kemudian simpan hasil text preprocessing ke file csv
